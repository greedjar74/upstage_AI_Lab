# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %% [markdown]
# # 데이터 가져오기

# %% [markdown]
# ## 포지션별 데이터

# %%
data_path = './League1_data/League1_Position_Player_Stats/'
path_list = os.listdir(data_path)
path_list.pop(2)
path_list
# Out:
# ['L1_M_Player.csv',
#  'L1_AM_Player.csv',
#  'L1_DM_Player.csv',
#  'L1_FW_Player.csv',
#  'L1_GK_Player.csv',
#  'L1_D_Player.csv']

# %%
L1_M_player_df = pd.read_csv(data_path+path_list[0])
L1_AM_player_df = pd.read_csv(data_path+path_list[1])
L1_DM_player_df = pd.read_csv(data_path+path_list[2])
L1_FW_player_df = pd.read_csv(data_path+path_list[3])
L1_GK_player_df = pd.read_csv(data_path+path_list[4])
L1_D_player_df = pd.read_csv(data_path+path_list[5])

# %%
print(L1_GK_player_df.shape)
print(L1_M_player_df.shape)
print(L1_AM_player_df.shape)
print(L1_DM_player_df.shape)
print(L1_FW_player_df.shape)
print(L1_D_player_df.shape)
# Out:
# (20, 35)
# (57, 35)
# (62, 35)
# (29, 35)
# (20, 35)
# (123, 35)

# %%
# col확인 -> Unnamed: 0 제거 필요
L1_AM_player_df.columns
# Out:
# Index(['Unnamed: 0', 'player_name', 'team_number', 'Team', 'age', 'position',
#        'Apps', 'Mins', 'Assists', 'KeyP', 'AvgP', 'PS%', 'Crosses', 'LongB',
#        'ThrB', 'Rating', 'Goals', 'Yel', 'Red', 'SpG', 'AerialsWon', 'MoM',
#        'Dribble', 'Fouled', 'Off', 'Disp', 'UnsTch', 'Tackles', 'Inter',
#        'Fouls', 'Offsides', 'Clear', 'Drb', 'Blocks', 'OwnG'],
#       dtype='object')

# %%
#  Unnamed: 0 제거
L1_GK_player_df.drop('Unnamed: 0', axis=1, inplace=True)
L1_GK_player_df.shape
# Out:
# (20, 34)

# %%
#  Unnamed: 0 제거
L1_M_player_df.drop('Unnamed: 0', axis=1, inplace=True)
L1_M_player_df.shape
# Out:
# (57, 34)

# %%
#  Unnamed: 0 제거
L1_AM_player_df.drop('Unnamed: 0', axis=1, inplace=True)
L1_AM_player_df.shape
# Out:
# (62, 34)

# %%
#  Unnamed: 0 제거
L1_DM_player_df.drop('Unnamed: 0', axis=1, inplace=True)
L1_DM_player_df.shape
# Out:
# (29, 34)

# %%
#  Unnamed: 0 제거
L1_FW_player_df.drop('Unnamed: 0', axis=1, inplace=True)
L1_FW_player_df.shape
# Out:
# (20, 34)

# %%
#  Unnamed: 0 제거
L1_D_player_df.drop('Unnamed: 0', axis=1, inplace=True)
L1_D_player_df.shape
# Out:
# (123, 34)

# %% [markdown]
# # L1 팀 분석 데이터

# %%
L1_Team_df = pd.read_csv('./League1_data/League1_22_23_Team_Table_Added.csv')
L1_Team_df.columns
# Out:
# Index(['Unnamed: 0', 'Rank_x', 'Team', 'Goals', 'Shotspg', 'Yellow', 'Red',
#        'Possession', 'Pass', 'AerialsWon', 'Rating', 'def_Shotspg',
#        'def_Tacklespg', 'def_Interceptionspg', 'def_Foulspg', 'def_Offsidespg',
#        'of_Shotspg', 'of_ShotsOTpg', 'of_Dribblespg', 'of_Fouledpg', 'xG',
#        'xGDiff', 'Shots', 'xG_Shots', 'Rank_y', 'P', 'W', 'D', 'L', 'GF', 'GA',
#        'GD', 'Pts'],
#       dtype='object')

# %%
L1_Team_df.drop('Unnamed: 0', axis=1, inplace=True)

# %% [markdown]
# # GK 포지션 데이터
# ## GK포지션에서 승리에 가장 큰 영향을 주는 변수 추출
# - 포지션의 특수성을 생각해서 필요없는 변수는 미리 제거

# %%
L1_GK_df = pd.merge(L1_GK_player_df, L1_Team_df[['Team', 'Pts']], on='Team', how='inner')

# %%
L1_GK_df.columns
# Out:
# Index(['player_name', 'team_number', 'Team', 'age', 'position', 'Apps', 'Mins',
#        'Assists', 'KeyP', 'AvgP', 'PS%', 'Crosses', 'LongB', 'ThrB', 'Rating',
#        'Goals', 'Yel', 'Red', 'SpG', 'AerialsWon', 'MoM', 'Dribble', 'Fouled',
#        'Off', 'Disp', 'UnsTch', 'Tackles', 'Inter', 'Fouls', 'Offsides',
#        'Clear', 'Drb', 'Blocks', 'OwnG', 'Pts'],
#       dtype='object')

# %%
# 수치형 데이터만 뽑아온다.

L1_GK_numeric_df = L1_GK_df.select_dtypes(['int64', 'float64'])

# %%
L1_GK_corr_matrix = L1_GK_numeric_df.corr()
L1_GK_corr_matrix
# Out:
#              team_number       age      Apps      Mins   Assists      KeyP  \
# team_number     1.000000  0.021390  0.191679  0.201402 -0.150672  0.006271
# age             0.021390  1.000000 -0.168229 -0.181238  0.130732 -0.024740
# Apps            0.191679 -0.168229  1.000000  0.998845  0.052989  0.003558
# Mins            0.201402 -0.181238  0.998845  1.000000  0.037073  0.015333
# Assists        -0.150672  0.130732  0.052989  0.037073  1.000000  0.251630
# KeyP            0.006271 -0.024740  0.003558  0.015333  0.251630  1.000000
# AvgP            0.034215  0.316339  0.000696  0.001780  0.274309  0.605157
# PS%            -0.030228 -0.253431  0.323264  0.320635  0.243441  0.150785
# Crosses              NaN       NaN       NaN       NaN       NaN       NaN
# LongB           0.182498  0.556904 -0.204874 -0.198818 -0.015049  0.241079
# ThrB                 NaN       NaN       NaN       NaN       NaN       NaN
# Rating          0.026249 -0.226819  0.192146  0.207441  0.117954  0.423625
# Goals                NaN       NaN       NaN       NaN       NaN       NaN
# Yel             0.285695 -0.159353  0.455837  0.448497  0.229200 -0.119280
# Red            -0.216428 -0.079377  0.047949  0.036753 -0.132110 -0.275010
# SpG                  NaN       NaN       NaN       NaN       NaN       NaN
# AerialsWon     -0.205057 -0.365930 -0.109309 -0.103180  0.121459 -0.198658
# MoM             0.256471 -0.121604  0.609735  0.621866 -0.073667 -0.153351
# Dribble        -0.048574  0.056687 -0.452492 -0.430803 -0.157243 -0.054554
# Fouled          0.099031 -0.510300  0.292514  0.282600  0.170956  0.071175
# Off                  NaN       NaN       NaN       NaN       NaN       NaN
# Disp                 NaN       NaN       NaN       NaN       NaN       NaN
# UnsTch          0.007180  0.197920  0.252637  0.245528  0.022875 -0.190476
# Tackles        -0.033264 -0.272141 -0.298895 -0.280603 -0.205879 -0.190476
# Inter          -0.159824 -0.098960 -0.067607 -0.079671 -0.205879  0.047619
# Fouls          -0.255779  0.283433 -0.004077 -0.029412  0.628971 -0.054554
# Offsides             NaN       NaN       NaN       NaN       NaN       NaN
# Clear           0.183380 -0.131346  0.082876  0.084412 -0.172375 -0.399604
# Drb            -0.000126  0.558327 -0.339235 -0.345840 -0.073750  0.065795
# Blocks               NaN       NaN       NaN       NaN       NaN       NaN
# OwnG                 NaN       NaN       NaN       NaN       NaN       NaN
# Pts            -0.139850 -0.157578  0.341110  0.338090  0.323276  0.453770
#
#                  AvgP       PS%  Crosses     LongB  ...    UnsTch   Tackles  \
# team_number  0.034215 -0.030228      NaN  0.182498  ...  0.007180 -0.033264
# age          0.316339 -0.253431      NaN  0.556904  ...  0.197920 -0.272141
# Apps         0.000696  0.323264      NaN -0.204874  ...  0.252637 -0.298895
# Mins         0.001780  0.320635      NaN -0.198818  ...  0.245528 -0.280603
# Assists      0.274309  0.243441      NaN -0.015049  ...  0.022875 -0.205879
# KeyP         0.605157  0.150785      NaN  0.241079  ... -0.190476 -0.190476
# AvgP         1.000000  0.159944      NaN  0.589751  ...  0.211029 -0.313440
# PS%          0.159944  1.000000      NaN -0.362145  ...  0.083942 -0.289134
# Crosses           NaN       NaN      NaN       NaN  ...       NaN       NaN
# LongB        0.589751 -0.362145      NaN  1.000000  ...  0.227459 -0.208390
# ThrB              NaN       NaN      NaN       NaN  ...       NaN       NaN
# Rating       0.402267  0.421244      NaN -0.027089  ...  0.062060 -0.369660
# Goals             NaN       NaN      NaN       NaN  ...       NaN       NaN
# Yel         -0.213217  0.315953      NaN -0.384548  ... -0.289679 -0.034080
# Red          0.007966 -0.151619      NaN -0.168682  ...  0.030557  0.030557
# SpG               NaN       NaN      NaN       NaN  ...       NaN       NaN
# AerialsWon  -0.144768  0.039500      NaN -0.341961  ...  0.072239  0.343137
# MoM          0.055756  0.101174      NaN -0.012235  ...  0.492336 -0.314772
# Dribble      0.213321  0.023152      NaN  0.285553  ...  0.218218  0.218218
# Fouled       0.194818  0.286248      NaN -0.287045  ... -0.071175  0.213524
# Off               NaN       NaN      NaN       NaN  ...       NaN       NaN
# Disp              NaN       NaN      NaN       NaN  ...       NaN       NaN
# UnsTch       0.211029  0.083942      NaN  0.227459  ...  1.000000 -0.190476
# Tackles     -0.313440 -0.289134      NaN -0.208390  ... -0.190476  1.000000
# Inter        0.080688 -0.111923      NaN -0.222010  ... -0.428571  0.285714
# Fouls        0.248875  0.115758      NaN -0.159161  ... -0.054554 -0.054554
# Offsides          NaN       NaN      NaN       NaN  ...       NaN       NaN
# Clear       -0.340147 -0.514868      NaN -0.146487  ...  0.130483  0.171259
# Drb          0.483106 -0.190441      NaN  0.546382  ...  0.285112  0.065795
# Blocks            NaN       NaN      NaN       NaN  ...       NaN       NaN
# OwnG              NaN       NaN      NaN       NaN  ...       NaN       NaN
# Pts          0.301362  0.801292      NaN -0.183129  ... -0.162315 -0.470357
#
#                 Inter     Fouls  Offsides         Clear       Drb  Blocks  \
# team_number -0.159824 -0.255779       NaN  1.833801e-01 -0.000126     NaN
# age         -0.098960  0.283433       NaN -1.313456e-01  0.558327     NaN
# Apps        -0.067607 -0.004077       NaN  8.287637e-02 -0.339235     NaN
# Mins        -0.079671 -0.029412       NaN  8.441160e-02 -0.345840     NaN
# Assists     -0.205879  0.628971       NaN -1.723755e-01 -0.073750     NaN
# KeyP         0.047619 -0.054554       NaN -3.996041e-01  0.065795     NaN
# AvgP         0.080688  0.248875       NaN -3.401470e-01  0.483106     NaN
# PS%         -0.111923  0.115758       NaN -5.148685e-01 -0.190441     NaN
# Crosses           NaN       NaN       NaN           NaN       NaN     NaN
# LongB       -0.222010 -0.159161       NaN -1.464869e-01  0.546382     NaN
# ThrB              NaN       NaN       NaN           NaN       NaN     NaN
# Rating      -0.132214  0.006182       NaN -2.033234e-02 -0.003728     NaN
# Goals             NaN       NaN       NaN           NaN       NaN     NaN
# Yel         -0.034080  0.331869       NaN  1.838494e-01 -0.282529     NaN
# Red          0.336123  0.490098       NaN  5.547078e-01  0.182953     NaN
# SpG               NaN       NaN       NaN           NaN       NaN     NaN
# AerialsWon  -0.108359  0.227592       NaN  3.525916e-01  0.016636     NaN
# MoM         -0.314772 -0.240411       NaN  4.644341e-01 -0.211884     NaN
# Dribble     -0.327327 -0.250000       NaN -9.342939e-03  0.301511     NaN
# Fouled       0.355874  0.326164       NaN -1.649318e-16 -0.032781     NaN
# Off               NaN       NaN       NaN           NaN       NaN     NaN
# Disp              NaN       NaN       NaN           NaN       NaN     NaN
# UnsTch      -0.428571 -0.054554       NaN  1.304830e-01  0.285112     NaN
# Tackles      0.285714 -0.054554       NaN  1.712589e-01  0.065795     NaN
# Inter        1.000000  0.218218       NaN -3.262074e-02  0.065795     NaN
# Fouls        0.218218  1.000000       NaN  3.737175e-02  0.301511     NaN
# Offsides          NaN       NaN       NaN           NaN       NaN     NaN
# Clear       -0.032621  0.037372       NaN  1.000000e+00 -0.045072     NaN
# Drb          0.065795  0.301511       NaN -4.507203e-02  1.000000     NaN
# Blocks            NaN       NaN       NaN           NaN       NaN     NaN
# OwnG              NaN       NaN       NaN           NaN       NaN     NaN
# Pts         -0.043837  0.118088       NaN -6.456396e-01 -0.210628     NaN
#
#              OwnG       Pts
# team_number   NaN -0.139850
# age           NaN -0.157578
# Apps          NaN  0.341110
# Mins          NaN  0.338090
# Assists       NaN  0.323276
# KeyP          NaN  0.453770
# AvgP          NaN  0.301362
# PS%           NaN  0.801292
# Crosses       NaN       NaN
# LongB         NaN -0.183129
# ThrB          NaN       NaN
# Rating        NaN  0.521357
# Goals         NaN       NaN
# Yel           NaN  0.321785
# Red           NaN -0.267611
# SpG           NaN       NaN
# AerialsWon    NaN -0.138395
# MoM           NaN -0.038556
# Dribble       NaN -0.173739
# Fouled        NaN  0.233753
# Off           NaN       NaN
# Disp          NaN       NaN
# UnsTch        NaN -0.162315
# Tackles       NaN -0.470357
# Inter         NaN -0.043837
# Fouls         NaN  0.118088
# Offsides      NaN       NaN
# Clear         NaN -0.645640
# Drb           NaN -0.210628
# Blocks        NaN       NaN
# OwnG          NaN       NaN
# Pts           NaN  1.000000
#
# [32 rows x 32 columns]

# %%
# heatmap으로 상관관계 시각화

plt.figure(figsize=(10, 10))
sns.heatmap(L1_GK_corr_matrix)
plt.show()

# %%
# 결과가 nan인 변수 제거

L1_GK_df.drop(['Crosses', 'ThrB', 'Goals', 'SpG', 'Off', 'Disp', 'Offsides', 'Blocks', 'OwnG'], axis=1, inplace=True)

# %%
# 수치형 데이터만 뽑아온다.

L1_GK_numeric_df = L1_GK_df.select_dtypes(['int64', 'float64'])

# %%
L1_GK_corr_matrix = L1_GK_numeric_df.corr()
L1_GK_corr_matrix
# Out:
#              team_number       age      Apps      Mins   Assists      KeyP  \
# team_number     1.000000  0.021390  0.191679  0.201402 -0.150672  0.006271
# age             0.021390  1.000000 -0.168229 -0.181238  0.130732 -0.024740
# Apps            0.191679 -0.168229  1.000000  0.998845  0.052989  0.003558
# Mins            0.201402 -0.181238  0.998845  1.000000  0.037073  0.015333
# Assists        -0.150672  0.130732  0.052989  0.037073  1.000000  0.251630
# KeyP            0.006271 -0.024740  0.003558  0.015333  0.251630  1.000000
# AvgP            0.034215  0.316339  0.000696  0.001780  0.274309  0.605157
# PS%            -0.030228 -0.253431  0.323264  0.320635  0.243441  0.150785
# LongB           0.182498  0.556904 -0.204874 -0.198818 -0.015049  0.241079
# Rating          0.026249 -0.226819  0.192146  0.207441  0.117954  0.423625
# Yel             0.285695 -0.159353  0.455837  0.448497  0.229200 -0.119280
# Red            -0.216428 -0.079377  0.047949  0.036753 -0.132110 -0.275010
# Pts          1.000000

# %%
# 내림차순 정렬 후 heatmap으로 시각화

L1_GK_corr_matrix_Pts.sort_values('Pts', ascending=False, inplace=True)
plt.figure(figsize=(3, 10))
sns.heatmap(L1_GK_corr_matrix_Pts, annot=True, fmt='.3f')
plt.show()
# Out:
# /var/folders/zt/1l6rrzf977nbpmcz1d2j0vd40000gn/T/ipykernel_72451/827887596.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   L1_GK_corr_matrix_Pts.sort_values('Pts', ascending=False, inplace=True)

# %%
# 상위 10개 변수 추출

L1_GK_corr_matrix_Pts.iloc[1:11].index.to_list()
# ['PS%', 'Rating', 'KeyP', 'Mins', 'Assists', 'Yel', 'AvgP', 'Fouled', 'Fouls', 'MoM']
# Out:
# ['PS%',
#  'Rating',
#  'KeyP',
#  'Apps',
#  'Mins',
#  'Assists',
#  'Yel',
#  'AvgP',
#  'Fouled',
#  'Fouls']

# %%
index_li = L1_GK_corr_matrix_Pts.iloc[:11].index.tolist()
corr_li = L1_GK_corr_matrix_Pts['Pts'].tolist()
for i in range(1, 11):
    print(f'{index_li[i]}: {corr_li[i]:.3f}')
    
# PS%: 0.801 Rating: 0.521 KeyP: 0.454 Apps: 0.341 Mins: 0.338 Assists: 0.323 Yel: 0.322 AvgP: 0.301 Fouled: 0.234 Fouls: 0.118
# Out:
# PS%: 0.801
# Rating: 0.521
# KeyP: 0.454
# Apps: 0.341
# Mins: 0.338
# Assists: 0.323
# Yel: 0.322
# AvgP: 0.301
# Fouled: 0.234
# Fouls: 0.118

# %% [markdown]
# # FW 포지션 데이터
# ## FW포지션에서 승리에 가장 큰 영향을 주는 변수 추출

# %%
L1_FW_df = pd.merge(L1_FW_player_df, L1_Team_df[['Team', 'Pts']], on='Team', how='inner')

# %%
L1_FW_df.columns
# Out:
# Index(['player_name', 'team_number', 'Team', 'age', 'position', 'Apps', 'Mins',
#        'Assists', 'KeyP', 'AvgP', 'PS%', 'Crosses', 'LongB', 'ThrB', 'Rating',
#        'Goals', 'Yel', 'Red', 'SpG', 'AerialsWon', 'MoM', 'Dribble', 'Fouled',
#        'Off', 'Disp', 'UnsTch', 'Tackles', 'Inter', 'Fouls', 'Offsides',
#        'Clear', 'Drb', 'Blocks', 'OwnG', 'Pts'],
#       dtype='object')

# %%
# 수치형 데이터만 뽑아온다.

L1_FW_numeric_df = L1_FW_df.select_dtypes(['int64', 'float64'])

# %%
L1_FW_corr_matrix = L1_FW_numeric_df.corr()
L1_FW_corr_matrix
# Out:
#              team_number       age      Apps      Mins   Assists      KeyP  \
# team_number     1.000000  0.154445 -0.023808  0.227310 -0.044272  0.319407
# age             0.154445  1.000000  0.237549  0.033423 -0.335352 -0.098045
# Apps           -0.023808  0.237549  1.000000  0.766972  0.397532  0.367699
# Mins            0.227310  0.033423  0.766972  1.000000  0.297704  0.699855
# Assists        -0.044272 -0.335352  0.397532  0.297704  1.000000  0.162021
# KeyP            0.319407 -0.098045  0.367699  0.699855  0.162021  1.000000
# AvgP            0.340121  0.110684  0.154281  0.536327 -0.043063  0.680391
# PS%            -0.498021 -0.061817 -0.159313 -0.157763  0.285584 -0.082261
# Crosses         0.045771  0.214977  0.284901  0.479420  0.082217  0.573891
# LongB           0.176705 -0.104475  0.343927  0.455559  0.359601  0.495823
# ThrB           -0.274008  0.211259  0.132288  0.086069  0.019477  0.270233
# Rating          0.512025 -0.049962  0.373105  0.747013  0.306365  0.770207
# Goals           0.110900 -0.029317  0.667254  0.840776  0.375043  0.730033
# Yel             0.281770 -0.108899  0.405567  0.611075 -0.074583  0.319880
# Red            -0.167399  0.702759  0.156080  0.173103 -0.259166  0.285719
# SpG             0.493980 -0.137584  0.352225  0.763326  0.267816  0.765494
# AerialsWon      0.746921  0.234832 -0.006424  0.207998 -0.357400  0.083314
# MoM             0.306395 -0.019625  0.509920  0.745632  0.427561  0.531955
# Dribble         0.141719 -0.255647  0.155189  0.397487  0.404261  0.492593
# Fouled          0.308465 -0.239369  0.180352  0.548644  0.098269  0.439065
# Off             0.263437 -0.324328  0.508416  0.792653  0.195548  0.560027
# Disp            0.489888 -0.189755  0.176437  0.537187  0.138936  0.651995
# UnsTch          0.450498 -0.234585  0.102084  0.542594  0.029496  0.478939
# Tackles         0.129329 -0.012245  0.033459  0.281979 -0.104273  0.266957
# Inter          -0.021413  0.015043  0.104578  0.259525  0.148993  0.135772
# Fouls           0.423996 -0.039487  0.230417  0.553264 -0.084386  0.225691
# Offsides             NaN       NaN       NaN       NaN       NaN       NaN
# Clear           0.525058  0.096507  0.382615  0.487820 -0.017795  0.122373
# Drb             0.223310  0.032444  0.171814  0.498896 -0.083753  0.498009
# Blocks          0.608575 -0.060671 -0.464837 -0.132383 -0.260598  0.004764
# OwnG                 NaN       NaN       NaN       NaN       NaN       NaN
# Pts            -0.067300 -0.192595  0.151160  0.057685  0.644154  0.223329
#
#                  AvgP       PS%   Crosses         LongB  ...    UnsTch  \
# team_number  0.340121 -0.498021  0.045771  1.767050e-01  ...  0.450498
# age          0.110684 -0.061817  0.214977 -1.044751e-01  ... -0.234585
# Apps         0.154281 -0.159313  0.284901  3.439269e-01  ...  0.102084
# Mins         0.536327 -0.157763  0.479420  4.555590e-01  ...  0.542594
# Assists     -0.043063  0.285584  0.082217  3.596014e-01  ...  0.029496
# KeyP         0.680391 -0.082261  0.573891  4.958232e-01  ...  0.478939
# AvgP         1.000000  0.147178  0.240935  5.725034e-01  ...  0.528164
# PS%          0.147178  1.000000  0.172173  1.043056e-01  ... -0.150698
# Crosses      0.240935  0.172173  1.000000  1.491080e-01  ...  0.367165
# LongB        0.572503  0.104306  0.149108  1.000000e+00  ...  0.442657
# ThrB         0.365450  0.320985  0.263822  1.648451e-01  ... -0.144412
# Rating       0.627506 -0.253942  0.299545  3.392842e-01  ...  0.511068
# Goals        0.266553 -0.134073  0.587159  2.940158e-01  ...  0.317810
# Yel          0.333810 -0.328569  0.044406  4.716902e-01  ...  0.582553
# Red          0.401242  0.262822  0.553372  7.610050e-17  ... -0.084169
# SpG          0.401634 -0.289092  0.520256  2.479158e-01  ...  0.563510
# AerialsWon   0.354145 -0.663206 -0.304407  2.017310e-02  ...  0.377414
# MoM          0.310873 -0.138686  0.491233  4.146370e-01  ...  0.515857
# Dribble      0.345527  0.225457  0.584916  3.477335e-01  ...  0.590003
# Fouled       0.600422 -0.032301  0.051567  6.089704e-01  ...  0.690557
# Off          0.247762 -0.450647  0.242464  3.213624e-01  ...  0.562678
# Disp         0.565619  0.090783  0.458616  4.841856e-01  ...  0.773414
# UnsTch       0.528164 -0.150698  0.367165  4.426567e-01  ...  1.000000
# Tackles      0.764051  0.078121 -0.133455  4.030383e-01  ...  0.532912
# Inter        0.484358  0.230042  0.147220  3.219577e-01  ...  0.305555
# Fouls        0.397283 -0.471948 -0.066472  3.665809e-01  ...  0.661590
# Offsides          NaN       NaN       NaN           NaN  ...       NaN
# Clear        0.175938 -0.645567 -0.220376  1.807295e-01  ...  0.388687
# Drb          0.618023  0.030721  0.277825  2.632852e-01  ...  0.462740
# Blocks       0.207099 -0.288324 -0.142620 -1.336704e-01  ...  0.244226
# OwnG              NaN       NaN       NaN           NaN  ...       NaN
# Pts          0.055147  0.256410 -0.115560  2.728639e-01  ... -0.119196
#
#               Tackles     Inter     Fouls  Offsides     Clear       Drb  \
# team_number  0.129329 -0.021413  0.423996       NaN  0.525058  0.223310
# age         -0.012245  0.015043 -0.039487       NaN  0.096507  0.032444
# Apps         0.033459  0.104578  0.230417       NaN  0.382615  0.171814
# Mins         0.281979  0.259525  0.553264       NaN  0.487820  0.498896
# Assists     -0.104273  0.148993 -0.084386       NaN -0.017795 -0.083753
# KeyP         0.266957  0.135772  0.225691       NaN  0.122373  0.498009
# AvgP         0.764051  0.484358  0.397283       NaN  0.175938  0.618023
# PS%          0.078121  0.230042 -0.471948       NaN -0.645567  0.030721
# Crosses     -0.133455  0.147220 -0.066472       NaN -0.220376  0.277825
# LongB        0.403038  0.321958  0.366581       NaN  0.180729  0.263285
# ThrB         0.231849  0.020345 -0.162950       NaN -0.456816  0.076787
# Rating       0.339456  0.116279  0.516810       NaN  0.476257  0.322164
# Goals       -0.083242 -0.100714  0.292031       NaN  0.241106  0.206832
# Yel          0.391575  0.251693  0.765147       NaN  0.478644  0.536373
# Red          0.178911  0.242705 -0.206708       NaN -0.272482  0.352322
# SpG          0.057737  0.022948  0.468766       NaN  0.399944  0.321701
# AerialsWon   0.416062  0.067222  0.674677       NaN  0.750658  0.218216
# MoM          0.065065 -0.018608  0.543572       NaN  0.292482  0.158026
# Dribble      0.149660  0.326470  0.076907       NaN -0.008604  0.202473
# Fouled       0.656971  0.309676  0.748364       NaN  0.336733  0.585718
# Off          0.155113  0.115019  0.685789       NaN  0.529880  0.329328
# Disp         0.316174  0.113111  0.355948       NaN  0.206057  0.426914
# UnsTch       0.532912  0.305555  0.661590       NaN  0.388687  0.462740
# Tackles      1.000000  0.615770  0.520836       NaN  0.225304  0.563221
# Inter        0.615770  1.000000  0.243373       NaN  0.066915  0.474911
# Fouls        0.520836  0.243373  1.000000       NaN  0.674323  0.376845
# Offsides          NaN       NaN       NaN       NaN       NaN       NaN
# Clear        0.225304  0.066915  0.674323       NaN  1.000000  0.039287
# Drb          0.563221  0.474911  0.376845       NaN  0.039287  1.000000
# Blocks       0.038455 -0.203466  0.172292       NaN  0.302514 -0.062265
# OwnG              NaN       NaN       NaN       NaN       NaN       NaN
# Pts         -0.041094 -0.214261 -0.121287       NaN -0.193353 -0.225203
#
#                Blocks  OwnG       Pts
# team_number  0.608575   NaN -0.067300
# age         -0.060671   NaN -0.192595
# Apps        -0.464837   NaN  0.151160
# Mins        -0.132383   NaN  0.057685
# Assists     -0.260598   NaN  0.644154
# KeyP         0.004764   NaN  0.223329
# AvgP         0.207099   NaN  0.055147
# PS%         -0.288324   NaN  0.256410
# Crosses     -0.142620   NaN -0.115560
# LongB       -0.133670   NaN  0.272864
# ThrB        -0.202721   NaN  0.237460
# Rating       0.260241   NaN  0.329366
# Goals       -0.183245   NaN  0.286296
# Yel         -0.154970   NaN -0.179159
# Red         -0.170527   NaN -0.136352
# SpG          0.134292   NaN  0.194001
# AerialsWon   0.532688   NaN -0.241633
# MoM          0.030903   NaN  0.290863
# Dribble      0.113271   NaN  0.100747
# Fouled       0.037560   NaN -0.019237
# Off         -0.108680   NaN  0.064701
# Disp         0.131138   NaN  0.081284
# UnsTch       0.244226   NaN -0.119196
# Tackles      0.038455   NaN -0.041094
# Inter       -0.203466   NaN -0.214261
# Fouls        0.172292   NaN -0.121287
# Offsides          NaN   NaN       NaN
# Clear        0.302514   NaN -0.193353
# Drb         -0.062265   NaN -0.225203
# Blocks       1.000000   NaN -0.257863
# OwnG              NaN   NaN       NaN
# Pts         -0.257863   NaN  1.000000
#
# [32 rows x 32 columns]

# %%
# heatmap으로 상관관계 시각화

plt.figure(figsize=(10, 10))
sns.heatmap(L1_FW_corr_matrix)
plt.show()

# %%
# 결과가 nan인 변수 제거

L1_FW_df.drop(['Offsides', 'OwnG'], axis=1, inplace=True)

# %%
# 수치형 데이터만 뽑아온다.

L1_FW_numeric_df = L1_FW_df.select_dtypes(['int64', 'float64'])

# %%
L1_FW_corr_matrix = L1_FW_numeric_df.corr()
L1_FW_corr_matrix
# Out:
#              team_number       age      Apps      Mins   Assists      KeyP  \
# team_number     1.000000  0.154445 -0.023808  0.227310 -0.044272  0.319407
# age             0.154445  1.000000  0.237549  0.033423 -0.335352 -0.098045
# Apps           -0.023808  0.237549  1.000000  0.766972  0.397532  0.367699
# Mins            0.227310  0.033423  0.766972  1.000000  0.297704  0.699855
# Assists        -0.044272 -0.335352  0.397532  0.297704  1.000000  0.162021
# KeyP            0.319407 -0.098045  0.367699  0.699855  0.162021  1.000000
# AvgP            0.340121  0.110684  0.154281  0.536327 -0.043063  0.680391
# PS%            -0.498021 -0.061817 -0.159313 -0.157763  0.285584 -0.082261
# Crosses         0.045771  0.214977  0.284901  0.479420  0.082217  0.573891
# LongB           0.176705 -0.104475  0.343927  0.455559  0.359601  0.495823
# ThrB           -0.274008  0.211259  0.132288  0.086069  0.019477  0.270233
# Rating          0.512025 -0.049962  0.373105  0.747013  0.306365  0.770207
# Goals           0.110900 -0.029317  0.667254  0.840776  0.375043  0.730033
# Yel             0.281770 -0.108899  0.405567  0.611075 -0.074583  0.319880
# Red            -0.167399  0.702759  0.156080  0.173103 -0.259166  0.285719
# SpG             0.493980 -0.137584  0.352225  0.763326  0.267816  0.765494
# AerialsWon      0.746921  0.234832 -0.006424  0.207998 -0.357400  0.083314
# MoM             0.306395 -0.019625  0.509920  0.745632  0.427561  0.531955
# Dribble         0.141719 -0.255647  0.155189  0.397487  0.404261  0.492593
# Fouled          0.308465 -0.239369  0.180352  0.548644  0.098269  0.439065
# Off             0.263437 -0.324328  0.508416  0.792653  0.195548  0.560027
# Disp            0.489888 -0.189755  0.176437  0.537187  0.138936  0.651995
# UnsTch          0.450498 -0.234585  0.102084  0.542594  0.029496  0.478939
# Tackles         0.129329 -0.012245  0.033459  0.281979 -0.104273  0.266957
# Inter          -0.021413  0.015043  0.104578  0.259525  0.148993  0.135772
# Fouls           0.423996 -0.039487  0.230417  0.553264 -0.084386  0.225691
# Clear           0.525058  0.096507  0.382615  0.487820 -0.017795  0.122373
# Drb             0.223310  0.032444  0.171814  0.498896 -0.083753  0.498009
# Blocks          0.608575 -0.060671 -0.464837 -0.132383 -0.260598  0.004764
# Pts            -0.067300 -0.192595  0.151160  0.057685  0.644154  0.223329
#
#                  AvgP       PS%   Crosses         LongB  ...       Off  \
# team_number  0.340121 -0.498021  0.045771  1.767050e-01  ...  0.263437
# age          0.110684 -0.061817  0.214977 -1.044751e-01  ... -0.324328
# Apps         0.154281 -0.159313  0.284901  3.439269e-01  ...  0.508416
# Mins         0.536327 -0.157763  0.479420  4.555590e-01  ...  0.792653
# SpG          0.633166  0.563510  0.057737  0.022948  0.468766  0.399944
# AerialsWon   0.187568  0.377414  0.416062  0.067222  0.674677  0.750658
# MoM          0.476743  0.515857  0.065065 -0.018608  0.543572  0.292482
# Dribble      0.604577  0.590003  0.149660  0.326470  0.076907 -0.008604
# Fouled       0.587564  0.690557  0.656971  0.309676  0.748364  0.336733
# Off          0.449904  0.562678  0.155113  0.115019  0.685789  0.529880
# Disp         1.000000  0.773414  0.316174  0.113111  0.355948  0.206057
# UnsTch       0.773414  1.000000  0.532912  0.305555  0.661590  0.388687
# Tackles      0.316174  0.532912  1.000000  0.615770  0.520836  0.225304
# Inter        0.113111  0.305555  0.615770  1.000000  0.243373  0.066915
# Fouls        0.355948  0.661590  0.520836  0.243373  1.000000  0.674323
# Clear        0.206057  0.388687  0.225304  0.066915  0.674323  1.000000
# Drb          0.426914  0.462740  0.563221  0.474911  0.376845  0.039287
# Blocks       0.131138  0.244226  0.038455 -0.203466  0.172292  0.302514
# Pts          0.081284 -0.119196 -0.041094 -0.214261 -0.121287 -0.193353
#
#                   Drb    Blocks       Pts
# team_number  0.223310  0.608575 -0.067300
# age          0.032444 -0.060671 -0.192595
# Apps         0.171814 -0.464837  0.151160
# Mins         0.498896 -0.132383  0.057685
# Assists     -0.083753 -0.260598  0.644154
# KeyP         0.498009  0.004764  0.223329
# AvgP         0.618023  0.207099  0.055147
# PS%          0.030721 -0.288324  0.256410
# Crosses      0.277825 -0.142620 -0.115560
# LongB        0.263285 -0.133670  0.272864
# ThrB         0.076787 -0.202721  0.237460
# Rating       0.322164  0.260241  0.329366
# Goals        0.206832 -0.183245  0.286296
# Yel          0.536373 -0.154970 -0.179159
# Red          0.352322 -0.170527 -0.136352
# SpG          0.321701  0.134292  0.194001
# AerialsWon   0.218216  0.532688 -0.241633
# MoM          0.158026  0.030903  0.290863
# Dribble      0.202473  0.113271  0.100747
# Fouled       0.585718  0.037560 -0.019237
# Off          0.329328 -0.108680  0.064701
# Disp         0.426914  0.131138  0.081284
# UnsTch       0.462740  0.244226 -0.119196
# Tackles      0.563221  0.038455 -0.041094
# Inter        0.474911 -0.203466 -0.214261
# Fouls        0.376845  0.172292 -0.121287
# Clear        0.039287  0.302514 -0.193353
# Drb          1.000000 -0.062265 -0.225203
# Blocks      -0.062265  1.000000 -0.257863
# Pts         -0.225203 -0.257863  1.000000
#
# [30 rows x 30 columns]

# %%
# heatmap으로 상관관계 시각화

plt.figure(figsize=(10, 10))
sns.heatmap(L1_FW_corr_matrix)
plt.show()

# %%
# Pts부분만 뽑아서 상관관계 확인

L1_FW_corr_matrix_Pts = L1_FW_corr_matrix[['Pts']]
L1_FW_corr_matrix_Pts
# Out:
#                   Pts
# team_number -0.067300
# age         -0.192595
# Apps         0.151160
# Mins         0.057685
# Assists      0.644154
# KeyP         0.223329
# AvgP         0.055147
# PS%          0.256410
# Crosses     -0.115560
# LongB        0.272864
# ThrB         0.237460
# Rating       0.329366
# Goals        0.286296
# Yel         -0.179159
# Red         -0.136352
# SpG          0.194001
# AerialsWon  -0.241633
# MoM          0.290863
# Dribble      0.100747
# Fouled      -0.019237
# Off          0.064701
# Disp         0.081284
# UnsTch      -0.119196
# Tackles     -0.041094
# Inter       -0.214261
# Fouls       -0.121287
# Clear       -0.193353
# Drb         -0.225203
# Blocks      -0.257863
# Pts          1.000000

# %%
# 내림차순 정렬 후 heatmap으로 시각화

L1_FW_corr_matrix_Pts.sort_values('Pts', ascending=False, inplace=True)
plt.figure(figsize=(3, 10))
sns.heatmap(L1_FW_corr_matrix_Pts, annot=True, fmt='.3f')
plt.show()
# Out:
# /var/folders/zt/1l6rrzf977nbpmcz1d2j0vd40000gn/T/ipykernel_72451/1278398350.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   L1_FW_corr_matrix_Pts.sort_values('Pts', ascending=False, inplace=True)

# %%
# 상위 10개 변수 추출

L1_FW_corr_matrix_Pts.iloc[1:11].index.to_list()
# ['Assists', 'Rating', 'MoM', 'Goals', 'LongB', 'PS%', 'ThrB', 'KeyP', 'SpG', 'Dribble']
# Out:
# ['Assists',
#  'Rating',
#  'MoM',
#  'Goals',
#  'LongB',
#  'PS%',
#  'ThrB',
#  'KeyP',
#  'SpG',
#  'Apps']

# %%
index_li = L1_FW_corr_matrix_Pts.iloc[:11].index.tolist()
corr_li = L1_FW_corr_matrix_Pts['Pts'].tolist()
for i in range(1, 11):
    print(f'{index_li[i]}: {corr_li[i]:.3f}')
    
# Assists: 0.644 Rating: 0.329 MoM: 0.291 Goals: 0.286 LongB: 0.273 PS%: 0.256 ThrB: 0.237 KeyP: 0.223 SpG: 0.194 Apps: 0.151
# Out:
# Assists: 0.644
# Rating: 0.329
# MoM: 0.291
# Goals: 0.286
# LongB: 0.273
# PS%: 0.256
# ThrB: 0.237
# KeyP: 0.223
# SpG: 0.194
# Apps: 0.151

# %% [markdown]
# # AM 포지션 데이터
# ## AM포지션에서 승리에 가장 큰 영향을 주는 변수 추출

# %%
L1_AM_player_df.head()
# Out:
#       player_name  team_number                 Team  age position  Apps  Mins  \
# 0    Lionel Messi          304  Paris Saint-Germain   36       AM    32  2842
# 1   Kylian Mbappé          304  Paris Saint-Germain   24       AM    34  2822
# 2          Neymar          304  Paris Saint-Germain   31       AM    20  1553
# 3  Jonathan David          607                Lille   23       AM    37  3179
# 4    Amine Gouiri          313               Rennes   23       AM    33  2532
#
#    Assists  KeyP  AvgP  ...  Disp  UnsTch  Tackles  Inter  Fouls  Offsides  \
# 0       16   2.9  60.3  ...   2.4     1.6      0.8    0.1    0.3       0.0
# 1        5   1.6  37.9  ...   1.2     1.9      0.3    0.1    0.6       0.0
# 2       11   2.5  59.4  ...   1.9     2.5      1.1    0.2    1.3       0.0
# 3        4   1.4  23.2  ...   1.4     2.4      0.6    0.2    1.1       0.0
# 4        3   1.1  22.1  ...   1.1     2.2      1.3    0.4    1.2       0.0
#
#    Clear  Drb  Blocks  OwnG
# 0    0.0  0.5     0.0     0
# 1    0.1  0.3     0.0     0
# 2    0.1  0.5     0.1     0
# 3    0.3  0.5     0.1     0
# 4    0.3  0.6     0.0     0
#
# [5 rows x 34 columns]

# %%
L1_AM_df = pd.merge(L1_AM_player_df, L1_Team_df[['Team', 'Pts']], on='Team', how='inner')

# %%
L1_AM_df.columns
# Out:
# Index(['player_name', 'team_number', 'Team', 'age', 'position', 'Apps', 'Mins',
#        'Assists', 'KeyP', 'AvgP', 'PS%', 'Crosses', 'LongB', 'ThrB', 'Rating',
#        'Goals', 'Yel', 'Red', 'SpG', 'AerialsWon', 'MoM', 'Dribble', 'Fouled',
#        'Off', 'Disp', 'UnsTch', 'Tackles', 'Inter', 'Fouls', 'Offsides',
#        'Clear', 'Drb', 'Blocks', 'OwnG', 'Pts'],
#       dtype='object')

# %%
# 수치형 데이터만 뽑아온다.

L1_AM_numeric_df = L1_AM_df.select_dtypes(['int64', 'float64'])

# %%
L1_AM_corr_matrix = L1_AM_numeric_df.corr()
L1_AM_corr_matrix
# Out:
#              team_number       age      Apps      Mins   Assists      KeyP  \
# team_number     1.000000  0.068271  0.006024  0.028383  0.041670  0.051118
# age             0.068271  1.000000 -0.003935  0.182326  0.179538  0.271661
# Apps            0.006024 -0.003935  1.000000  0.745308  0.117272 -0.045947
# Mins            0.028383  0.182326  0.745308  1.000000  0.415034  0.384851
# Assists         0.041670  0.179538  0.117272  0.415034  1.000000  0.724583
# KeyP            0.051118  0.271661 -0.045947  0.384851  0.724583  1.000000
# AvgP           -0.053841  0.268639 -0.061642  0.383926  0.684295  0.846126
# PS%            -0.096928 -0.143335 -0.297224 -0.149507  0.137980  0.344202
# Crosses         0.262617  0.195693 -0.227056  0.046325  0.414197  0.734354
# LongB          -0.081466  0.199739 -0.116486  0.136278  0.409873  0.647607
# ThrB           -0.055271  0.377656  0.013758  0.308594  0.743683  0.737687
# Offsides    -0.087321  0.313922  1.000000  0.077089 -0.174937  0.173199
# Clear        0.262319  0.349612  0.077089  1.000000  0.193458  0.371806
# Drb          0.618386  0.229513 -0.174937  0.193458  1.000000  0.183299
# Blocks       0.182124  0.256871  0.173199  0.371806  0.183299  1.000000
# OwnG        -0.139883  0.052922 -0.016393  0.140816 -0.089535 -0.082476
# Pts         -0.229916 -0.020647  0.094247 -0.485157 -0.268496 -0.034723
#
#                  OwnG       Pts
# team_number  0.040802 -0.078887
# age         -0.099187  0.054706
# Apps         0.108364 -0.268563
# Mins         0.023120 -0.081676
# Assists     -0.100617  0.414261
# KeyP        -0.108925  0.363198
# AvgP        -0.128134  0.337329
# PS%         -0.043036  0.390038
# Crosses     -0.101082  0.087964
# LongB       -0.118359  0.052952
# ThrB        -0.060068  0.364282
# Rating      -0.121412  0.532231
# Goals       -0.020994  0.324036
# Yel         -0.153925  0.175119
# Red         -0.053812 -0.191082
# SpG         -0.054223  0.381330
# AerialsWon   0.143060 -0.381884
# MoM         -0.094084  0.367391
# Dribble     -0.093865  0.389738
# Fouled      -0.065405  0.120370
# Off          0.113851  0.114523
# Disp        -0.024986  0.273132
# UnsTch       0.046941 -0.022831
# Tackles     -0.088280 -0.211193
# Inter       -0.139883 -0.229916
# Fouls        0.052922 -0.020647
# Offsides    -0.016393  0.094247
# Clear        0.140816 -0.485157
# Drb         -0.089535 -0.268496
# Blocks      -0.082476 -0.034723
# OwnG         1.000000 -0.259210
# Pts         -0.259210  1.000000
#
# [32 rows x 32 columns]

# %%
# 결과가 nan인 변수 제거

L1_AM_df.drop('OwnG', axis=1, inplace=True)

# %%
# 수치형 데이터만 뽑아온다.

L1_AM_numeric_df = L1_AM_df.select_dtypes(['int64', 'float64'])

# %%
L1_AM_corr_matrix = L1_AM_numeric_df.corr()
L1_AM_corr_matrix
# Out:
#              team_number       age      Apps      Mins   Assists      KeyP  \
# team_number     1.000000  0.068271  0.006024  0.028383  0.041670  0.051118
# age             0.068271  1.000000 -0.003935  0.182326  0.179538  0.271661
# Apps            0.006024 -0.003935  1.000000  0.745308  0.117272 -0.045947
# Mins            0.028383  0.182326  0.745308  1.000000  0.415034  0.384851
# Assists         0.041670  0.179538  0.117272  0.415034  1.000000  0.724583
# KeyP            0.051118  0.271661 -0.045947  0.384851  0.724583  1.000000
# AvgP           -0.053841  0.268639 -0.061642  0.383926  0.684295  0.846126
# PS%            -0.096928 -0.143335 -0.297224 -0.149507  0.137980  0.344202
# Crosses         0.262617  0.195693 -0.227056  0.046325  0.414197  0.734354
# LongB          -0.081466  0.199739 -0.116486  0.136278  0.409873  0.647607
# ThrB           -0.055271  0.377656  0.013758  0.308594  0.743683  0.737687
# Rating         -0.023121  0.242380  0.063311  0.514421  0.758404  0.805377
# Goals          -0.035028  0.170224  0.402697  0.682505  0.402303  0.318846
# Yel            -0.100334  0.037678  0.285715  0.488992  0.206448  0.140347
# Red            -0.104911  0.261280  0.123563  0.091538 -0.046070 -0.084417
# SpG             0.001050  0.260145  0.202086  0.621275  0.523154  0.585631
# AerialsWon      0.098627  0.185162  0.292921  0.297140 -0.190410 -0.263009
# AvgP         0.073101  0.337329
# PS%         -0.103728  0.390038
# Crosses     -0.091239  0.087964
# LongB        0.001895  0.052952
# ThrB        -0.009444  0.364282
# Rating       0.037594  0.532231
# Goals        0.153153  0.324036
# Yel          0.264683  0.175119
# Red          0.034457 -0.191082
# SpG          0.043262  0.381330
# AerialsWon   0.207997 -0.381884
# MoM         -0.033134  0.367391
# Dribble     -0.267387  0.389738
# Fouled       0.172032  0.120370
# Off          0.069689  0.114523
# Disp        -0.053542  0.273132
# UnsTch       0.160022 -0.022831
# Tackles      0.089576 -0.211193
# Inter        0.182124 -0.229916
# Fouls        0.256871 -0.020647
# Offsides     0.173199  0.094247
# Clear        0.371806 -0.485157
# Drb          0.183299 -0.268496
# Blocks       1.000000 -0.034723
# Pts         -0.034723  1.000000
#
# [31 rows x 31 columns]

# %%
# heatmap으로 상관관계 시각화

plt.figure(figsize=(10, 10))
sns.heatmap(L1_AM_corr_matrix)
plt.show()

# %%
# Pts부분만 뽑아서 상관관계 확인

L1_AM_corr_matrix_Pts = L1_AM_corr_matrix[['Pts']]
L1_AM_corr_matrix_Pts
# Out:
#                   Pts
# team_number -0.078887
# age          0.054706
# Apps        -0.268563
# Mins        -0.081676
# Assists      0.414261
# KeyP         0.363198
# AvgP         0.337329
# PS%          0.390038
# Crosses      0.087964
# LongB        0.052952
# ThrB         0.364282
# Rating       0.532231
# Goals        0.324036
# Yel          0.175119
# Red         -0.191082
# SpG          0.381330
# AerialsWon  -0.381884
# MoM          0.367391
# Dribble      0.389738
# Fouled       0.120370
# Off          0.114523
# Disp         0.273132
# UnsTch      -0.022831
# Tackles     -0.211193
# Inter       -0.229916
# Fouls       -0.020647
# Offsides     0.094247
# Clear       -0.485157
# Drb         -0.268496
# Blocks      -0.034723
# Pts          1.000000

# %%
# 내림차순 정렬 후 heatmap으로 시각화
# 전체적으로 Pts와의 상관관계가 조금 낮은 상태..

L1_AM_corr_matrix_Pts.sort_values('Pts', ascending=False, inplace=True)
plt.figure(figsize=(3, 10))
sns.heatmap(L1_AM_corr_matrix_Pts, annot=True, fmt='.3f')
plt.show()
# Out:
# /var/folders/zt/1l6rrzf977nbpmcz1d2j0vd40000gn/T/ipykernel_72451/2085341670.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   L1_AM_corr_matrix_Pts.sort_values('Pts', ascending=False, inplace=True)

# %%
# 상위 10개 변수 추출

L1_AM_corr_matrix_Pts.iloc[1:11].index.to_list()
# ['Rating', 'Assists', 'PS%', 'Dribble', 'SpG', 'MoM', 'ThrB', 'KeyP', 'AvgP', 'Goals']
# Out:
# ['Rating',
#  'Assists',
#  'PS%',
#  'Dribble',
#  'SpG',
#  'MoM',
#  'ThrB',
#  'KeyP',
#  'AvgP',
#  'Goals']

# %%
index_li = L1_AM_corr_matrix_Pts.iloc[:11].index.tolist()
corr_li = L1_AM_corr_matrix_Pts['Pts'].tolist()
for i in range(1, 11):
    print(f'{index_li[i]}: {corr_li[i]:.3f}')
    
# Rating: 0.532 Assists: 0.414 PS%: 0.390 Dribble: 0.390 SpG: 0.381 MoM: 0.367 ThrB: 0.364 KeyP: 0.363 AvgP: 0.337 Goals: 0.324
# Out:
# Rating: 0.532
# Assists: 0.414
# PS%: 0.390
# Dribble: 0.390
# SpG: 0.381
# MoM: 0.367
# ThrB: 0.364
# KeyP: 0.363
# AvgP: 0.337
# Goals: 0.324

# %% [markdown]
# # M 포지션 데이터
# ## M포지션에서 승리에 가장 큰 영향을 주는 변수 추출

# %%
L1_M_player_df.head()
# Out:
#            player_name  team_number         Team  age position  Apps  Mins  \
# 0  Alexandre Lacazette          228         Lyon   32        M    35  2938
# 1         Rémy Cabella          607        Lille   33        M    32  2535
# 2        Téji Savanier          311  Montpellier   31        M    30  2557
# 3          Enzo Le Fée          146      Lorient   23        M    35  3039
# 4  Benjamin Bourigeaud          313       Rennes   29        M    37  3084
#
#    Assists  KeyP  AvgP  ...  Disp  UnsTch  Tackles  Inter  Fouls  Offsides  \
# 0        5   1.4  24.9  ...   1.3     1.9      1.2    0.4    1.8       0.0
# 1       10   3.2  49.1  ...   1.1     1.5      2.0    0.5    0.8       0.0
# 2        4   1.9  47.3  ...   1.7     2.4      1.5    1.0    1.9       0.0
# 3        5   1.9  56.1  ...   1.6     2.1      3.1    1.0    1.2       0.0
# 4       10   2.6  46.6  ...   0.5     0.9      1.2    0.8    0.9       0.1
#
#    Clear  Drb  Blocks  OwnG
# 0    0.1  0.5     0.1     0
# 1    0.2  1.1     0.2     0
# 2    0.4  1.6     0.1     0
# 3    0.9  2.0     0.1     0
# 4    0.7  1.2     0.1     0
#
# [5 rows x 34 columns]

# %%
L1_M_df = pd.merge(L1_M_player_df, L1_Team_df[['Team', 'Pts']], on='Team', how='inner')

# %%
L1_M_df.columns
# Out:
# Index(['player_name', 'team_number', 'Team', 'age', 'position', 'Apps', 'Mins',
#        'Assists', 'KeyP', 'AvgP', 'PS%', 'Crosses', 'LongB', 'ThrB', 'Rating',
#        'Goals', 'Yel', 'Red', 'SpG', 'AerialsWon', 'MoM', 'Dribble', 'Fouled',
#        'Off', 'Disp', 'UnsTch', 'Tackles', 'Inter', 'Fouls', 'Offsides',
#        'Clear', 'Drb', 'Blocks', 'OwnG', 'Pts'],
#       dtype='object')

# %%
# 수치형 데이터만 뽑아온다.

L1_M_numeric_df = L1_M_df.select_dtypes(['int64', 'float64'])

# %%
L1_M_corr_matrix = L1_M_numeric_df.corr()
L1_M_corr_matrix
# Out:
#              team_number       age      Apps      Mins   Assists      KeyP  \
# team_number     1.000000  0.017330 -0.084780 -0.004993  0.045109  0.055119
# age             0.017330  1.000000 -0.175936 -0.070491 -0.080998  0.122043
# Apps           -0.084780 -0.175936  1.000000  0.863366  0.517724  0.387170
# Mins           -0.004993 -0.070491  0.863366  1.000000  0.618858  0.514823
# Assists         0.045109 -0.080998  0.517724  0.618858  1.000000  0.776942
# KeyP            0.055119  0.122043  0.387170  0.514823  0.776942  1.000000
# AvgP           -0.111705 -0.036755  0.374580  0.592469  0.231374  0.243767
# PS%            -0.254435 -0.254978  0.143078  0.186073 -0.065486 -0.169925
# Crosses         0.176145  0.113526  0.211779  0.295960  0.589092  0.830153
# LongB           0.058433  0.183300  0.280884  0.489492  0.172308  0.142396
# ThrB           -0.164762  0.137729  0.359322  0.464668  0.530067  0.440794
# Rating         -0.029728 -0.068249  0.515817  0.726965  0.759930  0.752943
# Goals          -0.062553  0.136096  0.374170  0.455526  0.508188  0.496779
# Yel             0.082072 -0.087910  0.469736  0.592033  0.219858  0.097479
# Red             0.056051  0.252546 -0.040059  0.107219  0.081648  0.128933
# SpG            -0.029924  0.014702  0.422928  0.541171  0.645320  0.560563
# AerialsWon      0.024055  0.215019  0.162507  0.280261  0.166278  0.088874
# MoM            -0.030456  0.063432  0.491326  0.619403  0.705319  0.737082
# Dribble        -0.150988 -0.138929  0.152311  0.393044  0.287762  0.367478
# Fouled          0.005081  0.024891  0.300344  0.520779  0.303307  0.323946
# Off            -0.084078  0.248034  0.174969  0.191877  0.202755  0.312578
# Disp           -0.073049 -0.037189  0.280416  0.471958  0.294371  0.403234
# UnsTch          0.018024 -0.000079  0.219082  0.454698  0.423085  0.490168
# Tackles         0.112619 -0.190926  0.301967  0.530299  0.220782  0.222427
# Inter           0.199127 -0.146685  0.316624  0.452861  0.124047  0.074452
# Fouls           0.011318  0.005574  0.242770  0.481441  0.251055  0.230255
# Offsides        0.011286 -0.132291  0.235911  0.167046  0.108907 -0.015067
# Clear           0.151728 -0.020630  0.185585  0.384467  0.107670 -0.045342
# Drb             0.118114 -0.132553  0.196269  0.402134  0.171154  0.130537
# Blocks          0.176929 -0.061195  0.207319  0.300304  0.114375 -0.006437
# OwnG           -0.100169 -0.063201  0.209781  0.136339  0.052259 -0.069672
# Pts            -0.247060 -0.259285  0.169731  0.108541  0.238623  0.103367
corr_matrix_Pts
# Out:
#                   Pts
# team_number -0.247060
# age         -0.259285
# Apps         0.169731
# Mins         0.108541
# Assists      0.238623
# KeyP         0.103367
# AvgP         0.258636
# PS%          0.428046
# Crosses     -0.181349
# LongB       -0.106946
# ThrB         0.192957
# Rating       0.359548
# Goals        0.229387
# Yel         -0.077495
# Red         -0.178614
# SpG          0.166751
# AerialsWon  -0.102011
# MoM          0.149562
# Dribble     -0.080625
# Fouled      -0.009972
# Off          0.194177
# Disp        -0.021211
# UnsTch      -0.126971
# Tackles     -0.035590
# Inter       -0.228357
# Fouls        0.086145
# Offsides     0.130032
# Clear        0.002775
# Drb          0.049000
# Blocks      -0.006484
# OwnG         0.165747
# Pts          1.000000

# %%
# 내림차순 정렬 후 heatmap으로 시각화
# 전체적으로 Pts와의 상관관계가 조금 낮은 상태..

L1_M_corr_matrix_Pts.sort_values('Pts', ascending=False, inplace=True)
plt.figure(figsize=(3, 10))
sns.heatmap(L1_M_corr_matrix_Pts, annot=True, fmt='.3f')
plt.show()
# Out:
# /var/folders/zt/1l6rrzf977nbpmcz1d2j0vd40000gn/T/ipykernel_72451/2458765789.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   L1_M_corr_matrix_Pts.sort_values('Pts', ascending=False, inplace=True)

# %%
# 상위 5개 변수 추출

L1_M_corr_matrix_Pts.iloc[1:11].index.to_list()
# ['PS%', 'Rating', 'AvgP', 'Assists', 'Goals', 'Off', 'ThrB', 'SpG', 'OwnG', 'MoM']
# Out:
# ['PS%',
#  'Rating',
#  'AvgP',
#  'Assists',
#  'Goals',
#  'Off',
#  'ThrB',
#  'Apps',
#  'SpG',
#  'OwnG']

# %%
index_li = L1_M_corr_matrix_Pts.iloc[:11].index.tolist()
corr_li = L1_M_corr_matrix_Pts['Pts'].tolist()
for i in range(1, 11):
    print(f'{index_li[i]}: {corr_li[i]:.3f}')
    
# PS%: 0.428 Rating: 0.360 AvgP: 0.259 Assists: 0.239 Goals: 0.229 Off: 0.194 ThrB: 0.193 Apps: 0.170 SpG: 0.167 OwnG: 0.166
# Out:
# PS%: 0.428
# Rating: 0.360
# AvgP: 0.259
# Assists: 0.239
# Goals: 0.229
# Off: 0.194
# ThrB: 0.193
# Apps: 0.170
# SpG: 0.167
# OwnG: 0.166

# %% [markdown]
# # DM 포지션 데이터
# ## DM포지션에서 승리에 가장 큰 영향을 주는 변수 추출

# %%
L1_DM_player_df.head()
# Out:
#              player_name  team_number      Team  age position  Apps  Mins  \
# 0  Branco van den Boomen          246  Toulouse   27       DM    35  2893
# 1       Maxence Caqueret          228      Lyon   23       DM    36  2778
# 2        Khéphren Thuram          613      Nice   22       DM    35  2560
# 3          Azor Matusiwa          950     Reims   25       DM    30  2492
# 4        Youssouf Fofana          248    Monaco   24       DM    36  3089
#
#    Assists  KeyP  AvgP  ...  Disp  UnsTch  Tackles  Inter  Fouls  Offsides  \
# 0        8   2.5  54.2  ...   0.3     0.9      2.0    0.3    0.9       0.0
# 1        7   1.7  46.5  ...   1.3     1.9      2.4    1.1    1.3       0.0
# 2        4   1.0  37.7  ...   1.0     0.9      1.5    1.1    0.9       0.0
# 3        0   0.8  53.3  ...   0.4     0.8      2.2    1.5    1.4       0.0
# 4        2   0.9  47.7  ...   1.1     1.3      2.3    1.6    1.4       0.0
#
#    Clear  Drb  Blocks  OwnG
# 0    0.7  1.5     0.1     0
# 1    0.8  1.8     0.1     0
# 2    0.9  0.7     0.4     0
# 3    1.6  0.8     0.4     0
# 4    0.9  1.0     0.2     1
#
# [5 rows x 34 columns]

# %%
L1_DM_df = pd.merge(L1_DM_player_df, L1_Team_df[['Team', 'Pts']], on='Team', how='inner')

# %%
L1_DM_df.columns
# Out:
# Index(['player_name', 'team_number', 'Team', 'age', 'position', 'Apps', 'Mins',
#        'Assists', 'KeyP', 'AvgP', 'PS%', 'Crosses', 'LongB', 'ThrB', 'Rating',
#        'Goals', 'Yel', 'Red', 'SpG', 'AerialsWon', 'MoM', 'Dribble', 'Fouled',
#        'Off', 'Disp', 'UnsTch', 'Tackles', 'Inter', 'Fouls', 'Offsides',
#        'Clear', 'Drb', 'Blocks', 'OwnG', 'Pts'],
#       dtype='object')

# %%
# 수치형 데이터만 뽑아온다.

L1_DM_numeric_df = L1_DM_df.select_dtypes(['int64', 'float64'])

# %%
L1_DM_corr_matrix = L1_DM_numeric_df.corr()
L1_DM_corr_matrix
# Out:
#              team_number       age      Apps      Mins       Assists  \
# team_number     1.000000  0.123637  0.268169  0.041541 -1.644575e-01
# age             0.123637  1.000000  0.372864  0.483217 -5.058266e-02
# Apps            0.268169  0.372864  1.000000  0.853210  4.001110e-01
# Mins            0.041541  0.483217  0.853210  1.000000  3.816115e-01
# Assists        -0.164458 -0.050583  0.400111  0.381612  1.000000e+00
# KeyP           -0.120270  0.132253  0.416408  0.498328  8.242066e-01
# AvgP           -0.122041  0.450051  0.395645  0.758290  2.905200e-01
# PS%            -0.007168 -0.124159 -0.049339  0.162923  1.611130e-15
# Crosses        -0.058803  0.214249  0.311597  0.347000  7.573679e-01
# LongB          -0.051868  0.426642  0.196888  0.488798  3.572400e-01
# ThrB           -0.351687  0.188293  0.350477  0.495207  5.447360e-01
# Rating         -0.148245  0.265222  0.525895  0.748721  6.028789e-01
# Goals           0.018754  0.510010  0.476807  0.448508  5.093448e-01
# Yel            -0.061249  0.217544  0.166247  0.166928  2.441756e-02
# Red            -0.109604 -0.316360 -0.134980 -0.179450 -1.258741e-01
# SpG            -0.174796  0.166031  0.346852  0.400227  4.605483e-01
# AerialsWon     -0.120020  0.246478  0.022607  0.133138 -3.688500e-01
# MoM            -0.155291  0.263178  0.243136  0.332297  6.512392e-01
# Dribble        -0.059318 -0.241786  0.237559  0.274491  2.262903e-01
# Fouled          0.228056  0.084803  0.223801  0.302951 -1.299949e-01
# Off            -0.169481 -0.011818  0.420586  0.331137  5.633218e-01
# Disp           -0.024934 -0.280434  0.240330  0.268117  1.953085e-01
# UnsTch         -0.067673  0.099546  0.461594  0.479174  3.116359e-01
# Tackles        -0.038816  0.381735  0.530366  0.606925  2.470196e-01
# Inter           0.054980  0.464686  0.553065  0.707878 -7.704894e-02
# Fouls          -0.297252 -0.023640  0.325337  0.387572 -6.498188e-02
# Offsides        0.367249  0.043889  0.143341  0.022862  3.602268e-02
# Clear          -0.155855  0.290205  0.300024  0.462511 -3.600180e-03
# Drb             0.095985  0.551680  0.495037  0.550285  3.874134e-01
# Blocks         -0.093017 -0.069138  0.169391  0.312679 -1.066983e-01
# OwnG           -0.129727 -0.089172  0.225499  0.347835 -2.928998e-02
# Pts            -0.142173 -0.438532 -0.346914 -0.233745 -4.383268e-02
#
#                  KeyP      AvgP           PS%   Crosses     LongB  ...  \
# team_number -0.120270 -0.122041 -7.167705e-03 -0.058803 -0.051868  ...
# age          0.132253  0.450051 -1.241586e-01  0.214249  0.426642  ...
# Apps         0.416408  0.395645 -4.933863e-02  0.311597  0.196888  ...
# Mins         0.498328  0.758290  1.629227e-01  0.347000  0.488798  ...
# Assists      0.824207  0.290520  1.611130e-15  0.757368  0.357240  ...
# KeyP         1.000000  0.527220  7.258855e-03  0.848091  0.615218  ...
# AvgP         0.527220  1.000000  4.083710e-01  0.345825  0.715286  ...
# PS%          0.007259  0.408371  1.000000e+00 -0.108129 -0.012181  ...
# Crosses      0.848091  0.345825 -1.081291e-01  1.000000  0.633055  ...
# LongB        0.615218  0.715286 -1.218108e-02  0.633055  1.000000  ...
# ThrB         0.544250  0.477973  1.218063e-01  0.438565  0.243763  ...
# Off          0.068004  0.256318  0.077630 -0.158317  0.012434  0.228304
# Disp         0.736025  0.207477  0.197185  0.363138  0.027077 -0.039142
# UnsTch       1.000000  0.445334  0.313863  0.442227 -0.088046  0.119096
# Tackles      0.445334  1.000000  0.429872  0.226340  0.134350  0.295963
# Inter        0.313863  0.429872  1.000000  0.327002 -0.138997  0.632683
# Fouls        0.442227  0.226340  0.327002  1.000000 -0.105424  0.297525
# Offsides    -0.088046  0.134350 -0.138997 -0.105424  1.000000 -0.153130
# Clear        0.119096  0.295963  0.632683  0.297525 -0.153130  1.000000
# Drb          0.375478  0.675068  0.319010 -0.010870  0.158779  0.151745
# Blocks      -0.068425  0.219913  0.401980  0.284631  0.159976  0.621974
# OwnG         0.283629  0.040723  0.282410  0.504835 -0.153522  0.054035
# Pts          0.020138 -0.092082 -0.238602  0.034589  0.085062 -0.043185
#
#                   Drb    Blocks      OwnG       Pts
# team_number  0.095985 -0.093017 -0.129727 -0.142173
# age          0.551680 -0.069138 -0.089172 -0.438532
# Apps         0.495037  0.169391  0.225499 -0.346914
# Mins         0.550285  0.312679  0.347835 -0.233745
# Assists      0.387413 -0.106698 -0.029290 -0.043833
# KeyP         0.370380 -0.111481  0.051581 -0.102547
# AvgP         0.539395  0.270597  0.334914  0.088776
# PS%          0.079569  0.396088  0.193975  0.331421
# Crosses      0.388580 -0.192731 -0.083801 -0.104407
# LongB        0.469380 -0.059383 -0.041178 -0.147348
# ThrB         0.224997  0.067285  0.534409  0.044654
# Rating       0.371798  0.295456  0.273219  0.051033
# Goals        0.376705 -0.195866  0.034162 -0.240574
# Yel          0.241297  0.285276 -0.066898 -0.105685
# Red         -0.228528 -0.078539  0.479257  0.237658
# SpG          0.192443 -0.138384  0.165647 -0.183253
# AerialsWon  -0.092824  0.164527 -0.055006 -0.025686
# MoM          0.409168 -0.031025 -0.168951 -0.008043
# Dribble     -0.088354  0.233447  0.347121  0.017676
# Fouled       0.221898  0.132024  0.219938  0.067870
# Off          0.124428  0.155522  0.136487  0.085354
# Disp         0.068412  0.168599  0.439289  0.304397
# UnsTch       0.375478 -0.068425  0.283629  0.020138
# Tackles      0.675068  0.219913  0.040723 -0.092082
# Inter        0.319010  0.401980  0.282410 -0.238602
# Fouls       -0.010870  0.284631  0.504835  0.034589
# Offsides     0.158779  0.159976 -0.153522  0.085062
# Clear        0.151745  0.621974  0.054035 -0.043185
# Drb          1.000000 -0.107082 -0.125003 -0.165568
# Blocks      -0.107082  1.000000  0.128845  0.276588
# OwnG        -0.125003  0.128845  1.000000  0.385581
# Pts         -0.165568  0.276588  0.385581  1.000000
#
# [32 rows x 32 columns]

# %%
# heatmap으로 상관관계 시각화

plt.figure(figsize=(10, 10))
sns.heatmap(L1_DM_corr_matrix)
plt.show()

# %%
# Pts부분만 뽑아서 상관관계 확인

L1_DM_corr_matrix_Pts = L1_DM_corr_matrix[['Pts']]
L1_DM_corr_matrix_Pts
# Out:
#                   Pts
# team_number -0.142173
# age         -0.438532
# Apps        -0.346914
# Mins        -0.233745
# Assists     -0.043833
# KeyP        -0.102547
# AvgP         0.088776
# PS%          0.331421
# Crosses     -0.104407
# LongB       -0.147348
# ThrB         0.044654
# Rating       0.051033
# Goals       -0.240574
# Yel         -0.105685
# Red          0.237658
# SpG         -0.183253
# AerialsWon  -0.025686
# MoM         -0.008043
# Dribble      0.017676
# Fouled       0.067870
# Off          0.085354
# Disp         0.304397
# UnsTch       0.020138
# Tackles     -0.092082
# Inter       -0.238602
# Fouls        0.034589
# Offsides     0.085062
# Clear       -0.043185
# Drb         -0.165568
# Blocks       0.276588
# OwnG         0.385581
# Pts          1.000000

# %%
# 내림차순 정렬 후 heatmap으로 시각화
# 전체적으로 Pts와의 상관관계가 조금 낮은 상태..

L1_DM_corr_matrix_Pts.sort_values('Pts', ascending=False, inplace=True)
plt.figure(figsize=(3, 10))
sns.heatmap(L1_DM_corr_matrix_Pts, annot=True, fmt='.3f')
plt.show()
# Out:
# /var/folders/zt/1l6rrzf977nbpmcz1d2j0vd40000gn/T/ipykernel_72451/454864161.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   L1_DM_corr_matrix_Pts.sort_values('Pts', ascending=False, inplace=True)

# %%
# 상위 10개 변수 추출

L1_DM_corr_matrix_Pts.iloc[1:11].index.to_list()
# ['OwnG', 'PS%', 'Disp', 'Blocks', 'Red', 'AvgP', 'Off', 'Offsides', 'Fouled', 'Rating']
# Out:
# ['OwnG',
#  'PS%',
#  'Disp',
#  'Blocks',
#  'Red',
#  'AvgP',
#  'Off',
#  'Offsides',
#  'Fouled',
#  'Rating']

# %%
index_li = L1_DM_corr_matrix_Pts.iloc[:11].index.tolist()
corr_li = L1_DM_corr_matrix_Pts['Pts'].tolist()
for i in range(1, 11):
    print(f'{index_li[i]}: {corr_li[i]:.3f}')
    
# OwnG: 0.386 PS%: 0.331 Disp: 0.304 Blocks: 0.277 Red: 0.238 AvgP: 0.089 Off: 0.085 Offsides: 0.085 Fouled: 0.068 Rating: 0.051
# Out:
# OwnG: 0.386
# PS%: 0.331
# Disp: 0.304
# Blocks: 0.277
# Red: 0.238
# AvgP: 0.089
# Off: 0.085
# Offsides: 0.085
# Fouled: 0.068
# Rating: 0.051

# %% [markdown]
# # D 포지션 데이터
# ## D포지션에서 승리에 가장 큰 영향을 주는 변수 추출

# %%
L1_D_player_df
# Out:
#                player_name  team_number                 Team  age position  \
# 0           Benjamin André          607                Lille   32        D
# 1           Andrei Girotto          302               Nantes   31        D
# 2          Fabien Centonze          302               Nantes   27        D
# 3              Nuno Mendes          304  Paris Saint-Germain   21        D
# 4    Przemyslaw Frankowski          309                 Lens   28        D
# ..                     ...          ...                  ...  ...      ...
# 118            Sada Thioub          614               Angers   28        D
# 119          Andreas Bruus          229               Troyes   24        D
# 120      Sébastien Corchia          302               Nantes   32        D
# 121        Abdoulaye Bamba          614               Angers   33        D
# 122          Cédric Avinel          610           AC Ajaccio   36        D
#
#      Apps  Mins  Assists  KeyP  AvgP  ...  Disp  UnsTch  Tackles  Inter  \
# 0      34  2919        1   0.6  67.6  ...   1.0     1.1      3.8    1.4
# 1      36  3153        1   0.4  48.1  ...   0.2     0.3      3.4    2.0
# 2      23  1693        0   0.5  32.0  ...   0.5     1.1      2.5    1.9
# 3      23  1554        5   1.0  35.9  ...   0.7     1.3      2.0    0.7
# 4      37  2838        3   1.8  36.1  ...   0.4     0.8      2.1    1.1
# ..    ...   ...      ...   ...   ...  ...   ...     ...      ...    ...
# 118    27  1056        2   0.6  16.9  ...   0.7     0.6      0.7    0.3
# 119    27  1626        2   0.8  17.4  ...   0.1     0.9      0.4    0.6
# 120    22   775        1   0.2  12.2  ...   0.3     0.6      0.7    0.6
# 121    21  1359        0   0.2  30.9  ...   0.2     0.4      1.0    0.9
# 122    24  1791        0   0.0  29.8  ...   0.0     0.1      0.5    0.6
#
#      Fouls  Offsides  Clear  Drb  Blocks  OwnG
# 0      1.7       0.1    1.6  1.6     0.2     0
# 1      1.5       0.3    4.8  1.6     0.7     0
# 2      0.6       0.1    2.3  0.5     0.3     0
# 3      1.1       0.1    0.7  0.5     0.1     0
# 4      0.9       0.1    0.9  1.1     0.2     0
# ..     ...       ...    ...  ...     ...   ...
# 118    0.5       0.0    0.1  0.3     0.0     0
# 119    0.4       0.0    0.8  0.4     0.1     0
# 120    0.7       0.0    0.7  0.5     0.1     0
# 121    0.5       0.3    1.7  0.1     0.1     0
# 122    0.5       0.4    3.7  0.2     0.5     0
#
# [123 rows x 34 columns]

# %%
L1_D_df = pd.merge(L1_D_player_df, L1_Team_df[['Team', 'Pts']], on='Team', how='inner')

# %%
L1_D_df.columns
# Out:
# Index(['player_name', 'team_number', 'Team', 'age', 'position', 'Apps', 'Mins',
#        'Assists', 'KeyP', 'AvgP', 'PS%', 'Crosses', 'LongB', 'ThrB', 'Rating',
#        'Goals', 'Yel', 'Red', 'SpG', 'AerialsWon', 'MoM', 'Dribble', 'Fouled',
#        'Off', 'Disp', 'UnsTch', 'Tackles', 'Inter', 'Fouls', 'Offsides',
#        'Clear', 'Drb', 'Blocks', 'OwnG', 'Pts'],
#       dtype='object')

# %%
# 수치형 데이터만 뽑아온다.

L1_D_numeric_df = L1_D_df.select_dtypes(['int64', 'float64'])

# %%
L1_D_corr_matrix = L1_D_numeric_df.corr()
L1_D_corr_matrix
# Out:
#              team_number       age      Apps      Mins   Assists      KeyP  \
# team_number     1.000000 -0.012865  0.040990  0.042155 -0.216232 -0.146960
# age            -0.012865  1.000000  0.105029  0.100555 -0.053199 -0.090889
# Apps            0.040990  0.105029  1.000000  0.852384  0.197849  0.022866
# Mins            0.042155  0.100555  0.852384  1.000000  0.100696 -0.065989
# Assists        -0.216232 -0.053199  0.197849  0.100696  1.000000  0.590330
# KeyP           -0.146960 -0.090889  0.022866 -0.065989  0.590330  1.000000
# AvgP           -0.075677  0.132508  0.360409  0.620399 -0.022287 -0.148298
# PS%            -0.121739  0.120630  0.105406  0.243665 -0.113394 -0.250487
# Crosses        -0.121623 -0.131170 -0.090331 -0.177077  0.352134  0.774123
# LongB           0.104855  0.279310  0.282641  0.512464 -0.160852 -0.290444
# ThrB           -0.102940 -0.019436  0.101724  0.100852  0.305822  0.312486
# Rating         -0.065603 -0.036065  0.388180  0.538510  0.383366  0.340064
# Goals          -0.095520 -0.014696  0.260391  0.225165  0.163575  0.181376
# Yel             0.113746  0.066461  0.313085  0.399631 -0.112124 -0.169698
# Red             0.029874 -0.034134  0.045172  0.140973 -0.086414 -0.141728
# SpG            -0.042292  0.013308  0.274947  0.236072  0.254926  0.263851
# AerialsWon      0.017526  0.212419  0.299877  0.491090 -0.184987 -0.470079
# MoM            -0.068673 -0.033722  0.236437  0.324849  0.193748  0.192088
# Dribble         0.055525 -0.365504 -0.015381 -0.034255  0.197384  0.450987
# Fouled          0.078080 -0.193447 -0.002677  0.092973 -0.009135  0.162866
# Off            -0.136125 -0.041872 -0.042605 -0.073523  0.262261  0.355197
# Disp           -0.017324 -0.166726  0.058132 -0.006643  0.171059  0.451545
# UnsTch          0.010323 -0.185411  0.028203 -0.033669  0.228392  0.489478
# Tackles         0.052979 -0.010443  0.129245  0.276340  0.106168  0.309531
# SpG         -0.102432  0.145454
# AerialsWon   0.187315 -0.061515
# MoM          0.023691  0.160013
# Dribble     -0.264171  0.022213
# Fouled      -0.192618  0.015924
# Off         -0.233678  0.040696
# Disp        -0.185716  0.001889
# UnsTch      -0.235339 -0.054821
# Tackles     -0.116813  0.081735
# Inter        0.161848 -0.027966
# Fouls       -0.103204 -0.050641
# Offsides     0.305653 -0.065664
# Clear        0.340003 -0.141712
# Drb         -0.162886  0.017783
# Blocks       0.342278 -0.025317
# OwnG         1.000000 -0.073831
# Pts         -0.073831  1.000000
#
# [32 rows x 32 columns]

# %%
# heatmap으로 상관관계 시각화

plt.figure(figsize=(10, 10))
sns.heatmap(L1_D_corr_matrix)
plt.show()

# %%
# Pts부분만 뽑아서 상관관계 확인

L1_D_corr_matrix_Pts = L1_D_corr_matrix[['Pts']]
L1_D_corr_matrix_Pts
# Out:
#                   Pts
# team_number -0.104185
# age         -0.057351
# Apps         0.221618
# Mins         0.162973
# Assists      0.331132
# KeyP         0.174831
# AvgP         0.467823
# PS%          0.472830
# Crosses      0.029055
# LongB        0.046014
# ThrB         0.088243
# Rating       0.569837
# Goals        0.179483
# Yel          0.043360
# Red         -0.018891
# SpG          0.145454
# AerialsWon  -0.061515
# MoM          0.160013
# Dribble      0.022213
# Fouled       0.015924
# Off          0.040696
# Disp         0.001889
# UnsTch      -0.054821
# Tackles      0.081735
# Inter       -0.027966
# Fouls       -0.050641
# Offsides    -0.065664
# Clear       -0.141712
# Drb          0.017783
# Blocks      -0.025317
# OwnG        -0.073831
# Pts          1.000000

# %%
# 내림차순 정렬 후 heatmap으로 시각화
# 전체적으로 Pts와의 상관관계가 조금 낮은 상태..

L1_D_corr_matrix_Pts.sort_values('Pts', ascending=False, inplace=True)
plt.figure(figsize=(3, 10))
sns.heatmap(L1_D_corr_matrix_Pts, annot=True, fmt='.3f')
plt.show()
# Out:
# /var/folders/zt/1l6rrzf977nbpmcz1d2j0vd40000gn/T/ipykernel_72451/4052533319.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   L1_D_corr_matrix_Pts.sort_values('Pts', ascending=False, inplace=True)

# %%
# 상위 10개 변수 추출

L1_D_corr_matrix_Pts.iloc[1:11].index.to_list()
# ['Rating', 'PS%', 'AvgP', 'Assists', 'Goals', 'KeyP', 'Mins', 'MoM', 'SpG', 'ThrB']
# Out:
# ['Rating',
#  'PS%',
#  'AvgP',
#  'Assists',
#  'Apps',
#  'Goals',
#  'KeyP',
#  'Mins',
#  'MoM',
#  'SpG']

# %%
index_li = L1_D_corr_matrix_Pts.iloc[:11].index.tolist()
corr_li = L1_D_corr_matrix_Pts['Pts'].tolist()
for i in range(1, 11):
    print(f'{index_li[i]}: {corr_li[i]:.3f}')
    
# Rating: 0.570 PS%: 0.473 AvgP: 0.468 Assists: 0.331 Apps: 0.222 Goals: 0.179 KeyP: 0.175 Mins: 0.163 MoM: 0.160 SpG: 0.145
# Out:
# Rating: 0.570
# PS%: 0.473
# AvgP: 0.468
# Assists: 0.331
# Apps: 0.222
# Goals: 0.179
# KeyP: 0.175
# Mins: 0.163
# MoM: 0.160
# SpG: 0.145

# %% [markdown]
# # 결과 분서
# ## 전체적으로 상관계수가 매우 낮다
# - 음... 뭔가 분석할 때 추가 작업이 필요할듯

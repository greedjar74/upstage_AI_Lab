# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %% [markdown]
# # 데이터 가져오기

# %% [markdown]
# ## 포지션별 데이터

# %%
data_path = './EPL_data/EPL_Position_Player_Stats/'
path_list = os.listdir(data_path)
path_list.pop(1)
path_list
# Out:
# ['EPL_GK_Player.csv',
#  'EPL_M_Player.csv',
#  'EPL_AM_Player.csv',
#  'EPL_DM_Player.csv',
#  'EPL_FW_Player.csv',
#  'EPL_D_Player.csv']

# %%
EPL_GK_player_df = pd.read_csv('./EPL_data/EPL_Position_Player_Stats/'+path_list[0])
EPL_M_player_df = pd.read_csv('./EPL_data/EPL_Position_Player_Stats/'+path_list[1])
EPL_AM_player_df = pd.read_csv('./EPL_data/EPL_Position_Player_Stats/'+path_list[2])
EPL_DM_player_df = pd.read_csv('./EPL_data/EPL_Position_Player_Stats/'+path_list[3])
EPL_FW_player_df = pd.read_csv('./EPL_data/EPL_Position_Player_Stats/'+path_list[4])
EPL_D_player_df = pd.read_csv('./EPL_data/EPL_Position_Player_Stats/'+path_list[5])

# %%
print(EPL_GK_player_df.shape)
print(EPL_M_player_df.shape)
print(EPL_AM_player_df.shape)
print(EPL_DM_player_df.shape)
print(EPL_FW_player_df.shape)
print(EPL_D_player_df.shape)
# Out:
# (19, 35)
# (56, 35)
# (71, 35)
# (18, 35)
# (16, 35)
# (128, 35)

# %%
# col확인 -> Unnamed: 0 제거 필요
EPL_AM_player_df.columns
# Out:
# Index(['Unnamed: 0', 'player_name', 'team_number', 'Team', 'age', 'position',
#        'Apps', 'Mins', 'Assists', 'KeyP', 'AvgP', 'PS%', 'Crosses', 'LongB',
#        'ThrB', 'Rating', 'Goals', 'Yel', 'Red', 'SpG', 'AerialsWon', 'MoM',
#        'Dribble', 'Fouled', 'Off', 'Disp', 'UnsTch', 'Tackles', 'Inter',
#        'Fouls', 'Offsides', 'Clear', 'Drb', 'Blocks', 'OwnG'],
#       dtype='object')

# %%
#  Unnamed: 0 제거
EPL_GK_player_df.drop('Unnamed: 0', axis=1, inplace=True)
EPL_GK_player_df.shape
# Out:
# (19, 34)

# %%
#  Unnamed: 0 제거
EPL_M_player_df.drop('Unnamed: 0', axis=1, inplace=True)
EPL_M_player_df.shape
# Out:
# (56, 34)

# %%
#  Unnamed: 0 제거
EPL_AM_player_df.drop('Unnamed: 0', axis=1, inplace=True)
EPL_AM_player_df.shape
# Out:
# (71, 34)

# %%
#  Unnamed: 0 제거
EPL_DM_player_df.drop('Unnamed: 0', axis=1, inplace=True)
EPL_DM_player_df.shape
# Out:
# (18, 34)

# %%
#  Unnamed: 0 제거
EPL_FW_player_df.drop('Unnamed: 0', axis=1, inplace=True)
EPL_FW_player_df.shape
# Out:
# (16, 34)

# %%
#  Unnamed: 0 제거
EPL_D_player_df.drop('Unnamed: 0', axis=1, inplace=True)
EPL_D_player_df.shape
# Out:
# (128, 34)

# %% [markdown]
# ## EPL 팀 분석 데이터

# %%
EPL_Team_df = pd.read_csv('./EPL_data/EPL_Team.csv')
EPL_Team_df.shape
# Out:
# (20, 25)

# %%
EPL_Team_df.drop('Unnamed: 0', axis=1, inplace=True)
EPL_Team_df.shape
# Out:
# (20, 24)

# %% [markdown]
# # GK 포지션 데이터
# ## GK포지션에서 승리에 가장 큰 영향을 주는 변수 추출
# - 포지션의 특수성을 생각해서 필요없는 변수는 미리 제거

# %%
EPL_GK_df = pd.merge(EPL_GK_player_df, EPL_Team_df, on='Team', how='inner')

# %%
# GK 데이터 cols 확인
# 필요없는 변수는 제거해준다.

EPL_GK_df.columns
# Out:
# Index(['player_name', 'team_number', 'Team', 'age', 'position', 'Apps', 'Mins',
#        'Assists', 'KeyP', 'AvgP', 'PS%', 'Crosses', 'LongB', 'ThrB',
#        'Rating_x', 'Goals_x', 'Yel', 'Red_x', 'SpG', 'AerialsWon_x', 'MoM',
#        'Dribble', 'Fouled', 'Off', 'Disp', 'UnsTch', 'Tackles', 'Inter',
#        'Fouls', 'Offsides', 'Clear', 'Drb', 'Blocks', 'OwnG', 'Rank_x', 'P',
#        'W', 'D', 'L', 'GF', 'GA', 'GD', 'Pts', 'Rank_y', 'Goals_y', 'Shotspg',
#        'Yellow', 'Red_y', 'Possession', 'Pass', 'AerialsWon_y', 'Rating_y',
#        'Squad', 'Average age', 'Foreigne Players', 'Average Market Value',
#        'Market Value'],
#       dtype='object')

# %%
# 필요없는 변수 추측
# 필요한 변수만 뽑아온다.

EPL_GK_df = EPL_GK_df[['age','Apps', 'Mins', 'Assists', 
                       'KeyP', 'AvgP', 'PS%', 'Crosses', 'LongB', 
                       'ThrB','Rating_x', 'Yel', 'Red_x', 'AerialsWon_x', 
                       'MoM', 'Dribble', 'Fouled', 'Disp', 'UnsTch', 
                       'Tackles', 'Inter', 'Fouls', 'Offsides', 'Clear', 
                       'Drb', 'Blocks', 'OwnG', 'Rank_x', 'P', 
                       'GF', 'GA', 'GD', 'Pts', 'Possession', 
                       'Pass', 'Squad', 'Market Value']]

# %%
EPL_GK_df
# Out:
#     age  Apps  Mins  Assists  KeyP  AvgP   PS%  Crosses  LongB  ThrB  ...  \
# 0    27    38  3420        0   0.1  38.8  60.7      0.0   10.8   0.0  ...
# 1    31    36  3240        0   0.0  33.5  76.3      0.0    4.4   0.0  ...
# 2    30    37  3330        1   0.0  33.5  83.4      0.0    4.5   0.0  ...
# 3    30    36  3141        0   0.1  34.7  71.6      0.0    6.6   0.0  ...
# 4    28    29  2566        0   0.0  30.9  80.7      0.0    4.1   0.0  ...
# 5    33    27  2386        0   0.0  25.8  56.0      0.0    6.4   0.0  ...
# 6    36    27  2430        0   0.0  26.0  67.5      0.0    5.6   0.0  ...
# 7    31    37  3262        0   0.1  17.8  58.8      0.0    3.8   0.0  ...
# 8    29    37  3330        1   0.1  31.2  51.8      0.0    7.9   0.0  ...
# 9    38    36  3114        0   0.0  21.5  58.1      0.0    5.8   0.0  ...
# 10   32    38  3420        0   0.0  28.5  68.3      0.0    4.9   0.0  ...
# 11   25    38  3420        0   0.0  24.6  63.4      0.0    3.6   0.0  ...
# ...

# %%
# 승점을 기준으로 내림차순 정렬

EPL_GK_df.sort_values('Pts', ascending=False, inplace=True)
EPL_GK_df[['Pts']]
# Out:
#     Pts
# 15   89
# 11   84
# 10   75
# 7    71
# 2    67
# 18   62
# 3    61
# 12   60
# 0    59
# 1    52
# 6    45
# 4    44
# 13   41
# 9    40
# 5    39
# 8    36
# 14   34
# 17   31
# 16   25

# %%
# 수치형 데이터만 뽑아온다.

EPL_GK_numeric_df = EPL_GK_df.select_dtypes(['int64', 'float64'])

# %%
# 상관관계 확인

EPL_GK_corr_matrix = EPL_GK_numeric_df.corr()
EPL_GK_corr_matrix
# Out:
#                    age          Apps      Mins   Assists      KeyP      AvgP  \
# age           1.000000 -1.173706e-01 -0.159524 -0.035702 -0.052689 -0.351490
# Apps         -0.117371  1.000000e+00  0.996476  0.291449  0.417088  0.137891
# Mins         -0.159524  9.964755e-01  1.000000  0.313234  0.394701  0.169748
# Assists      -0.035702  2.914494e-01  0.313234  1.000000  0.130437  0.293524
# KeyP         -0.052689  4.170885e-01  0.394701  0.130437  1.000000  0.190644
# AvgP         -0.351490  1.378907e-01  0.169748  0.293524  0.190644  1.000000
# PS%           0.111469 -1.879982e-01 -0.176879  0.267826 -0.347025  0.354595
# Crosses            NaN           NaN       NaN       NaN       NaN       NaN
# LongB        -0.025519  2.371648e-01  0.233956  0.137040  0.562193  0.533920
# ThrB               NaN           NaN       NaN       NaN       NaN       NaN
# Rating_x      0.346556  3.579192e-01  0.337880  0.036185  0.402463  0.350000
# ...

# %%
# heatmap으로 상관관계 시각화

plt.figure(figsize=(10, 10))
sns.heatmap(EPL_GK_corr_matrix)
plt.title('GK values Corr')
plt.show()

# %%
# 히트맵을 보고 nan이 나오는 변수는 제거
EPL_GK_df.drop(['Crosses', 'ThrB', 'Disp', 'Fouls', 'Offsides', 'Blocks', 'P'], axis=1, inplace=True)

# %%
# 변수 제거 후 다시 상관계수 확인
# 수치형 데이터만 뽑아온다.

EPL_GK_numeric_df = EPL_GK_df.select_dtypes(['int64', 'float64'])

# %%
EPL_GK_corr_matrix = EPL_GK_numeric_df.corr()
EPL_GK_corr_matrix
# Out:
#                    age          Apps      Mins   Assists      KeyP      AvgP  \
# age           1.000000 -1.173706e-01 -0.159524 -0.035702 -0.052689 -0.351490
# Apps         -0.117371  1.000000e+00  0.996476  0.291449  0.417088  0.137891
# Mins         -0.159524  9.964755e-01  1.000000  0.313234  0.394701  0.169748
# Assists      -0.035702  2.914494e-01  0.313234  1.000000  0.130437  0.293524
# KeyP         -0.052689  4.170885e-01  0.394701  0.130437  1.000000  0.190644
# AvgP         -0.351490  1.378907e-01  0.169748  0.293524  0.190644  1.000000
# PS%           0.111469 -1.879982e-01 -0.176879  0.267826 -0.347025  0.354595
# LongB        -0.025519  2.371648e-01  0.233956  0.137040  0.562193  0.533920
# Rating_x      0.346556  3.579192e-01  0.337880  0.036185  0.402463  0.350000
# Yel          -0.036379  2.419867e-01  0.219376  0.286984  0.587213  0.126971
# Red_x         0.072875  1.903740e-01  0.166272 -0.102062  0.456435 -0.531621
# ...

# %%
# heatmap으로 상관관계 시각화

plt.figure(figsize=(10, 10))
sns.heatmap(EPL_GK_corr_matrix)
plt.title('GK values Corr')
plt.show()

# %%
# Pts부분만 뽑아서 상관관계 확인

EPL_GK_corr_matrix_Pts = EPL_GK_corr_matrix[['Pts']]
EPL_GK_corr_matrix_Pts
# Out:
#                    Pts
# age           0.068226
# Apps          0.317753
# Mins          0.321146
# Assists       0.256484
# KeyP          0.096252
# AvgP         -0.006132
# PS%           0.496921
# LongB        -0.205233
# Rating_x      0.144538
# Yel          -0.015892
# Red_x         0.231993
# AerialsWon_x -0.286622
# MoM          -0.253475
# Dribble       0.011119
# Fouled       -0.213645
# UnsTch        0.039449
# Tackles      -0.161317
# Inter        -0.084905
# Clear        -0.315993
# Drb           0.045550
# OwnG          0.159505
# Rank_x       -0.979464
# GF            0.874654
# GA           -0.820625
# GD            0.960759
# Pts           1.000000
# Possession    0.729641
# Pass          0.672985
# Squad        -0.385687

# %%
# 내림차순 정렬 후 heatmap으로 시각화

EPL_GK_corr_matrix_Pts.sort_values('Pts', ascending=False, inplace=True)
plt.figure(figsize=(3, 10))
sns.heatmap(EPL_GK_corr_matrix_Pts,annot=True, fmt='.3f')
plt.show()
# Out:
# /var/folders/zt/1l6rrzf977nbpmcz1d2j0vd40000gn/T/ipykernel_72346/912495408.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   EPL_GK_corr_matrix_Pts.sort_values('Pts', ascending=False, inplace=True)

# %%
# 상위 10개의 지표 선택
# Pts는 자기자신과 공분산이 1이므로 제외
# GD, GF 등 팀 지표가 들어가있다. -> 팀지표에서 Pts를 제외하곤 다 빼고 구해야됨

EPL_GK_corr_matrix_Pts[1:11].index.to_list()
# Out:
# ['GD',
#  'GF',
#  'Possession',
#  'Pass',
#  'PS%',
#  'Mins',
#  'Apps',
#  'Assists',
#  'Red_x',
#  'OwnG']

# %%
EPL_GK_df = pd.merge(EPL_GK_player_df, EPL_Team_df[['Team', 'Pts']], on='Team', how='inner')

# %%
EPL_GK_df
# Out:
#           player_name  team_number               Team  age position  Apps  \
# 0          David Raya          189          Brentford   27       GK    38
# 1          Bernd Leno          170             Fulham   31       GK    36
# 2             Alisson           26          Liverpool   30       GK    37
# 3   Emiliano Martínez           24        Aston Villa   30       GK    36
# 4   Kepa Arrizabalaga           15            Chelsea   28       GK    29
# 5                Neto          183        Bournemouth   33       GK    27
# 6      Vicente Guaita          162     Crystal Palace   36       GK    27
# 7           Nick Pope           23          Newcastle   31       GK    37
# 8     Jordan Pickford           31            Everton   29       GK    37
# 9    Lukasz Fabianski           29           West Ham   38       GK    36
# 10       David de Gea           32  Manchester United   32       GK    38
# 11     Aaron Ramsdale           13            Arsenal   25       GK    38
# ...

# %%
# 수치형 데이터만 뽑아온다.

EPL_GK_numeric_df = EPL_GK_df.select_dtypes(['int64', 'float64'])

# %%
EPL_GK_corr_matrix = EPL_GK_numeric_df.corr()
EPL_GK_corr_matrix
# Out:
#              team_number       age          Apps      Mins   Assists  \
# team_number     1.000000  0.075181 -2.253154e-01 -0.199850 -0.029677
# age             0.075181  1.000000 -1.173706e-01 -0.159524 -0.035702
# Apps           -0.225315 -0.117371  1.000000e+00  0.996476  0.291449
# Mins           -0.199850 -0.159524  9.964755e-01  1.000000  0.313234
# Assists        -0.029677 -0.035702  2.914494e-01  0.313234  1.000000
# KeyP           -0.089529 -0.052689  4.170885e-01  0.394701  0.130437
# AvgP            0.263787 -0.351490  1.378907e-01  0.169748  0.293524
# PS%             0.148101  0.111469 -1.879982e-01 -0.176879  0.267826
# Crosses              NaN       NaN           NaN       NaN       NaN
# LongB           0.168557 -0.025519  2.371648e-01  0.233956  0.137040
# ThrB                 NaN       NaN           NaN       NaN       NaN
# Rating          0.088250  0.346556  3.579192e-01  0.337880  0.036185
# Goals                NaN       NaN           NaN       NaN       NaN
# ...

# %%
# heatmap으로 상관관계 시각화

plt.figure(figsize=(10, 10))
sns.heatmap(EPL_GK_corr_matrix)
plt.title('GK values Corr')
plt.show()

# %%
# 히트맵을 보고 nan이 나오는 변수는 제거
EPL_GK_df.drop(['Crosses', 'ThrB', 'Goals', 'SpG', 'Off', 'Disp', 'Fouls', 'Offsides', 'Blocks'], axis=1, inplace=True)

# %%
# 수치형 데이터만 뽑아온다.

EPL_GK_numeric_df = EPL_GK_df.select_dtypes(['int64', 'float64'])

# %%
EPL_GK_corr_matrix = EPL_GK_numeric_df.corr()
EPL_GK_corr_matrix
# Out:
#              team_number       age          Apps      Mins   Assists  \
# team_number     1.000000  0.075181 -2.253154e-01 -0.199850 -0.029677
# age             0.075181  1.000000 -1.173706e-01 -0.159524 -0.035702
# Apps           -0.225315 -0.117371  1.000000e+00  0.996476  0.291449
# Mins           -0.199850 -0.159524  9.964755e-01  1.000000  0.313234
# Assists        -0.029677 -0.035702  2.914494e-01  0.313234  1.000000
# KeyP           -0.089529 -0.052689  4.170885e-01  0.394701  0.130437
# AvgP            0.263787 -0.351490  1.378907e-01  0.169748  0.293524
# PS%             0.148101  0.111469 -1.879982e-01 -0.176879  0.267826
# LongB           0.168557 -0.025519  2.371648e-01  0.233956  0.137040
# Rating          0.088250  0.346556  3.579192e-01  0.337880  0.036185
# Yel             0.103573 -0.036379  2.419867e-01  0.219376  0.286984
# Red            -0.177420  0.072875  1.903740e-01  0.166272 -0.102062
# AerialsWon     -0.029493  0.154387 -2.679461e-01 -0.301490 -0.092219
# ...

# %%
# heatmap으로 상관관계 시각화

plt.figure(figsize=(10, 10))
sns.heatmap(EPL_GK_corr_matrix)
plt.title('GK values Corr')
plt.show()

# %%
# Pts부분만 뽑아서 상관관계 확인

EPL_GK_corr_matrix_Pts = EPL_GK_corr_matrix[['Pts']]
EPL_GK_corr_matrix_Pts
# Out:
#                   Pts
# team_number  0.097805
# age          0.068226
# Apps         0.317753
# Mins         0.321146
# Assists      0.256484
# KeyP         0.096252
# AvgP        -0.006132
# PS%          0.496921
# LongB       -0.205233
# Rating       0.144538
# Yel         -0.015892
# Red          0.231993
# AerialsWon  -0.286622
# MoM         -0.253475
# Dribble      0.011119
# Fouled      -0.213645
# UnsTch       0.039449
# Tackles     -0.161317
# Inter       -0.084905
# Clear       -0.315993
# Drb          0.045550
# OwnG         0.159505
# Pts          1.000000

# %%
# 내림차순 정렬 후 heatmap으로 시각화

EPL_GK_corr_matrix_Pts.sort_values('Pts', ascending=False, inplace=True)
plt.figure(figsize=(3, 10))
sns.heatmap(EPL_GK_corr_matrix_Pts, annot=True, fmt='.3f')
plt.show()
# Out:
# /var/folders/zt/1l6rrzf977nbpmcz1d2j0vd40000gn/T/ipykernel_72346/4005008825.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   EPL_GK_corr_matrix_Pts.sort_values('Pts', ascending=False, inplace=True)

# %%
# 상위 5개의 지표 선택
# Pts는 자기자신과 공분산이 1이므로 제외

# 결과를 분석해보자
# PS%: 골키퍼의 패스 성공률이 높을수록 승리에 가까워질 것 같다. -> 인정
# Mins: 플레이 타임... -> 어느정도 인정
# Apps: 경기 출전수... -> 어느정도 인정
# Assists: 골키퍼한테 어시스트..? -> 노인정
# Red: 골키퍼한테 레드카드 -> 어느정도 인정 -> Red카드에 의해 경기 결과가 바뀌는 경우의 수가 많았을까? -> 적절하지는 않다고 본다.

# 종합: 골키퍼의 경우 평가 지표가 적절하지 않아 평가하기에 적합하지는 않은 것 같다.

EPL_GK_corr_matrix_Pts.iloc[1:6].index.to_list()
# Out:
# ['PS%', 'Mins', 'Apps', 'Assists', 'Red']

# %%
index_li = EPL_GK_corr_matrix_Pts.iloc[:11].index.tolist()
corr_li = EPL_GK_corr_matrix_Pts['Pts'].tolist()
for i in range(1, 11):
    print(f'{index_li[i]}: {corr_li[i]:.3f}')
    
# PS%: 0.497 Mins: 0.321 Apps: 0.318 Assists: 0.256 Red: 0.232 OwnG: 0.160 Rating: 0.145 team_number: 0.098 KeyP: 0.096 age: 0.068
# Out:
# PS%: 0.497
# Mins: 0.321
# Apps: 0.318
# Assists: 0.256
# Red: 0.232
# OwnG: 0.160
# Rating: 0.145
# team_number: 0.098
# KeyP: 0.096
# age: 0.068

# %% [markdown]
# # FW 포지션 데이터
# ## FW포지션에서 승리에 가장 큰 영향을 주는 변수 추출

# %%
EPL_FW_df = pd.merge(EPL_FW_player_df, EPL_Team_df[['Team', 'Pts']], on='Team', how='inner')

# %%
EPL_FW_df.columns
# Out:
# Index(['player_name', 'team_number', 'Team', 'age', 'position', 'Apps', 'Mins',
#        'Assists', 'KeyP', 'AvgP', 'PS%', 'Crosses', 'LongB', 'ThrB', 'Rating',
#        'Goals', 'Yel', 'Red', 'SpG', 'AerialsWon', 'MoM', 'Dribble', 'Fouled',
#        'Off', 'Disp', 'UnsTch', 'Tackles', 'Inter', 'Fouls', 'Offsides',
#        'Clear', 'Drb', 'Blocks', 'OwnG', 'Pts'],
#       dtype='object')

# %%
# 수치형 데이터만 뽑아온다.

EPL_FW_numeric_df = EPL_FW_df.select_dtypes(['int64', 'float64'])

# %%
EPL_FW_corr_matrix = EPL_FW_numeric_df.corr()
EPL_FW_corr_matrix
# Out:
#              team_number       age      Apps      Mins   Assists      KeyP  \
# team_number     1.000000 -0.039337 -0.221772  0.185226 -0.106884  0.105643
# age            -0.039337  1.000000  0.283817  0.246644 -0.169598 -0.081000
# Apps           -0.221772  0.283817  1.000000  0.737170  0.663187  0.343151
# Mins            0.185226  0.246644  0.737170  1.000000  0.746252  0.725715
# Assists        -0.106884 -0.169598  0.663187  0.746252  1.000000  0.713043
# KeyP            0.105643 -0.081000  0.343151  0.725715  0.713043  1.000000
# AvgP            0.405567  0.105019  0.293567  0.769749  0.356478  0.684053
# PS%            -0.159963 -0.327415  0.094521  0.036759  0.227692  0.308032
# Crosses         0.238294  0.231986  0.294120  0.421784  0.033673  0.162285
# LongB           0.146336  0.170062  0.035161  0.417261  0.028275  0.387689
# ThrB            0.347927 -0.320631 -0.007894  0.278794  0.258641  0.630493
# ...

# %%
# heatmap으로 상관관계 시각화

plt.figure(figsize=(10, 10))
sns.heatmap(EPL_FW_corr_matrix)
plt.title('FW values Corr')
plt.show()

# %%
# 결과가 nan인 변수 제거

EPL_FW_df.drop('OwnG', axis=1, inplace=True)

# %%
# 수치형 데이터만 뽑아온다.

EPL_FW_numeric_df = EPL_FW_df.select_dtypes(['int64', 'float64'])

# %%
EPL_FW_corr_matrix = EPL_FW_numeric_df.corr()
EPL_FW_corr_matrix
# Out:
#              team_number       age      Apps      Mins   Assists      KeyP  \
# team_number     1.000000 -0.039337 -0.221772  0.185226 -0.106884  0.105643
# age            -0.039337  1.000000  0.283817  0.246644 -0.169598 -0.081000
# Apps           -0.221772  0.283817  1.000000  0.737170  0.663187  0.343151
# Mins            0.185226  0.246644  0.737170  1.000000  0.746252  0.725715
# Assists        -0.106884 -0.169598  0.663187  0.746252  1.000000  0.713043
# KeyP            0.105643 -0.081000  0.343151  0.725715  0.713043  1.000000
# AvgP            0.405567  0.105019  0.293567  0.769749  0.356478  0.684053
# PS%            -0.159963 -0.327415  0.094521  0.036759  0.227692  0.308032
# Crosses         0.238294  0.231986  0.294120  0.421784  0.033673  0.162285
# LongB           0.146336  0.170062  0.035161  0.417261  0.028275  0.387689
# ThrB            0.347927 -0.320631 -0.007894  0.278794  0.258641  0.630493
# ...

# %%
# heatmap으로 상관관계 시각화

plt.figure(figsize=(10, 10))
sns.heatmap(EPL_FW_corr_matrix)
plt.title('FW values Corr')
plt.show()

# %%
# Pts부분만 뽑아서 상관관계 확인

EPL_FW_corr_matrix_Pts = EPL_FW_corr_matrix[['Pts']]
EPL_FW_corr_matrix_Pts
# Out:
#                   Pts
# team_number -0.020777
# age         -0.119064
# Apps         0.354483
# Mins         0.360245
# Assists      0.388210
# KeyP         0.496470
# AvgP         0.247929
# PS%          0.540948
# Crosses      0.009272
# LongB        0.055242
# ThrB         0.323319
# Rating       0.624597
# Goals        0.643566
# Yel          0.336372
# Red         -0.159547
# SpG          0.558593
# AerialsWon  -0.103263
# MoM          0.546180
# Dribble      0.091442
# Fouled       0.175261
# Off          0.105997
# Disp        -0.037453
# UnsTch      -0.069801
# Tackles     -0.267164
# Inter        0.010045
# Fouls       -0.037213
# Offsides    -0.276505
# Clear       -0.283218
# Drb         -0.357617
# Blocks      -0.108221
# Pts          1.000000

# %%
# 내림차순 정렬 후 heatmap으로 시각화

EPL_FW_corr_matrix_Pts.sort_values('Pts', ascending=False, inplace=True)
plt.figure(figsize=(3, 10))
sns.heatmap(EPL_FW_corr_matrix_Pts, annot=True, fmt='.3f')
plt.show()
# Out:
# /var/folders/zt/1l6rrzf977nbpmcz1d2j0vd40000gn/T/ipykernel_72346/3386556046.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   EPL_FW_corr_matrix_Pts.sort_values('Pts', ascending=False, inplace=True)

# %%
# 상위 5개 변수 추출

# 결과분석
# Goals: 공격수에게 골은 당연한 지표
# Rating: 평점 -> 평점을 잘 받으면 역할을 잘 수행했다는 의미 -> 의미있는 지표
# SpG: 경기당 슈팅 횟수 -> 의미있는 지표
# Mom: MoM 선정 횟수 -> 의미있는 지표
# PS%: 패스 성공률 -> 음.. 조금 중요도는 낮을 것 같지만 의미있는 지표

# GK와 비교했을 때 전체적으로 정확한 지표들이 추출된 것 같다.

EPL_FW_corr_matrix_Pts.iloc[1:6].index.to_list()
# Out:
# ['Goals', 'Rating', 'SpG', 'MoM', 'PS%']

# %%
index_li = EPL_FW_corr_matrix_Pts.iloc[:11].index.tolist()
corr_li = EPL_FW_corr_matrix_Pts['Pts'].tolist()
for i in range(1, 11):
    print(f'{index_li[i]}: {corr_li[i]:.3f}')
    

# Goals: 0.644 Rating: 0.625 SpG: 0.559 MoM: 0.546 PS%: 0.541 KeyP: 0.496 Assists: 0.388 Mins: 0.360 Apps: 0.354 Yel: 0.336
# Out:
# Goals: 0.644
# Rating: 0.625
# SpG: 0.559
# MoM: 0.546
# PS%: 0.541
# KeyP: 0.496
# Assists: 0.388
# Mins: 0.360
# Apps: 0.354
# Yel: 0.336

# %% [markdown]
# # AM 포지션 데이터
# ## AM포지션에서 승리에 가장 큰 영향을 주는 변수 추출

# %%
EPL_AM_player_df.head()
# Out:
#           player_name  team_number             Team  age position  Apps  Mins  \
# 0          Harry Kane           30        Tottenham   29       AM    38  3408
# 1       Gabriel Jesus           13          Arsenal   26       AM    26  2075
# 2       Jack Grealish          167  Manchester City   27       AM    28  2064
# 3     Martin Ødegaard           13          Arsenal   24       AM    37  3149
# 4  Gabriel Martinelli           13          Arsenal   22       AM    36  2806
#
#    Assists  KeyP  AvgP  ...  Disp  UnsTch  Tackles  Inter  Fouls  Offsides  \
# 0        3   1.5  22.4  ...   1.5     1.9      0.4    0.1    0.8       0.1
# 1        6   1.2  25.9  ...   2.5     3.4      1.3    0.4    1.7       0.0
# 2        7   1.8  35.3  ...   1.0     1.3      0.9    0.3    1.0       0.0
# 3        7   2.1  45.6  ...   1.2     1.1      1.0    0.2    0.8       0.0
# 4        5   1.6  27.1  ...   1.6     2.3      0.9    0.3    1.1       0.0
#
#    Clear  Drb  Blocks  OwnG
# ...

# %%
EPL_AM_df = pd.merge(EPL_AM_player_df, EPL_Team_df[['Team', 'Pts']], on='Team', how='inner')

# %%
EPL_AM_df.columns
# Out:
# Index(['player_name', 'team_number', 'Team', 'age', 'position', 'Apps', 'Mins',
#        'Assists', 'KeyP', 'AvgP', 'PS%', 'Crosses', 'LongB', 'ThrB', 'Rating',
#        'Goals', 'Yel', 'Red', 'SpG', 'AerialsWon', 'MoM', 'Dribble', 'Fouled',
#        'Off', 'Disp', 'UnsTch', 'Tackles', 'Inter', 'Fouls', 'Offsides',
#        'Clear', 'Drb', 'Blocks', 'OwnG', 'Pts'],
#       dtype='object')

# %%
# 수치형 데이터만 뽑아온다.

EPL_AM_numeric_df = EPL_AM_df.select_dtypes(['int64', 'float64'])

# %%
EPL_AM_corr_matrix = EPL_AM_numeric_df.corr()
EPL_AM_corr_matrix
# Out:
#              team_number       age      Apps      Mins   Assists      KeyP  \
# team_number     1.000000  0.054540 -0.012491 -0.107838 -0.044672 -0.023477
# age             0.054540  1.000000  0.231026  0.195660  0.097955  0.056544
# Apps           -0.012491  0.231026  1.000000  0.828421  0.441060  0.380609
# Mins           -0.107838  0.195660  0.828421  1.000000  0.589270  0.651979
# Assists        -0.044672  0.097955  0.441060  0.589270  1.000000  0.756727
# KeyP           -0.023477  0.056544  0.380609  0.651979  0.756727  1.000000
# AvgP           -0.097198  0.034531  0.372269  0.622092  0.561297  0.795213
# PS%             0.061486 -0.123448 -0.191102 -0.119579  0.009245  0.220320
# Crosses         0.187308 -0.100743  0.346398  0.441615  0.561083  0.654988
# LongB           0.037823  0.112818  0.260972  0.450477  0.419377  0.681389
# ThrB           -0.017317  0.093285  0.252499  0.452589  0.493007  0.629942
# ...

# %%
# heatmap으로 상관관계 시각화

plt.figure(figsize=(10, 10))
sns.heatmap(EPL_AM_corr_matrix)
plt.title('AM values Corr')
plt.show()

# %%
# Pts부분만 뽑아서 상관관계 확인

EPL_AM_corr_matrix_Pts = EPL_AM_corr_matrix[['Pts']]
EPL_AM_corr_matrix_Pts
# Out:
#                   Pts
# team_number  0.041889
# age         -0.131515
# Apps        -0.118074
# Mins        -0.005265
# Assists      0.225793
# KeyP         0.212702
# AvgP         0.335327
# PS%          0.443118
# Crosses     -0.142141
# LongB        0.172339
# ThrB         0.174752
# Rating       0.498307
# Goals        0.334774
# Yel         -0.121058
# Red         -0.046060
# SpG          0.272537
# AerialsWon  -0.050542
# MoM          0.286377
# Dribble      0.200541
# Fouled      -0.009323
# Off         -0.064904
# Disp        -0.049917
# UnsTch      -0.036554
# Tackles     -0.111497
# Inter       -0.101878
# Fouls       -0.107661
# Offsides    -0.135716
# Clear       -0.165843
# Drb         -0.021563
# Blocks      -0.137564
# OwnG         0.069532
# Pts          1.000000

# %%
# 내림차순 정렬 후 heatmap으로 시각화
# 전체적으로 Pts와의 상관관계가 조금 낮은 상태..

EPL_AM_corr_matrix_Pts.sort_values('Pts', ascending=False, inplace=True)
plt.figure(figsize=(3, 10))
sns.heatmap(EPL_AM_corr_matrix_Pts, annot=True, fmt='.3f')
plt.show()
# Out:
# /var/folders/zt/1l6rrzf977nbpmcz1d2j0vd40000gn/T/ipykernel_72346/1071266647.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   EPL_AM_corr_matrix_Pts.sort_values('Pts', ascending=False, inplace=True)

# %%
# 상위 5개 변수 추출

# 결과분석
# Rating: 평점 -> 평점을 잘 받으면 역할을 잘 수행했다는 의미 -> 의미있는 지표
# PS%: 패스 성공률 -> 음.. 조금 중요도는 낮을 것 같지만 의미있는 지표
# AvgP: 경기당 패스 횟수 -> 의미있는 지표
# Goals: 골 성공 횟수 -> 공격형 미드필더에게 의미있는 지표 -> 그러나 FW만큼 상관관계가 크지는 않다.
# MoM: 의미있는 지표

# FW와 비교했을 때 상대적으로 지표들이 Pts와 상관관계가 높지 않다.
# 선수 풀이 작아서 그런건지 아니면 롤의 서폿처럼 승리에 큰 기여 없는 도구인건지?ㅎ

EPL_AM_corr_matrix_Pts.iloc[1:6].index.to_list()
# Out:
# ['Rating', 'PS%', 'AvgP', 'Goals', 'MoM']

# %%
index_li = EPL_AM_corr_matrix_Pts.iloc[:11].index.tolist()
corr_li = EPL_AM_corr_matrix_Pts['Pts'].tolist()
for i in range(1, 11):
    print(f'{index_li[i]}: {corr_li[i]:.3f}')
    
# Rating: 0.498 PS%: 0.443 AvgP: 0.335 Goals: 0.335 MoM: 0.286 SpG: 0.273 Assists: 0.226 KeyP: 0.213 Dribble: 0.201 ThrB: 0.175
# Out:
# Rating: 0.498
# PS%: 0.443
# AvgP: 0.335
# Goals: 0.335
# MoM: 0.286
# SpG: 0.273
# Assists: 0.226
# KeyP: 0.213
# Dribble: 0.201
# ThrB: 0.175

# %% [markdown]
# # M 포지션 데이터
# ## M포지션에서 승리에 가장 큰 영향을 주는 변수 추출

# %%
EPL_M_player_df.head()
# Out:
#            player_name  team_number               Team  age position  Apps  \
# 0      Kevin De Bruyne          167    Manchester City   31        M    32
# 1      Bruno Fernandes           32  Manchester United   28        M    37
# 2          Solly March          211           Brighton   28        M    33
# 3       Ilkay Gündogan          167    Manchester City   32        M    31
# 4  Alexis Mac Allister          211           Brighton   24        M    35
#
#    Mins  Assists  KeyP  AvgP  ...  Disp  UnsTch  Tackles  Inter  Fouls  \
# 0  2425       16   3.1  42.4  ...   0.9     1.3      0.9    0.3    0.6
# 1  3320        8   3.2  50.1  ...   1.1     1.1      1.8    0.7    1.1
# 2  2728        7   2.0  33.4  ...   1.0     1.7      1.6    0.7    1.4
# 3  2359        4   1.2  49.7  ...   0.9     0.9      1.0    0.6    0.7
# 4  2886        2   1.3  51.5  ...   1.0     1.3      2.0    0.6    1.0
#
#    Offsides  Clear  Drb  Blocks  OwnG
# 0       0.0    0.3  0.8     0.1     0
# ...

# %%
EPL_M_df = pd.merge(EPL_M_player_df, EPL_Team_df[['Team', 'Pts']], on='Team', how='inner')

# %%
EPL_M_df.columns
# Out:
# Index(['player_name', 'team_number', 'Team', 'age', 'position', 'Apps', 'Mins',
#        'Assists', 'KeyP', 'AvgP', 'PS%', 'Crosses', 'LongB', 'ThrB', 'Rating',
#        'Goals', 'Yel', 'Red', 'SpG', 'AerialsWon', 'MoM', 'Dribble', 'Fouled',
#        'Off', 'Disp', 'UnsTch', 'Tackles', 'Inter', 'Fouls', 'Offsides',
#        'Clear', 'Drb', 'Blocks', 'OwnG', 'Pts'],
#       dtype='object')

# %%
# 수치형 데이터만 뽑아온다.

EPL_M_numeric_df = EPL_M_df.select_dtypes(['int64', 'float64'])

# %%
EPL_M_corr_matrix = EPL_M_numeric_df.corr()
EPL_M_corr_matrix
# Out:
#              team_number       age      Apps      Mins   Assists      KeyP  \
# team_number     1.000000 -0.043232  0.149421  0.046824  0.082504  0.035328
# age            -0.043232  1.000000 -0.050490 -0.077998  0.165879  0.103990
# Apps            0.149421 -0.050490  1.000000  0.820526  0.327471  0.498618
# Mins            0.046824 -0.077998  0.820526  1.000000  0.480254  0.675159
# Assists         0.082504  0.165879  0.327471  0.480254  1.000000  0.793291
# KeyP            0.035328  0.103990  0.498618  0.675159  0.793291  1.000000
# AvgP           -0.021040  0.069784  0.424099  0.667798  0.386679  0.509320
# PS%             0.034102  0.016582 -0.004131  0.009505 -0.074967 -0.131707
# Crosses         0.180635  0.090841  0.381140  0.490721  0.711733  0.731364
# LongB           0.094323  0.023993  0.507664  0.661447  0.488040  0.532889
# ThrB           -0.033137  0.152626  0.258902  0.384574  0.585211  0.690034
# ...

# %%
# heatmap으로 상관관계 시각화

plt.figure(figsize=(10, 10))
sns.heatmap(EPL_M_corr_matrix)
plt.title('M values Corr')
plt.show()

# %%
# Pts부분만 뽑아서 상관관계 확인

EPL_M_corr_matrix_Pts = EPL_M_corr_matrix[['Pts']]
EPL_M_corr_matrix_Pts
# Out:
#                   Pts
# team_number  0.158221
# age          0.150054
# Apps         0.270595
# Mins         0.187844
# Assists      0.628312
# KeyP         0.403389
# AvgP         0.312193
# PS%          0.264775
# Crosses      0.213236
# LongB        0.355201
# ThrB         0.556818
# Rating       0.474179
# Goals        0.210943
# Yel         -0.085677
# Red         -0.128539
# SpG          0.332909
# AerialsWon  -0.278535
# MoM          0.421469
# Dribble      0.050521
# Fouled       0.087654
# Off          0.064962
# Disp         0.177790
# UnsTch      -0.026451
# Tackles     -0.132666
# Inter       -0.148008
# Fouls        0.023558
# Offsides    -0.065924
# Clear       -0.238645
# Drb          0.066543
# Blocks      -0.144412
# OwnG        -0.195343
# Pts          1.000000

# %%
# 내림차순 정렬 후 heatmap으로 시각화
# 전체적으로 Pts와의 상관관계가 조금 낮은 상태..

EPL_M_corr_matrix_Pts.sort_values('Pts', ascending=False, inplace=True)
plt.figure(figsize=(3, 10))
sns.heatmap(EPL_M_corr_matrix_Pts, annot=True, fmt='.3f')
plt.show()
# Out:
# /var/folders/zt/1l6rrzf977nbpmcz1d2j0vd40000gn/T/ipykernel_72346/1808164691.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   EPL_M_corr_matrix_Pts.sort_values('Pts', ascending=False, inplace=True)

# %%
# 상위 5개 변수 추출

# 결과분석
# Assists: 의미있는 지표
# ThrB: 의미있는 지표
# Rating: 의미있는 지표
# Mom: 의미있는 지표
# KeyP: 의미있는 지표

# FW와 비교했을 때 상대적으로 지표들이 Pts와 상관관계가 높지 않다.
# 그러나 AM과 비교했을 때는 상대적으로 상관관계가 높다.
# AM 선수 풀이 작아서 상관관계가 낮게 나온 것 같다.

EPL_M_corr_matrix_Pts.iloc[1:6].index.to_list()
# Out:
# ['Assists', 'ThrB', 'Rating', 'MoM', 'KeyP']

# %%
index_li = EPL_M_corr_matrix_Pts.iloc[:11].index.tolist()
corr_li = EPL_M_corr_matrix_Pts['Pts'].tolist()
for i in range(1, 11):
    print(f'{index_li[i]}: {corr_li[i]:.3f}')
    
# Assists: 0.628 ThrB: 0.557 Rating: 0.474 MoM: 0.421 KeyP: 0.403 LongB: 0.355 SpG: 0.333 AvgP: 0.312 Apps: 0.271 PS%: 0.265
# Out:
# Assists: 0.628
# ThrB: 0.557
# Rating: 0.474
# MoM: 0.421
# KeyP: 0.403
# LongB: 0.355
# SpG: 0.333
# AvgP: 0.312
# Apps: 0.271
# PS%: 0.265

# %% [markdown]
# # DM 포지션 데이터
# ## DM포지션에서 승리에 가장 큰 영향을 주는 변수 추출

# %%
EPL_DM_player_df.head()
# Out:
#        player_name  team_number               Team  age position  Apps  Mins  \
# 0  Bruno Guimarães           23          Newcastle   25       DM    32  2735
# 1         Casemiro           32  Manchester United   31       DM    28  2126
# 2      Rúben Neves          161             Wolves   26       DM    35  3022
# 3    João Palhinha          170             Fulham   27       DM    35  3113
# 4   Moisés Caicedo          211           Brighton   21       DM    37  3141
#
#    Assists  KeyP  AvgP  ...  Disp  UnsTch  Tackles  Inter  Fouls  Offsides  \
# 0        5   1.3  51.0  ...   1.9     1.4      2.4    1.1    1.4       0.0
# 1        3   1.0  50.4  ...   0.5     0.6      3.2    1.2    1.7       0.0
# 2        1   0.9  58.1  ...   0.4     0.6      2.3    1.4    1.1       0.0
# 3        0   0.2  36.2  ...   0.8     1.1      4.2    1.3    1.4       0.0
# 4        1   1.2  59.7  ...   0.6     1.1      2.7    1.5    1.8       0.0
#
#    Clear  Drb  Blocks  OwnG
# ...

# %%
EPL_DM_df = pd.merge(EPL_DM_player_df, EPL_Team_df[['Team', 'Pts']], on='Team', how='inner')

# %%
EPL_DM_df.columns
# Out:
# Index(['player_name', 'team_number', 'Team', 'age', 'position', 'Apps', 'Mins',
#        'Assists', 'KeyP', 'AvgP', 'PS%', 'Crosses', 'LongB', 'ThrB', 'Rating',
#        'Goals', 'Yel', 'Red', 'SpG', 'AerialsWon', 'MoM', 'Dribble', 'Fouled',
#        'Off', 'Disp', 'UnsTch', 'Tackles', 'Inter', 'Fouls', 'Offsides',
#        'Clear', 'Drb', 'Blocks', 'OwnG', 'Pts'],
#       dtype='object')

# %%
# 수치형 데이터만 뽑아온다.

EPL_DM_numeric_df = EPL_DM_df.select_dtypes(['int64', 'float64'])

# %%
EPL_DM_corr_matrix = EPL_DM_numeric_df.corr()
EPL_DM_corr_matrix
# Out:
#              team_number       age      Apps      Mins   Assists      KeyP  \
# team_number     1.000000  0.153230  0.010983  0.012218 -0.293698 -0.240512
# age             0.153230  1.000000 -0.166760 -0.094270  0.131372 -0.187665
# Apps            0.010983 -0.166760  1.000000  0.932012  0.238477  0.500828
# Mins            0.012218 -0.094270  0.932012  1.000000  0.219479  0.531867
# Assists        -0.293698  0.131372  0.238477  0.219479  1.000000  0.515449
# KeyP           -0.240512 -0.187665  0.500828  0.531867  0.515449  1.000000
# AvgP           -0.061737 -0.014198  0.448280  0.616177  0.117361  0.765695
# PS%            -0.008843 -0.518594 -0.052358  0.096909 -0.337221  0.222208
# Crosses        -0.050662  0.147446  0.499665  0.434140  0.205196  0.512396
# LongB           0.034102  0.134954  0.419065  0.534620  0.098131  0.560720
# ThrB           -0.474473  0.012626  0.201950  0.288484  0.570325  0.807224
# ...

# %%
# heatmap으로 상관관계 시각화

plt.figure(figsize=(10, 10))
sns.heatmap(EPL_DM_corr_matrix)
plt.title('DM values Corr')
plt.show()

# %%
# Pts부분만 뽑아서 상관관계 확인

EPL_DM_corr_matrix_Pts = EPL_DM_corr_matrix[['Pts']]
EPL_DM_corr_matrix_Pts
# Out:
#                   Pts
# team_number  0.044458
# age          0.171655
# Apps         0.072353
# Mins         0.056795
# Assists      0.484696
# KeyP         0.345136
# AvgP         0.279212
# PS%          0.006090
# Crosses     -0.061865
# LongB        0.193652
# ThrB         0.412220
# Rating       0.503820
# Goals        0.358554
# Yel         -0.188509
# Red          0.289496
# SpG          0.109489
# AerialsWon  -0.003871
# MoM          0.343280
# Dribble      0.090855
# Fouled       0.202906
# Off          0.227143
# Disp         0.216203
# UnsTch       0.089649
# Tackles      0.081954
# Inter       -0.105852
# Fouls        0.054788
# Offsides    -0.236953
# Clear       -0.149725
# Drb          0.149229
# Blocks      -0.360363
# OwnG         0.053072
# Pts          1.000000

# %%
# 내림차순 정렬 후 heatmap으로 시각화
# 전체적으로 Pts와의 상관관계가 조금 낮은 상태..

EPL_DM_corr_matrix_Pts.sort_values('Pts', ascending=False, inplace=True)
plt.figure(figsize=(3, 10))
sns.heatmap(EPL_DM_corr_matrix_Pts, annot=True, fmt='.3f')
plt.show()
# Out:
# /var/folders/zt/1l6rrzf977nbpmcz1d2j0vd40000gn/T/ipykernel_72346/2836490607.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   EPL_DM_corr_matrix_Pts.sort_values('Pts', ascending=False, inplace=True)

# %%
# 상위 5개 변수 추출

# 결과분석
# Rating: 평점 -> 평점을 잘 받으면 역할을 잘 수행했다는 의미 -> 의미있는 지표
# Assists: 의미있는 지표
# ThrB: 의미있는 지표
# Goals: 음... 조금 애매하다
# KeyP: 의미있는 지표

# FW와 비교했을 때 상대적으로 지표들이 Pts와 상관관계가 높지 않다.
# AM이랑 비슷 -> 선수풀이 작아서 그런듯


EPL_DM_corr_matrix_Pts.iloc[1:6].index.to_list()
# Out:
# ['Rating', 'Assists', 'ThrB', 'Goals', 'KeyP']

# %%
index_li = EPL_DM_corr_matrix_Pts.iloc[:11].index.tolist()
corr_li = EPL_DM_corr_matrix_Pts['Pts'].tolist()
for i in range(1, 11):
    print(f'{index_li[i]}: {corr_li[i]:.3f}')
    
# Rating: 0.504 Assists: 0.485 ThrB: 0.412 Goals: 0.359 KeyP: 0.345 MoM: 0.343 Red: 0.289 AvgP: 0.279 Off: 0.227 Disp: 0.216
# Out:
# Rating: 0.504
# Assists: 0.485
# ThrB: 0.412
# Goals: 0.359
# KeyP: 0.345
# MoM: 0.343
# Red: 0.289
# AvgP: 0.279
# Off: 0.227
# Disp: 0.216

# %% [markdown]
# # D 포지션 데이터
# ## D포지션에서 승리에 가장 큰 영향을 주는 변수 추출

# %%
EPL_D_player_df.head()
# Out:
#               player_name  team_number             Team  age position  Apps  \
# 0         Kieran Trippier           23        Newcastle   32        D    38
# 1             Bukayo Saka           13          Arsenal   21        D    38
# 2                   Rodri          167  Manchester City   27        D    36
# 3  Trent Alexander-Arnold           26        Liverpool   24        D    37
# 4           Ethan Pinnock          189        Brentford   30        D    30
#
#    Mins  Assists  KeyP  AvgP  ...  Disp  UnsTch  Tackles  Inter  Fouls  \
# 0  3348        7   2.9  54.3  ...   0.2     0.7      1.9    1.1    1.3
# 1  3195       11   2.0  32.5  ...   1.6     2.1      1.7    0.4    1.1
# 2  2921        6   0.9  82.7  ...   0.5     0.6      1.9    0.9    1.3
# 3  2932        9   1.9  62.4  ...   0.6     0.9      1.5    1.2    0.6
# 4  2700        0   0.3  36.4  ...   0.2     0.2      1.7    1.2    0.2
#
#    Offsides  Clear  Drb  Blocks  OwnG
# 0       0.3    2.0  1.2     0.4     1
# ...

# %%
EPL_D_df = pd.merge(EPL_D_player_df, EPL_Team_df[['Team', 'Pts']], on='Team', how='inner')

# %%
EPL_D_df.columns
# Out:
# Index(['player_name', 'team_number', 'Team', 'age', 'position', 'Apps', 'Mins',
#        'Assists', 'KeyP', 'AvgP', 'PS%', 'Crosses', 'LongB', 'ThrB', 'Rating',
#        'Goals', 'Yel', 'Red', 'SpG', 'AerialsWon', 'MoM', 'Dribble', 'Fouled',
#        'Off', 'Disp', 'UnsTch', 'Tackles', 'Inter', 'Fouls', 'Offsides',
#        'Clear', 'Drb', 'Blocks', 'OwnG', 'Pts'],
#       dtype='object')

# %%
# 수치형 데이터만 뽑아온다.

EPL_D_numeric_df = EPL_D_df.select_dtypes(['int64', 'float64'])

# %%
EPL_D_corr_matrix = EPL_D_numeric_df.corr()
EPL_D_corr_matrix
# Out:
#              team_number       age      Apps      Mins   Assists      KeyP  \
# team_number     1.000000 -0.005744  0.073898  0.106734 -0.098519 -0.103640
# age            -0.005744  1.000000  0.196334  0.116242  0.017634  0.044245
# Apps            0.073898  0.196334  1.000000  0.865676  0.394872  0.284773
# Mins            0.106734  0.116242  0.865676  1.000000  0.334067  0.247694
# Assists        -0.098519  0.017634  0.394872  0.334067  1.000000  0.766002
# KeyP           -0.103640  0.044245  0.284773  0.247694  0.766002  1.000000
# AvgP            0.000369  0.107607  0.284730  0.528781  0.124416  0.015731
# PS%            -0.102224 -0.029425  0.000977  0.117228 -0.018391 -0.136066
# Crosses        -0.073481  0.057771  0.201146  0.130340  0.611065  0.840143
# LongB           0.029913  0.153942  0.327075  0.523202  0.098737 -0.001113
# ThrB           -0.068137  0.008197  0.184097  0.181878  0.316469  0.392305
# ...

# %%
# heatmap으로 상관관계 시각화

plt.figure(figsize=(10, 10))
sns.heatmap(EPL_D_corr_matrix)
plt.title('D values Corr')
plt.show()

# %%
# Pts부분만 뽑아서 상관관계 확인

EPL_D_corr_matrix_Pts = EPL_D_corr_matrix[['Pts']]
EPL_D_corr_matrix_Pts
# Out:
#                   Pts
# team_number -0.017758
# age          0.091936
# Apps         0.198898
# Mins         0.082391
# Assists      0.280700
# KeyP         0.165100
# AvgP         0.356845
# PS%          0.463005
# Crosses      0.068988
# LongB        0.153821
# ThrB         0.289169
# Rating       0.368527
# Goals        0.173057
# Yel         -0.075483
# Red         -0.163609
# SpG          0.196274
# AerialsWon  -0.029699
# MoM          0.214525
# Dribble      0.010992
# Fouled      -0.033008
# Off          0.061065
# Disp        -0.108957
# UnsTch      -0.096270
# Tackles     -0.291802
# Inter       -0.346005
# Fouls       -0.100908
# Offsides     0.100372
# Clear       -0.261513
# Drb         -0.223505
# Blocks      -0.267814
# OwnG        -0.094379
# Pts          1.000000

# %%
# 내림차순 정렬 후 heatmap으로 시각화
# 전체적으로 Pts와의 상관관계가 조금 낮은 상태..

EPL_D_corr_matrix_Pts.sort_values('Pts', ascending=False, inplace=True)
plt.figure(figsize=(3, 10))
sns.heatmap(EPL_D_corr_matrix_Pts, annot=True, fmt='.3f')
plt.show()
# Out:
# /var/folders/zt/1l6rrzf977nbpmcz1d2j0vd40000gn/T/ipykernel_72346/2455717194.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   EPL_D_corr_matrix_Pts.sort_values('Pts', ascending=False, inplace=True)

# %%
# 상위 5개 변수 추출

# 결과분석
# PS%: 의미있는 지표
# Rating: 평점 -> 평점을 잘 받으면 역할을 잘 수행했다는 의미 -> 의미있는 지표
# AvgP: 의미있는 지표
# ThrB: 의미있는 지표
# Assists: 음... 애매

# FW와 비교했을 때 상대적으로 지표들이 Pts와 상관관계가 높지 않다.
# 선수가 많은데도 상관관계가 적다... -> 도구..?


EPL_D_corr_matrix_Pts.iloc[1:6].index.to_list()
# Out:
# ['PS%', 'Rating', 'AvgP', 'ThrB', 'Assists']

# %% [markdown]
# # 결과 분석
#
# ### FW, M 포지션을 제외하고는 상관관계가 작다.
# - 선수 풀이 작아서?
# - 실제로 경기 결과에 큰 영향을 주지 못하는 포지션이라서?
# - 포지션에 대한 이해, 지표가 가지는 의미 이해가 필요할 듯 하다.

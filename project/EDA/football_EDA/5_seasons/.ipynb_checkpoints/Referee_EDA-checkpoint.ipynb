# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %% [markdown]
# # 데이터 가져오기

# %% [markdown]
# ## EPL 심판 데이터

# %%
EPL_referee_path = './EPL/EPL_Referee/'
EPL_referee_path_list = os.listdir(EPL_referee_path)
EPL_referee_path_list.sort()
EPL_referee_path_list
# Out:
# ['18_19_EPL_Referee_Stats.csv',
#  '19_20_EPL_Referee_Stats.csv',
#  '20_21_EPL_Referee_Stats.csv',
#  '21_22_EPL_Referee_Stats.csv',
#  '22_23_EPL_Referee_Stats.csv']

# %%
EPL_referee_data_list = []
for path in EPL_referee_path_list:
    tmp = pd.read_csv(EPL_referee_path + path)
    tmp.drop('Unnamed: 0', axis=1, inplace=True)
    EPL_referee_data_list.append(tmp)

# %%
EPL_referee_data_list[0]
# Out:
#                Name  Apps  Fouls_pg  Fouls_Tackles  Pen_pg  Yel_pg  Yel  \
# 0    Anthony Taylor    32     21.34           0.64    0.34    3.19  102
# 1    Michael Oliver    30     21.27           0.61    0.30    2.77   83
# 2         Mike Dean    29     20.69           0.60    0.28    4.45  129
# 3   Martin Atkinson    29     20.79           0.63    0.21    3.14   91
# 4     Jonathan Moss    27     22.26           0.70    0.37    3.44   93
# 5    Andre Marriner    27     17.56           0.49    0.11    2.70   73
# 6      Kevin Friend    27     20.44           0.61    0.30    3.41   92
# 7      Craig Pawson    26     20.00           0.56    0.31    3.50   91
# 8      Paul Tierney    24     20.29           0.59    0.21    3.42   82
# 9    Chris Kavanagh    24     19.29           0.55    0.21    3.08   74
# 10   Stuart Attwell    20     18.00           0.57    0.30    3.15   63
# 11        Lee Mason    19     22.84           0.69    0.21    3.32   63
# ...

# %%
EPL_referee = pd.concat([EPL_referee_data_list[0], EPL_referee_data_list[1], EPL_referee_data_list[2], EPL_referee_data_list[3], EPL_referee_data_list[4]])
EPL_referee.reset_index(inplace=True)
EPL_referee.drop('index', axis=1, inplace=True)
EPL_referee
# Out:
#                 Name  Apps  Fouls_pg  Fouls_Tackles  Pen_pg  Yel_pg  Yel  \
# 0     Anthony Taylor    32     21.34           0.64    0.34    3.19  102
# 1     Michael Oliver    30     21.27           0.61    0.30    2.77   83
# 2          Mike Dean    29     20.69           0.60    0.28    4.45  129
# 3    Martin Atkinson    29     20.79           0.63    0.21    3.14   91
# 4      Jonathan Moss    27     22.26           0.70    0.37    3.44   93
# ..               ...   ...       ...            ...     ...     ...  ...
# 98   Tony Harrington     6     22.00           0.54    0.33    3.83   23
# 99       Darren Bond     4     19.75           0.62    0.00    4.00   16
# 100     Tim Robinson     2     28.50           0.97    0.00    4.50    9
# 101    Robert Madley     1     27.00           0.79    0.00    6.00    6
# 102       Josh Smith     1     25.00           0.89    1.00    3.00    3
#
#      Red_pg  Red
# 0      0.03    1
# 1      0.23    7
# 2      0.34   10
# 3      0.03    1
# ...

# %%
#EPL_referee.to_csv('EPL_referee_5seasons.csv')

# %% [markdown]
# ## Bundesliga 심판 데이터

# %%
BL_referee_path = './Bundesliga/BL_Referee/'
BL_referee_path_list = os.listdir(BL_referee_path)
BL_referee_path_list.sort()
BL_referee_path_list
# Out:
# ['18_19_BL_Referee_Stats.csv',
#  '19_20_BL_Referee_Stats.csv',
#  '20_21_BL_Referee_Stats.csv',
#  '21_22_BL_Referee_Stats.csv',
#  '22_23_BL_Referee_Stats.csv']

# %%
BL_referee_data_list = []
for path in BL_referee_path_list:
    tmp = pd.read_csv(BL_referee_path + path)
    tmp.drop('Unnamed: 0', axis=1, inplace=True)
    BL_referee_data_list.append(tmp)

# %%
BL_referee_data_list[0]
# Out:
#                       Name  Apps  Fouls_pg  Fouls_Tackles  Pen_pg  Yel_pg  \
# 0             Manuel Gräfe    18     18.61           0.52    0.17    2.44
# 1            Deniz Aytekin    17     22.71           0.62    0.29    3.76
# 2             Felix Zwayer    16     21.00           0.60    0.38    3.50
# 3          Dr. Felix Brych    16     25.94           0.74    0.38    3.63
# 4        Christian Dingert    15     23.87           0.72    0.53    3.53
# 5              Marco Fritz    15     25.20           0.71    0.27    3.67
# 6           Tobias Stieler    14     24.71           0.79    0.43    2.57
# 7           Daniel Siebert    14     24.79           0.75    0.14    3.00
# 8         Sascha Stegemann    14     25.64           0.83    0.29    4.14
# 9              Tobias Welz    14     25.79           0.79    0.50    3.43
# 10         Bastian Dankert    13     27.69           0.91    0.23    3.77
# 11         Robert Hartmann    13     24.08           0.78    0.31    2.69
# ...

# %%
BL_referee = pd.concat([BL_referee_data_list[0], BL_referee_data_list[1], BL_referee_data_list[2], BL_referee_data_list[3], BL_referee_data_list[4]])
BL_referee.reset_index(inplace=True)
BL_referee.drop('index', axis=1, inplace=True)
BL_referee
# Out:
#                   Name  Apps  Fouls_pg  Fouls_Tackles  Pen_pg  Yel_pg  Yel  \
# 0         Manuel Gräfe    18     18.61           0.52    0.17    2.44   44
# 1        Deniz Aytekin    17     22.71           0.62    0.29    3.76   64
# 2         Felix Zwayer    16     21.00           0.60    0.38    3.50   56
# 3      Dr. Felix Brych    16     25.94           0.74    0.38    3.63   58
# 4    Christian Dingert    15     23.87           0.72    0.53    3.53   53
# ..                 ...   ...       ...            ...     ...     ...  ...
# 121    Patrick Ittrich     9     25.33           0.91    0.33    3.44   31
# 122     Tobias Reichel     9     28.00           0.93    0.11    3.44   31
# 123     Benjamin Brand     6     29.83           1.03    0.17    4.67   28
# 124        Timo Gerach     2     26.00           0.79    0.50    3.50    7
# 125        Robin Braun     1     22.00           0.79    1.00    3.00    3
#
#      Red_pg  Red
# 0      0.06    1
# 1      0.24    4
# ...

# %%
#BL_referee.to_csv('BL_referee_5seasons.csv')

# %% [markdown]
# ## Laliga 심판 데이터

# %%
LL_referee_path = './Laliga/LL_Referee/'
LL_referee_path_list = os.listdir(LL_referee_path)
LL_referee_path_list.sort()
LL_referee_path_list
# Out:
# ['18_19_LL_Referee_Stats.csv',
#  '19_20_LL_Referee_Stats.csv',
#  '20_21_LL_Referee_Stats.csv',
#  '21_22_LL_Referee_Stats.csv',
#  '22_23_LL_Referee_Stats.csv']

# %%
LL_referee_data_list = []
for path in LL_referee_path_list:
    tmp = pd.read_csv(LL_referee_path + path)
    tmp.drop('Unnamed: 0', axis=1, inplace=True)
    LL_referee_data_list.append(tmp)

# %%
LL_referee_data_list[0]
# Out:
#                       Name  Apps  Fouls_pg  Fouls_Tackles  Pen_pg  Yel_pg  \
# 0           X.E. Fernández    21     28.71           0.86    0.43    5.86
# 1          J.M.S. Martínez    21     29.86           0.97    0.38    5.57
# 2       R. deB. Bengoetxea    20     26.80           0.80    0.20    5.35
# 3            A.U. Mallenco    20     29.20           0.90    0.30    4.60
# 4       Mario Melero López    20     27.45           0.79    0.30    4.95
# 5             A.M.M. Lahoz    19     26.58           0.82    0.47    5.58
# 6            E.P. Iglesias    19     29.42           0.90    0.47    4.16
# 7            C.d.C. Grande    19     25.53           0.75    0.26    4.21
# 8          I.I. Villanueva    19     24.79           0.77    0.42    4.42
# 9        Jesús Gil Manzano    19     25.68           0.69    0.37    5.58
# 10   Juan Martínez Munuera    19     28.11           0.87    0.47    4.95
# 11    Santiago Jaime Latre    19     27.05           0.77    0.21    4.68
# ...

# %%
LL_referee = pd.concat([LL_referee_data_list[0], LL_referee_data_list[1], LL_referee_data_list[2], LL_referee_data_list[3], LL_referee_data_list[4]])
LL_referee.reset_index(inplace=True)
LL_referee.drop('index', axis=1, inplace=True)
LL_referee
# Out:
#                       Name  Apps  Fouls_pg  Fouls_Tackles  Pen_pg  Yel_pg  \
# 0           X.E. Fernández    21     28.71           0.86    0.43    5.86
# 1          J.M.S. Martínez    21     29.86           0.97    0.38    5.57
# 2       R. deB. Bengoetxea    20     26.80           0.80    0.20    5.35
# 3            A.U. Mallenco    20     29.20           0.90    0.30    4.60
# 4       Mario Melero López    20     27.45           0.79    0.30    4.95
# ..                     ...   ...       ...            ...     ...     ...
# 95          J.L.M. Montero    18     27.50           0.87    0.17    5.06
# 96            M.Á.O. Arias    17     24.24           0.74    0.41    4.29
# 97          G.C. Fernández    17     28.94           0.98    0.71    5.65
# 98   Javier Alberola Rojas    16     25.56           0.82    0.19    3.06
# 99  Valentín Pizarro Gómez    16     23.75           0.77    0.25    3.69
#
#     Yel  Red_pg  Red
# 0   123    0.29    6
# 1   117    0.24    5
# ...

# %%
#LL_referee.to_csv('LL_referee_5seasons.csv')

# %% [markdown]
# ## Ligue1 심판 데이터

# %%
L1_referee_path = './League1/L1_Referee/'
L1_referee_path_list = os.listdir(L1_referee_path)
L1_referee_path_list.sort()
L1_referee_path_list
# Out:
# ['18_19_L1_Referee_Stats.csv',
#  '19_20_L1_Referee_Stats.csv',
#  '20_21_L1_Referee_Stats.csv',
#  '21_22_L1_Referee_Stats.csv',
#  '22_23_L1_Referee_Stats.csv']

# %%
L1_referee_data_list = []
for path in L1_referee_path_list:
    tmp = pd.read_csv(L1_referee_path + path)
    tmp.drop('Unnamed: 0', axis=1, inplace=True)
    L1_referee_data_list.append(tmp)

# %%
L1_referee_data_list[0]
# Out:
#                   Name  Apps  Fouls_pg  Fouls_Tackles  Pen_pg  Yel_pg  Yel  \
# 0       Benoît Bastien    21     26.14           0.69    0.33    4.29   90
# 1       Antony Gautier    21     28.24           0.78    0.43    3.48   73
# 2       Jerome Brisard    20     27.40           0.80    0.25    3.35   67
# 3   Jerome Miguelgorry    20     24.70           0.69    0.45    3.70   74
# 4       Thomas Leonard    19     26.05           0.76    0.32    3.84   73
# 5      Frank Schneider    19     26.74           0.77    0.63    3.84   73
# 6    Hakim Ben El Hadj    19     27.63           0.78    0.26    3.26   62
# 7         Ruddy Buquet    19     25.79           0.71    0.47    4.16   79
# 8        Willy Delajod    19     27.84           0.71    0.58    3.16   60
# 9       Clément Turpin    19     26.05           0.65    0.58    3.11   59
# 10         Johan Hamel    18     24.39           0.71    0.39    3.00   54
# ...

# %%
L1_referee = pd.concat([L1_referee_data_list[0], L1_referee_data_list[1], L1_referee_data_list[2], L1_referee_data_list[3], L1_referee_data_list[4]])
L1_referee.reset_index(inplace=True)
L1_referee.drop('index', axis=1, inplace=True)
L1_referee
# Out:
#                    Name  Apps  Fouls_pg  Fouls_Tackles  Pen_pg  Yel_pg  Yel  \
# 0        Benoît Bastien    21     26.14           0.69    0.33    4.29   90
# 1        Antony Gautier    21     28.24           0.78    0.43    3.48   73
# 2        Jerome Brisard    20     27.40           0.80    0.25    3.35   67
# 3    Jerome Miguelgorry    20     24.70           0.69    0.45    3.70   74
# 4        Thomas Leonard    19     26.05           0.76    0.32    3.84   73
# ..                  ...   ...       ...            ...     ...     ...  ...
# 111   Hakim Ben El Hadj    15     23.73           0.65    0.20    3.80   57
# 112         Johan Hamel     8     21.13           0.55    0.63    2.88   23
# 113          Karim Abed     1     19.00           0.68    0.00    2.00    2
# 114     Gustavo Correia     1     24.00           0.62    2.00    3.00    3
# 115       M.B. Nogueira     1     30.00           0.67    0.00    4.00    4
#
#      Red_pg  Red
# 0      0.48   10
# 1      0.33    7
# ...

# %%
#L1_referee.to_csv('L1_referee_5seasons.csv')

# %% [markdown]
# ## SerieA 심판 데이터

# %%
SA_referee_path = './SerieA/SA_Referee/'
SA_referee_path_list = os.listdir(SA_referee_path)
SA_referee_path_list.sort()
SA_referee_path_list
# Out:
# ['18_19_SA_Referee_Stats.csv',
#  '19_20_SA_Referee_Stats.csv',
#  '20_21_SA_Referee_Stats.csv',
#  '21_22_SA_Referee_Stats.csv',
#  '22_23_SA_Referee_Stats.csv']

# %%
SA_referee_data_list = []
for path in SA_referee_path_list:
    tmp = pd.read_csv(SA_referee_path + path)
    tmp.drop('Unnamed: 0', axis=1, inplace=True)
    SA_referee_data_list.append(tmp)

# %%
SA_referee_data_list[0]
# Out:
#                       Name  Apps  Fouls_pg  Fouls_Tackles  Pen_pg  Yel_pg  \
# 0           Daniele Orsato    19     25.84           0.75    0.21    5.47
# 1           Daniele Doveri    19     27.11           0.84    0.37    4.47
# 2          Fabrizio Pasqua    19     24.11           0.70    0.11    3.47
# 3      Gianpaolo Calvarese    18     27.00           0.91    0.44    4.67
# 4         Piero Giacomelli    18     27.33           0.86    0.33    3.28
# 5             Paolo Valeri    17     26.71           0.89    0.47    4.24
# 6               Luca Banti    17     25.47           0.77    0.29    4.65
# 7   Paolo Silvio Mazzoleni    17     27.82           0.89    0.41    4.00
# 8           Rosario Abisso    17     22.76           0.66    0.35    4.06
# 9              Marco Guida    16     27.19           0.84    0.44    5.31
# 10         Gianluca Rocchi    16     29.69           0.88    0.63    4.88
# 11     Massimiliano Irrati    16     30.69           0.91    0.31    4.69
# ...

# %%
SA_referee = pd.concat([SA_referee_data_list[0], SA_referee_data_list[1], SA_referee_data_list[2], SA_referee_data_list[3], SA_referee_data_list[4]])
SA_referee.reset_index(inplace=True)
SA_referee.drop('index', axis=1, inplace=True)
SA_referee
# Out:
#                      Name  Apps  Fouls_pg  Fouls_Tackles  Pen_pg  Yel_pg  Yel  \
# 0          Daniele Orsato    19     25.84           0.75    0.21    5.47  104
# 1          Daniele Doveri    19     27.11           0.84    0.37    4.47   85
# 2         Fabrizio Pasqua    19     24.11           0.70    0.11    3.47   66
# 3     Gianpaolo Calvarese    18     27.00           0.91    0.44    4.67   84
# 4        Piero Giacomelli    18     27.33           0.86    0.33    3.28   59
# ..                    ...   ...       ...            ...     ...     ...  ...
# 206           Marco Serra     2     28.00           0.63    0.00    3.50    7
# 207     Daniele Perenzoni     2     28.50           0.83    0.50    4.00    8
# 208       Daniele Minelli     1     26.00           1.08    0.00    6.00    6
# 209       Daniele Paterna     1     30.00           1.11    0.00    6.00    6
# 210  Francesco Meraviglia     1     24.00           1.00    0.00    3.00    3
#
#      Red_pg  Red
# ...

# %%
#SA_referee.to_csv('SA_referee_5seasons.csv')

# %% [markdown]
# # EDA
# - 각 리그별 yellow 카드를 주는 횟수 -> 5년 총합, 5년 평균, 변화량
# - 각 리그별 Yel_pg값
#     - 데이터 추출 필요
# - 각 리그별 red 카드를 주는 횟수 -> 5년 총합, 5년 평균, 변화량
# - 각 리그별 Red_pg값
#     - 데이터 추출 필요
# - 각 리그별 fouls_pg값 5년 평균
# - 각 리그별 fouls_tackles값 -> 최대값, 통계 비교
#     - 요약 데이터 추출 필요
# - 각 리그별 Pen_pg값 -> 최대값, 통계 비교
#     - 요약 데이터 추출 필요

# %%
BL_referee = pd.read_csv('./referee/BL_referee_5seasons.csv')
EPL_referee = pd.read_csv('./referee/EPL_referee_5seasons.csv')
LL_referee = pd.read_csv('./referee/LL_referee_5seasons.csv')
L1_referee = pd.read_csv('./referee/L1_referee_5seasons.csv')
SA_referee = pd.read_csv('./referee/SA_referee_5seasons.csv')

# %%
BL_referee.drop('Unnamed: 0', axis=1, inplace=True)
EPL_referee.drop('Unnamed: 0', axis=1, inplace=True)
LL_referee.drop('Unnamed: 0', axis=1, inplace=True)
L1_referee.drop('Unnamed: 0', axis=1, inplace=True)
SA_referee.drop('Unnamed: 0', axis=1, inplace=True)

# %% [markdown]
# ## Yellow

# %%
Yellow_tmp = []
Yellow_tmp.append(BL_referee['Yel'].sum())
Yellow_tmp.append(EPL_referee['Yel'].sum())
Yellow_tmp.append(LL_referee['Yel'].sum())
Yellow_tmp.append(L1_referee['Yel'].sum())
Yellow_tmp.append(SA_referee['Yel'].sum())

Yellow_df = pd.DataFrame(Yellow_tmp, index=['BL', 'EPL', 'LL', 'L1', 'SA'], columns=['Yellow'])
Yellow_df.reset_index(inplace=True)
Yellow_df.columns = ['League', 'Yellow']
Yellow_df
# Out:
#   League  Yellow
# 0     BL    5521
# 1    EPL    6265
# 2     LL    9095
# 3     L1    6414
# 4     SA    8474

# %%
plt.figure(figsize=(8, 5))
sns.barplot(data=Yellow_df, x='League', y='Yellow')
plt.grid(True)

# %% [markdown]
# ## Yellow mean

# %%
Yellow_mean_tmp = []
Yellow_mean_tmp.append(BL_referee['Yel'].sum()/5)
Yellow_mean_tmp.append(EPL_referee['Yel'].sum()/5)
Yellow_mean_tmp.append(LL_referee['Yel'].sum()/5)
Yellow_mean_tmp.append(L1_referee['Yel'].sum()/5)
Yellow_mean_tmp.append(SA_referee['Yel'].sum()/5)

Yellow_mean_df = pd.DataFrame(Yellow_tmp, index=['BL', 'EPL', 'LL', 'L1', 'SA'], columns=['Yellow_mean'])
Yellow_mean_df.reset_index(inplace=True)
Yellow_mean_df.columns = ['League', 'Yellow_mean']
Yellow_mean_df
# Out:
#   League  Yellow_mean
# 0     BL         5521
# 1    EPL         6265
# 2     LL         9095
# 3     L1         6414
# 4     SA         8474

# %%
plt.figure(figsize=(8, 5))
sns.barplot(data=Yellow_mean_df, x='League', y='Yellow_mean')
plt.grid(True)

# %% [markdown]
# ## 각 리그 Yellow 값 변화

# %%
BL_Yellow_trend = []

for data in BL_referee_data_list:
    BL_Yellow_trend.append(data['Yel'].sum())

BL_Yellow_trend_df = pd.DataFrame(BL_Yellow_trend,index=['18-19', '19-20', '20-21', '21-22', '22-23'])
BL_Yellow_trend_df.reset_index(inplace=True)
BL_Yellow_trend_df.columns = ['Season', 'Yellow']
BL_Yellow_trend_df
# Out:
#   Season  Yellow
# 0  18-19    1014
# 1  19-20    1154
# 2  20-21    1081
# 3  21-22    1052
# 4  22-23    1220

# %%
plt.figure(figsize=(8, 5))
plt.plot(BL_Yellow_trend_df['Season'], BL_Yellow_trend_df['Yellow'], marker='o', linestyle='-', color='b')
plt.ylim([500, 2000])
plt.grid(True)

# %%
EPL_Yellow_trend = []

for data in EPL_referee_data_list:
    EPL_Yellow_trend.append(data['Yel'].sum())

EPL_Yellow_trend_df = pd.DataFrame(EPL_Yellow_trend,index=['18-19', '19-20', '20-21', '21-22', '22-23'])
EPL_Yellow_trend_df.reset_index(inplace=True)
EPL_Yellow_trend_df.columns = ['Season', 'Yellow']
EPL_Yellow_trend_df
# Out:
#   Season  Yellow
# 0  18-19    1221
# 1  19-20    1281
# 2  20-21    1094
# 3  21-22    1295
# 4  22-23    1374

# %%
plt.figure(figsize=(8, 5))
plt.plot(EPL_Yellow_trend_df['Season'], EPL_Yellow_trend_df['Yellow'], marker='o', linestyle='-', color='b')
plt.ylim([500, 2000])
plt.grid(True)

# %%
LL_Yellow_trend = []

for data in LL_referee_data_list:
    LL_Yellow_trend.append(data['Yel'].sum())

LL_Yellow_trend_df = pd.DataFrame(LL_Yellow_trend,index=['18-19', '19-20', '20-21', '21-22', '22-23'])
LL_Yellow_trend_df.reset_index(inplace=True)
LL_Yellow_trend_df.columns = ['Season', 'Yellow']
LL_Yellow_trend_df
# Out:
#   Season  Yellow
# 0  18-19    1871
# 1  19-20    1867
# 2  20-21    1639
# 3  21-22    1897
# 4  22-23    1821

# %%
plt.figure(figsize=(8, 5))
plt.plot(LL_Yellow_trend_df['Season'], LL_Yellow_trend_df['Yellow'], marker='o', linestyle='-', color='b')
plt.ylim([500, 2000])
plt.grid(True)

# %%
L1_Yellow_trend = []

for data in L1_referee_data_list:
    L1_Yellow_trend.append(data['Yel'].sum())

L1_Yellow_trend_df = pd.DataFrame(L1_Yellow_trend,index=['18-19', '19-20', '20-21', '21-22', '22-23'])
L1_Yellow_trend_df.reset_index(inplace=True)
L1_Yellow_trend_df.columns = ['Season', 'Yellow']
L1_Yellow_trend_df
# Out:
#   Season  Yellow
# 0  18-19    1348
# 1  19-20    1001
# 2  20-21    1419
# 3  21-22    1426
# 4  22-23    1220

# %%
plt.figure(figsize=(8, 5))
plt.plot(L1_Yellow_trend_df['Season'], L1_Yellow_trend_df['Yellow'], marker='o', linestyle='-', color='b')
plt.ylim([500, 2000])
plt.grid(True)

# %%
SA_Yellow_trend = []

for data in SA_referee_data_list:
    SA_Yellow_trend.append(data['Yel'].sum())

SA_Yellow_trend_df = pd.DataFrame(SA_Yellow_trend,index=['18-19', '19-20', '20-21', '21-22', '22-23'])
SA_Yellow_trend_df.reset_index(inplace=True)
SA_Yellow_trend_df.columns = ['Season', 'Yellow']
SA_Yellow_trend_df
# Out:
#   Season  Yellow
# 0  18-19    1697
# 1  19-20    1827
# 2  20-21    1597
# 3  21-22    1696
# 4  22-23    1657

# %%
plt.figure(figsize=(8, 5))
plt.plot(SA_Yellow_trend_df['Season'], SA_Yellow_trend_df['Yellow'], marker='o', linestyle='-', color='b')
plt.ylim([500, 2000])
plt.grid(True)

# %%
plt.figure(figsize=(8, 5))

plt.plot(BL_Yellow_trend_df['Season'], BL_Yellow_trend_df['Yellow'], marker='^', linestyle='-', color='black', label='Bundesliga')
plt.plot(EPL_Yellow_trend_df['Season'], EPL_Yellow_trend_df['Yellow'], marker='o', linestyle='-', color='b', label='EPL')
plt.plot(LL_Yellow_trend_df['Season'], LL_Yellow_trend_df['Yellow'], marker='D', linestyle='-', color='magenta', label='Laliga')
plt.plot(L1_Yellow_trend_df['Season'], L1_Yellow_trend_df['Yellow'], marker='s', linestyle='-', color='red', label='Ligue1')
plt.plot(SA_Yellow_trend_df['Season'], SA_Yellow_trend_df['Yellow'], marker='x', linestyle='-', color='green', label='SerieA')

plt.ylim([500, 2000])
plt.grid(True)
plt.legend()
plt.title('Big5 League Yellow Card Trend')
plt.show()

# %% [markdown]
# ## Red

# %%
Red_tmp = []
Red_tmp.append(BL_referee['Red'].sum())
Red_tmp.append(EPL_referee['Red'].sum())
Red_tmp.append(LL_referee['Red'].sum())
Red_tmp.append(L1_referee['Red'].sum())
Red_tmp.append(SA_referee['Red'].sum())

Red_df = pd.DataFrame(Red_tmp, index=['BL', 'EPL', 'LL', 'L1', 'SA'], columns=['Red'])
Red_df.reset_index(inplace=True)
Red_df.columns = ['League', 'Red']
Red_df
# Out:
#   League  Red
# 0     BL  198
# 1    EPL  212
# 2     LL  474
# 3     L1  475
# 4     SA  422

# %%
plt.figure(figsize=(8, 5))
sns.barplot(data=Red_df, x='League', y='Red')
plt.grid(True)

# %% [markdown]
# ## Red mean

# %%
Red_mean_tmp = []
Red_mean_tmp.append(BL_referee['Red'].sum()/5)
Red_mean_tmp.append(EPL_referee['Red'].sum()/5)
Red_mean_tmp.append(LL_referee['Red'].sum()/5)
Red_mean_tmp.append(L1_referee['Red'].sum()/5)
Red_mean_tmp.append(SA_referee['Red'].sum()/5)

Red_mean_df = pd.DataFrame(Red_mean_tmp, index=['BL', 'EPL', 'LL', 'L1', 'SA'], columns=['Red_mean'])
Red_mean_df.reset_index(inplace=True)
Red_mean_df.columns = ['League', 'Red_mean']
Red_mean_df
# Out:
#   League  Red_mean
# 0     BL      39.6
# 1    EPL      42.4
# 2     LL      94.8
# 3     L1      95.0
# 4     SA      84.4

# %%
plt.figure(figsize=(8, 5))
sns.barplot(data=Red_mean_df, x='League', y='Red_mean')
plt.grid(True)

# %% [markdown]
# ## 각 리그 Red값 변화

# %%
BL_Red_trend = []

for data in BL_referee_data_list:
    BL_Red_trend.append(data['Red'].sum())

BL_Red_trend_df = pd.DataFrame(BL_Red_trend,index=['18-19', '19-20', '20-21', '21-22', '22-23'])
BL_Red_trend_df.reset_index(inplace=True)
BL_Red_trend_df.columns = ['Season', 'Red']
BL_Red_trend_df
# Out:
#   Season  Red
# 0  18-19   43
# 1  19-20   55
# 2  20-21   33
# 3  21-22   24
# 4  22-23   43

# %%
plt.figure(figsize=(8, 5))
plt.plot(BL_Red_trend_df['Season'], BL_Red_trend_df['Red'], marker='o', linestyle='-', color='b')
plt.ylim([0, 150])
plt.grid(True)

# %%
EPL_Red_trend = []

for data in EPL_referee_data_list:
    EPL_Red_trend.append(data['Red'].sum())

EPL_Red_trend_df = pd.DataFrame(EPL_Red_trend,index=['18-19', '19-20', '20-21', '21-22', '22-23'])
EPL_Red_trend_df.reset_index(inplace=True)
EPL_Red_trend_df.columns = ['Season', 'Red']
EPL_Red_trend_df
# Out:
#   Season  Red
# 0  18-19   47
# 1  19-20   45
# 2  20-21   48
# 3  21-22   42
# 4  22-23   30

# %%
plt.figure(figsize=(8, 5))
plt.plot(EPL_Red_trend_df['Season'], EPL_Red_trend_df['Red'], marker='o', linestyle='-', color='b')
plt.ylim([0, 150])
plt.grid(True)

# %%
LL_Red_trend = []

for data in LL_referee_data_list:
    LL_Red_trend.append(data['Red'].sum())

LL_Red_trend_df = pd.DataFrame(LL_Red_trend,index=['18-19', '19-20', '20-21', '21-22', '22-23'])
LL_Red_trend_df.reset_index(inplace=True)
LL_Red_trend_df.columns = ['Season', 'Red']
LL_Red_trend_df
# Out:
#   Season  Red
# 0  18-19   79
# 1  19-20   89
# 2  20-21   75
# 3  21-22   92
# 4  22-23  139

# %%
plt.figure(figsize=(8, 5))
plt.plot(LL_Red_trend_df['Season'], LL_Red_trend_df['Red'], marker='o', linestyle='-', color='b')
plt.ylim([0, 150])
plt.grid(True)

# %%
L1_Red_trend = []

for data in L1_referee_data_list:
    L1_Red_trend.append(data['Red'].sum())

L1_Red_trend_df = pd.DataFrame(L1_Red_trend,index=['18-19', '19-20', '20-21', '21-22', '22-23'])
L1_Red_trend_df.reset_index(inplace=True)
L1_Red_trend_df.columns = ['Season', 'Red']
L1_Red_trend_df
# Out:
#   Season  Red
# 0  18-19  100
# 1  19-20   70
# 2  20-21  102
# 3  21-22  103
# 4  22-23  100

# %%
plt.figure(figsize=(8, 5))
plt.plot(L1_Red_trend_df['Season'], L1_Red_trend_df['Red'], marker='o', linestyle='-', color='b')
plt.ylim([0, 150])
plt.grid(True)

# %%
SA_Red_trend = []

for data in SA_referee_data_list:
    SA_Red_trend.append(data['Red'].sum())

SA_Red_trend_df = pd.DataFrame(SA_Red_trend,index=['18-19', '19-20', '20-21', '21-22', '22-23'])
SA_Red_trend_df.reset_index(inplace=True)
SA_Red_trend_df.columns = ['Season', 'Red']
SA_Red_trend_df
# Out:
#   Season  Red
# 0  18-19   90
# 1  19-20  102
# 2  20-21   69
# 3  21-22   93
# 4  22-23   68

# %%
plt.figure(figsize=(8, 5))
plt.plot(SA_Red_trend_df['Season'], SA_Red_trend_df['Red'], marker='o', linestyle='-', color='b')
plt.ylim([0,150])
plt.grid(True)

# %%
plt.figure(figsize=(8, 5))

plt.plot(BL_Red_trend_df['Season'], BL_Red_trend_df['Red'], marker='^', linestyle='-', color='black', label='Bundesliga')
plt.plot(EPL_Red_trend_df['Season'], EPL_Red_trend_df['Red'], marker='o', linestyle='-', color='b', label='EPL')
plt.plot(LL_Red_trend_df['Season'], LL_Red_trend_df['Red'], marker='D', linestyle='-', color='magenta', label='Laliga')
plt.plot(L1_Red_trend_df['Season'], L1_Red_trend_df['Red'], marker='s', linestyle='-', color='red', label='Ligue1')
plt.plot(SA_Red_trend_df['Season'], SA_Red_trend_df['Red'], marker='x', linestyle='-', color='green', label='SerieA')

plt.ylim([0, 150])
plt.grid(True)
plt.legend()
plt.title('Big5 League Red Card Trend')
plt.show()

# %% [markdown]
# ## Fouls/Tackles

# %%
F_per_T_tmp = []
F_per_T_tmp.append(BL_referee['Fouls_Tackles'].sum()/BL_referee.shape[0])
F_per_T_tmp.append(EPL_referee['Fouls_Tackles'].sum()/EPL_referee.shape[0])
F_per_T_tmp.append(LL_referee['Fouls_Tackles'].sum()/LL_referee.shape[0])
F_per_T_tmp.append(L1_referee['Fouls_Tackles'].sum()/L1_referee.shape[0])
F_per_T_tmp.append(SA_referee['Fouls_Tackles'].sum()/SA_referee.shape[0])

F_per_T_df = pd.DataFrame(F_per_T_tmp, index=['Bundesliga', 'EPL', 'Laliga', 'Ligue1', 'SerieA'], columns=['Fouls/Tackles'])
F_per_T_df.reset_index(inplace=True)
F_per_T_df.columns = ['League', 'Fouls/Tackles']
F_per_T_df
# Out:
#        League  Fouls/Tackles
# 0  Bundesliga       0.761984
# 1         EPL       0.653204
# 2      Laliga       0.869300
# 3      Ligue1       0.724052
# 4      SerieA       0.897109

# %%
plt.figure(figsize=(8, 5))
plt.plot(F_per_T_df['League'], F_per_T_df['Fouls/Tackles'], marker='o', linestyle='-', color='b')
plt.ylim([0.5, 1])
plt.xticks(rotation=90)
plt.grid(True)

# %% [markdown]
# ## 각 리그 Fouls/Tackles값 변화

# %%
BL_F_per_T_trend = []

for data in BL_referee_data_list:
    BL_F_per_T_trend.append(data['Fouls_Tackles'].sum()/data.shape[0])

BL_F_per_T_trend_df = pd.DataFrame(BL_F_per_T_trend,index=['18-19', '19-20', '20-21', '21-22', '22-23'])
BL_F_per_T_trend_df.reset_index(inplace=True)
BL_F_per_T_trend_df.columns = ['Season', 'Fouls_per_Tackles']
BL_F_per_T_trend_df
# Out:
#   Season  Fouls_per_Tackles
# 0  18-19           0.736000
# 1  19-20           0.759615
# 2  20-21           0.815769
# 3  21-22           0.740833
# 4  22-23           0.754800

# %%
plt.figure(figsize=(8, 5))
plt.plot(BL_F_per_T_trend_df['Season'], BL_F_per_T_trend_df['Fouls_per_Tackles'], marker='o', linestyle='-', color='b')
plt.ylim([0.5, 1])
plt.grid(True)

# %%
EPL_F_per_T_trend = []

for data in EPL_referee_data_list:
    EPL_F_per_T_trend.append(data['Fouls_Tackles'].sum()/data.shape[0])

EPL_F_per_T_trend_df = pd.DataFrame(EPL_F_per_T_trend,index=['18-19', '19-20', '20-21', '21-22', '22-23'])
EPL_F_per_T_trend_df.reset_index(inplace=True)
EPL_F_per_T_trend_df.columns = ['Season', 'Fouls_per_Tackles']
EPL_F_per_T_trend_df
# Out:
#   Season  Fouls_per_Tackles
# 0  18-19           0.595556
# 1  19-20           0.674762
# 2  20-21           0.707368
# 3  21-22           0.620000
# 4  22-23           0.665652

# %%
plt.figure(figsize=(8, 5))
plt.plot(EPL_F_per_T_trend_df['Season'], EPL_F_per_T_trend_df['Fouls_per_Tackles'], marker='o', linestyle='-', color='b')
plt.ylim([0.5, 1])
plt.grid(True)

# %%
LL_F_per_T_trend = []

for data in LL_referee_data_list:
    LL_F_per_T_trend.append(data['Fouls_Tackles'].sum()/data.shape[0])

LL_F_per_T_trend_df = pd.DataFrame(LL_F_per_T_trend,index=['18-19', '19-20', '20-21', '21-22', '22-23'])
LL_F_per_T_trend_df.reset_index(inplace=True)
LL_F_per_T_trend_df.columns = ['Season', 'Fouls_per_Tackles']
LL_F_per_T_trend_df
# Out:
#   Season  Fouls_per_Tackles
# 0  18-19             0.8130
# 1  19-20             0.9250
# 2  20-21             0.9395
# 3  21-22             0.8525
# 4  22-23             0.8165

# %%
plt.figure(figsize=(8, 5))
plt.plot(LL_F_per_T_trend_df['Season'], LL_F_per_T_trend_df['Fouls_per_Tackles'], marker='o', linestyle='-', color='b')
plt.ylim([0.5, 1])
plt.grid(True)

# %%
L1_F_per_T_trend = []

for data in L1_referee_data_list:
    L1_F_per_T_trend.append(data['Fouls_Tackles'].sum()/data.shape[0])

L1_F_per_T_trend_df = pd.DataFrame(L1_F_per_T_trend,index=['18-19', '19-20', '20-21', '21-22', '22-23'])
L1_F_per_T_trend_df.reset_index(inplace=True)
L1_F_per_T_trend_df.columns = ['Season', 'Fouls_per_Tackles']
L1_F_per_T_trend_df
# Out:
#   Season  Fouls_per_Tackles
# 0  18-19           0.731364
# 1  19-20           0.726957
# 2  20-21           0.772609
# 3  21-22           0.695769
# 4  22-23           0.696364

# %%
plt.figure(figsize=(8, 5))
plt.plot(L1_F_per_T_trend_df['Season'], L1_F_per_T_trend_df['Fouls_per_Tackles'], marker='o', linestyle='-', color='b')
plt.ylim([0.5, 1])
plt.grid(True)

# %%
SA_F_per_T_trend = []

for data in SA_referee_data_list:
    SA_F_per_T_trend.append(data['Fouls_Tackles'].sum()/data.shape[0])

SA_F_per_T_trend_df = pd.DataFrame(SA_F_per_T_trend,index=['18-19', '19-20', '20-21', '21-22', '22-23'])
SA_F_per_T_trend_df.reset_index(inplace=True)
SA_F_per_T_trend_df.columns = ['Season', 'Fouls_per_Tackles']
SA_F_per_T_trend_df
# Out:
#   Season  Fouls_per_Tackles
# 0  18-19           0.887692
# 1  19-20           0.957838
# 2  20-21           0.971111
# 3  21-22           0.882000
# 4  22-23           0.796444

# %%
plt.figure(figsize=(8, 5))
plt.plot(SA_F_per_T_trend_df['Season'], SA_F_per_T_trend_df['Fouls_per_Tackles'], marker='o', linestyle='-', color='b')
plt.ylim([0.5, 1])
plt.grid(True)

# %%
plt.figure(figsize=(8, 5))

plt.plot(BL_F_per_T_trend_df['Season'], BL_F_per_T_trend_df['Fouls_per_Tackles'], marker='^', linestyle='-', color='black', label='Bundesliga')
plt.plot(EPL_F_per_T_trend_df['Season'], EPL_F_per_T_trend_df['Fouls_per_Tackles'], marker='o', linestyle='-', color='b', label='EPL')
plt.plot(LL_F_per_T_trend_df['Season'], LL_F_per_T_trend_df['Fouls_per_Tackles'], marker='D', linestyle='-', color='magenta', label='Laliga')
plt.plot(L1_F_per_T_trend_df['Season'], L1_F_per_T_trend_df['Fouls_per_Tackles'], marker='s', linestyle='-', color='red', label='Ligue1')
plt.plot(SA_F_per_T_trend_df['Season'], SA_F_per_T_trend_df['Fouls_per_Tackles'], marker='x', linestyle='-', color='green', label='SerieA')

plt.ylim([0.5, 1])
plt.grid(True)
plt.legend()
plt.title('Big5 League Fouls/Tackles Trend')
plt.show()

# %% [markdown]
# ## 각 리그 Fouls_pg값 변화

# %%
BL_Fouls_pg_trend = []

for data in BL_referee_data_list:
    BL_Fouls_pg_trend.append(data['Fouls_pg'].sum()/data.shape[0])

BL_Fouls_pg_trend_df = pd.DataFrame(BL_Fouls_pg_trend,index=['18-19', '19-20', '20-21', '21-22', '22-23'])
BL_Fouls_pg_trend_df.reset_index(inplace=True)
BL_Fouls_pg_trend_df.columns = ['Season', 'Fouls_pg']
BL_Fouls_pg_trend_df
# Out:
#   Season   Fouls_pg
# 0  18-19  24.031600
# 1  19-20  24.423462
# 2  20-21  24.971538
# 3  21-22  24.002917
# 4  22-23  23.915200

# %%
plt.figure(figsize=(8, 5))
plt.plot(BL_Fouls_pg_trend_df['Season'], BL_Fouls_pg_trend_df['Fouls_pg'], marker='o', linestyle='-', color='b')
plt.ylim([10, 40])
plt.grid(True)

# %%
EPL_Fouls_pg_trend = []

for data in EPL_referee_data_list:
    EPL_Fouls_pg_trend.append(data['Fouls_pg'].sum()/data.shape[0])

EPL_Fouls_pg_trend_df = pd.DataFrame(EPL_Fouls_pg_trend,index=['18-19', '19-20', '20-21', '21-22', '22-23'])
EPL_Fouls_pg_trend_df.reset_index(inplace=True)
EPL_Fouls_pg_trend_df.columns = ['Season', 'Fouls_pg']
EPL_Fouls_pg_trend_df
# Out:
#   Season   Fouls_pg
# 0  18-19  20.356111
# 1  19-20  21.833810
# 2  20-21  21.868421
# 3  21-22  20.494091
# 4  22-23  22.171304

# %%
plt.figure(figsize=(8, 5))
plt.plot(EPL_Fouls_pg_trend_df['Season'], EPL_Fouls_pg_trend_df['Fouls_pg'], marker='o', linestyle='-', color='b')
plt.ylim([10, 40])
plt.grid(True)

# %%
LL_Fouls_pg_trend = []

for data in LL_referee_data_list:
    LL_Fouls_pg_trend.append(data['Fouls_pg'].sum()/data.shape[0])

LL_Fouls_pg_trend_df = pd.DataFrame(LL_Fouls_pg_trend,index=['18-19', '19-20', '20-21', '21-22', '22-23'])
LL_Fouls_pg_trend_df.reset_index(inplace=True)
LL_Fouls_pg_trend_df.columns = ['Season', 'Fouls_pg']
LL_Fouls_pg_trend_df
# Out:
#   Season  Fouls_pg
# 0  18-19   27.0885
# 1  19-20   27.4520
# 2  20-21   26.5075
# 3  21-22   26.4035
# 4  22-23   25.9870

# %%
plt.figure(figsize=(8, 5))
plt.plot(LL_Fouls_pg_trend_df['Season'], LL_Fouls_pg_trend_df['Fouls_pg'], marker='o', linestyle='-', color='b')
plt.ylim([10, 40])
plt.grid(True)

# %%
L1_Fouls_pg_trend = []

for data in L1_referee_data_list:
    L1_Fouls_pg_trend.append(data['Fouls_pg'].sum()/data.shape[0])

L1_Fouls_pg_trend_df = pd.DataFrame(L1_Fouls_pg_trend,index=['18-19', '19-20', '20-21', '21-22', '22-23'])
L1_Fouls_pg_trend_df.reset_index(inplace=True)
L1_Fouls_pg_trend_df.columns = ['Season', 'Fouls_pg']
L1_Fouls_pg_trend_df
# Out:
#   Season   Fouls_pg
# 0  18-19  26.695455
# 1  19-20  25.704348
# 2  20-21  25.779130
# 3  21-22  22.982308
# 4  22-23  24.704545

# %%
plt.figure(figsize=(8, 5))
plt.plot(L1_Fouls_pg_trend_df['Season'], L1_Fouls_pg_trend_df['Fouls_pg'], marker='o', linestyle='-', color='b')
plt.ylim([10, 40])
plt.grid(True)

# %%
SA_Fouls_pg_trend = []

for data in SA_referee_data_list:
    SA_Fouls_pg_trend.append(data['Fouls_pg'].sum()/data.shape[0])

SA_Fouls_pg_trend_df = pd.DataFrame(SA_Fouls_pg_trend,index=['18-19', '19-20', '20-21', '21-22', '22-23'])
SA_Fouls_pg_trend_df.reset_index(inplace=True)
SA_Fouls_pg_trend_df.columns = ['Season', 'Fouls_pg']
SA_Fouls_pg_trend_df
# Out:
#   Season   Fouls_pg
# 0  18-19  27.087692
# 1  19-20  27.296757
# 2  20-21  27.402222
# 3  21-22  26.859778
# 4  22-23  24.926889

# %%
plt.figure(figsize=(8, 5))
plt.plot(SA_Fouls_pg_trend_df['Season'], SA_Fouls_pg_trend_df['Fouls_pg'], marker='o', linestyle='-', color='b')
plt.ylim([10, 40])
plt.grid(True)

# %%
plt.figure(figsize=(8, 5))

plt.plot(BL_Fouls_pg_trend_df['Season'], BL_Fouls_pg_trend_df['Fouls_pg'], marker='^', linestyle='-', color='black', label='Bundesliga')
plt.plot(EPL_Fouls_pg_trend_df['Season'], EPL_Fouls_pg_trend_df['Fouls_pg'], marker='o', linestyle='-', color='b', label='EPL')
plt.plot(LL_Fouls_pg_trend_df['Season'], LL_Fouls_pg_trend_df['Fouls_pg'], marker='D', linestyle='-', color='magenta', label='Laliga')
plt.plot(L1_Fouls_pg_trend_df['Season'], L1_Fouls_pg_trend_df['Fouls_pg'], marker='s', linestyle='-', color='red', label='Ligue1')
plt.plot(SA_Fouls_pg_trend_df['Season'], SA_Fouls_pg_trend_df['Fouls_pg'], marker='x', linestyle='-', color='green', label='SerieA')

plt.ylim([10, 40])
plt.grid(True)
plt.legend()
plt.title('Big5 League Fouls per Game Trend')
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

import statsmodels.api as sm
from sklearn.model_selection import train_test_split

# %%
FW = pd.read_csv('./position data/FW_5seasons.csv')
FW.drop('Unnamed: 0', axis=1, inplace=True)
FW
# Out:
#                    Name                 Team  Age Position  Apps  Mins  Goals  \
# 0    Robert Lewandowski        Bayern Munich   35       FW    33  2959     22
# 1           Ádám Szalai           Hoffenheim   36       FW    30  1621      6
# 2      Sébastien Haller  Eintracht Frankfurt   29       FW    29  2181     15
# 3            Luka Jovic  Eintracht Frankfurt   26       FW    32  2249     17
# 4          Lucas Alario     Bayer Leverkusen   31       FW    27  1256      9
# ..                  ...                  ...  ...      ...   ...   ...    ...
# 523  Cristian Buonaiuto            Cremonese   31       FW    29   970      1
# 524      Daniel Ciofani            Cremonese   38       FW    32  1058      8
# 525    Felix Afena-Gyan            Cremonese   21       FW    23   812      0
# 526        Milan Djuric               Verona   33       FW    28  1364      1
# 527        M'Bala Nzola               Spezia   27       FW    31  2654     13
#
#      Assists  Yellow  Red  ...  Fouled  Off  Disp  UnsTch  AvgP   PSp  \
# 0          7       2    0  ...     1.4  0.9   1.5     1.5  22.1  77.5
# 1          3       3    0  ...     0.8  0.3   0.7     0.7  14.0  71.1
# 2          9       3    0  ...     1.5  0.7   1.7     1.7  27.0  63.5
# 3          5       1    0  ...     1.3  0.5   1.4     1.4  18.7  70.4
# 4          3       1    0  ...     0.9  0.5   0.9     0.9  15.0  75.5
# ..       ...     ...  ...  ...     ...  ...   ...     ...   ...   ...
# 523        0       3    0  ...     0.8  0.0   1.0     1.0  13.0  73.3
# 524        0       1    0  ...     0.5  0.2   0.3     0.3   6.0  62.5
# 525        0       4    0  ...     0.5  0.3   0.9     0.9   8.0  76.6
# 526        1       3    0  ...     1.0  0.2   0.5     0.5  18.5  51.6
# 527        2       8    0  ...     1.3  0.3   2.2     2.2  18.5  80.5
#
#      Crosses  LonB  ThrB       Pts
# 0        0.0   0.6   0.2  1.000000
# 1        0.0   0.4   0.0  0.542373
# 2        0.0   0.4   0.1  0.593220
# 3        0.1   0.9   0.1  0.593220
# 4        0.0   0.3   0.0  0.661017
# ..       ...   ...   ...       ...
# 523      0.6   0.4   0.0  0.112676
# 524      0.0   0.2   0.0  0.112676
# 525      0.0   0.1   0.0  0.112676
# 526      0.0   0.1   0.0  0.169014
# 527      0.1   0.1   0.0  0.169014
#
# [528 rows x 34 columns]

# %%
FW_df = FW.select_dtypes(['int64', 'float64'])
FW_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 528 entries, 0 to 527
# Data columns (total 31 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Age         528 non-null    int64
#  1   Apps        528 non-null    int64
#  2   Mins        528 non-null    int64
#  3   Goals       528 non-null    int64
#  4   Assists     528 non-null    int64
#  5   Yellow      528 non-null    int64
#  6   Red         528 non-null    int64
#  7   SpG         528 non-null    float64
#  8   PS          528 non-null    float64
#  9   Aerialswon  528 non-null    float64
#  10  MotM        528 non-null    int64
#  11  Rating      528 non-null    float64
#  12  Tackles     528 non-null    float64
#  13  Inter       528 non-null    float64
#  14  Fouls       528 non-null    float64
#  15  Offsides    528 non-null    float64
#  16  Clear       528 non-null    float64
#  17  Drb_def     528 non-null    float64
#  18  Blocks      528 non-null    float64
#  19  OwnG        528 non-null    int64
#  20  Drb_off     528 non-null    float64
#  21  Fouled      528 non-null    float64
#  22  Off         528 non-null    float64
#  23  Disp        528 non-null    float64
#  24  UnsTch      528 non-null    float64
#  25  AvgP        528 non-null    float64
#  26  PSp         528 non-null    float64
#  27  Crosses     528 non-null    float64
#  28  LonB        528 non-null    float64
#  29  ThrB        528 non-null    float64
#  30  Pts         528 non-null    float64
# dtypes: float64(22), int64(9)
# memory usage: 128.0 KB

# %% [markdown]
# # 전체 feature를 가지고 예측 모델 생성
# - R-squared: 0.583
# - MSE: 2544.999012366194

# %%
X = FW_df.drop('Pts', axis=1)
y_data = FW_df[['Pts']]

X_data = sm.add_constant(X, has_constant='add')
train_X, test_X, train_y, test_y = train_test_split(X_data, y_data, train_size=0.7, test_size=0.3)

model = sm.OLS(train_y, train_X)
fitted_model = model.fit()
print(fitted_model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    Pts   R-squared:                       0.602
# Model:                            OLS   Adj. R-squared:                  0.568
# Method:                 Least Squares   F-statistic:                     17.68
# Date:                Fri, 10 May 2024   Prob (F-statistic):           1.58e-51
# Time:                        10:18:50   Log-Likelihood:                 153.90
# No. Observations:                 369   AIC:                            -247.8
# Df Residuals:                     339   BIC:                            -130.5
# Df Model:                          29
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -7.3152      0.647    -11.313      0.000      -8.587      -6.043
# Age           -0.0010      0.002     -0.455      0.649      -0.005       0.003
# Apps           0.0185      0.004      5.103      0.000       0.011       0.026
# Mins          -0.0002   4.72e-05     -3.919      0.000      -0.000   -9.21e-05
# Goals         -0.0199      0.005     -3.899      0.000      -0.030      -0.010
# Assists        0.0001      0.007      0.014      0.989      -0.014       0.014
# Yellow         0.0111      0.005      2.072      0.039       0.001       0.022
# Red            0.0255      0.029      0.887      0.376      -0.031       0.082
# SpG           -0.0429      0.023     -1.828      0.068      -0.089       0.003
# PS             0.0628      0.019      3.225      0.001       0.025       0.101
# Aerialswon    -0.0962      0.014     -6.790      0.000      -0.124      -0.068
# MotM           0.0006      0.009      0.064      0.949      -0.017       0.018
# Rating         1.2467      0.108     11.578      0.000       1.035       1.459
# Tackles       -0.0617      0.063     -0.985      0.325      -0.185       0.061
# Inter         -0.0767      0.097     -0.794      0.428      -0.267       0.113
# Fouls         -0.0360      0.031     -1.154      0.249      -0.097       0.025
# Offsides      -0.3130      0.351     -0.892      0.373      -1.003       0.377
# Clear         -0.0536      0.039     -1.383      0.168      -0.130       0.023
# Drb_def       -0.0771      0.055     -1.397      0.163      -0.186       0.031
# Blocks        -0.1654      0.151     -1.095      0.274      -0.462       0.132
# OwnG           0.0624      0.047      1.330      0.184      -0.030       0.155
# Drb_off       -0.1398      0.045     -3.081      0.002      -0.229      -0.051
# Fouled        -0.0706      0.024     -2.919      0.004      -0.118      -0.023
# Off            0.0589      0.041      1.442      0.150      -0.021       0.139
# Disp           0.0274      0.015      1.795      0.074      -0.003       0.057
# UnsTch         0.0274      0.015      1.795      0.074      -0.003       0.057
# AvgP          -0.0023      0.004     -0.624      0.533      -0.010       0.005
# PSp           -0.0646      0.019     -3.338      0.001      -0.103      -0.027
# Crosses       -0.0549      0.141     -0.388      0.698      -0.333       0.223
# LonB          -0.0431      0.043     -0.998      0.319      -0.128       0.042
# ThrB          -0.3603      0.209     -1.724      0.086      -0.771       0.051
# ==============================================================================
# Omnibus:                        4.720   Durbin-Watson:                   1.905
# Prob(Omnibus):                  0.094   Jarque-Bera (JB):                4.509
# Skew:                           0.265   Prob(JB):                        0.105
# Kurtosis:                       3.115   Cond. No.                     1.11e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 9.65e-24. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
pred = fitted_model.predict(test_X)

plt.figure(figsize=(30, 10))
plt.plot(np.array(pred), label='pred')
plt.plot(np.array(test_y), label='true')
plt.grid(True)
plt.legend()
plt.show()

# %%
MSE = ((np.array(pred) - np.array(test_y))**2).sum() / test_X.shape[0]
MSE
# Out:
# 15.0041687771821

# %% [markdown]
# # feature 정제
# 1. 특정 지표 하나만 가지고 모델 생성
# 2. 내가 뽑은 주요 지표만 가지고 모델 생성
# 3. 의미 없어 보이는 몇 개의 데이터만 제거한 모델

# %% [markdown]
# ## 1-1. 특정 지표 하나만 가지고 모델 생성 - Goals
# - R-squared: 0.205
# - MSE: 17212.50769198861

# %%
X2 = FW_df[['Goals']]
y_data2 = FW_df[['Pts']]

X_data2 = sm.add_constant(X2, has_constant='add')
train_X2, test_X2, train_y2, test_y2 = train_test_split(X_data2, y_data2, train_size=0.7, test_size=0.3, random_state=42)

model2 = sm.OLS(train_y2, train_X2)
fitted_model2 = model2.fit()
print(fitted_model2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    Pts   R-squared:                       0.205
# Model:                            OLS   Adj. R-squared:                  0.203
# Method:                 Least Squares   F-statistic:                     94.77
# Date:                Fri, 10 May 2024   Prob (F-statistic):           4.49e-20
# Time:                        10:18:50   Log-Likelihood:                 35.711
# No. Observations:                 369   AIC:                            -67.42
# Df Residuals:                     367   BIC:                            -59.60
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.2485      0.018     13.953      0.000       0.214       0.284
# Goals          0.0167      0.002      9.735      0.000       0.013       0.020
# ==============================================================================
# Omnibus:                       18.162   Durbin-Watson:                   2.051
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               19.505
# Skew:                           0.553   Prob(JB):                     5.81e-05
# Kurtosis:                       3.209   Cond. No.                         16.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
pred2 = fitted_model2.predict(test_X2)

plt.figure(figsize=(30, 10))
plt.plot(np.array(pred), label='pred')
plt.plot(np.array(test_y2), label='true')
plt.grid(True)
plt.legend()
plt.savefig('Goals.png')
plt.show()

# %%
MSE2 = ((np.array(pred2) - np.array(test_y2))**2).sum() / test_X2.shape[0]
MSE2
# Out:
# 12.72915995068301

# %% [markdown]
# ## 1-2. 특정 지표 하나만 가지고 모델 생성 - Assists
# - R-squared: 0.154
# - MSE: 12624.694700608072

# %%
X3 = FW_df[['Assists']]
y_data3 = FW_df[['Pts']]

X_data3 = sm.add_constant(X3, has_constant='add')
train_X3, test_X3, train_y3, test_y3 = train_test_split(X_data3, y_data3, train_size=0.7, test_size=0.3, random_state=42)

model3 = sm.OLS(train_y3, train_X3)
fitted_model3 = model3.fit()
print(fitted_model3.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    Pts   R-squared:                       0.154
# Model:                            OLS   Adj. R-squared:                  0.152
# Method:                 Least Squares   F-statistic:                     66.80
# Date:                Fri, 10 May 2024   Prob (F-statistic):           4.93e-15
# Time:                        10:18:51   Log-Likelihood:                 24.181
# No. Observations:                 369   AIC:                            -44.36
# Df Residuals:                     367   BIC:                            -36.54
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.2865      0.017     17.306      0.000       0.254       0.319
# Assists        0.0468      0.006      8.173      0.000       0.036       0.058
# ==============================================================================
# Omnibus:                       14.018   Durbin-Watson:                   2.101
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               14.918
# Skew:                           0.492   Prob(JB):                     0.000576
# Kurtosis:                       2.991   Cond. No.                         4.30
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
pred3 = fitted_model3.predict(test_X3)

plt.figure(figsize=(30, 10))
plt.plot(np.array(pred), label='pred')
plt.plot(np.array(test_y3), label='true')
plt.grid(True)
plt.legend()
plt.savefig('Assists.png')
plt.show()

# %%
MSE3 = ((np.array(pred3) - np.array(test_y3))**2).sum() / test_X3.shape[0]
MSE3
# Out:
# 12.30654590782028

# %% [markdown]
# ## 1-3. 특정 지표 하나만 가지고 모델 생성 - SpG
# - R-squared: 0.139
# - MSE: 15686.32213555647

# %%
X4 = FW_df[['SpG']]
y_data4 = FW_df[['Pts']]

X_data4 = sm.add_constant(X4, has_constant='add')
train_X4, test_X4, train_y4, test_y4 = train_test_split(X_data4, y_data4, train_size=0.7, test_size=0.3, random_state=42)

model4 = sm.OLS(train_y4, train_X4)
fitted_model4 = model4.fit()
print(fitted_model4.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    Pts   R-squared:                       0.139
# Model:                            OLS   Adj. R-squared:                  0.137
# Method:                 Least Squares   F-statistic:                     59.44
# Date:                Fri, 10 May 2024   Prob (F-statistic):           1.20e-13
# Time:                        10:18:51   Log-Likelihood:                 21.024
# No. Observations:                 369   AIC:                            -38.05
# Df Residuals:                     367   BIC:                            -30.23
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.2072      0.026      8.112      0.000       0.157       0.257
# SpG            0.0986      0.013      7.710      0.000       0.073       0.124
# ==============================================================================
# Omnibus:                       11.873   Durbin-Watson:                   2.061
# Prob(Omnibus):                  0.003   Jarque-Bera (JB):               12.491
# Skew:                           0.450   Prob(JB):                      0.00194
# Kurtosis:                       2.956   Cond. No.                         5.15
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
pred4 = fitted_model4.predict(test_X4)

plt.figure(figsize=(30, 10))
plt.plot(np.array(pred), label='pred')
plt.plot(np.array(test_y4), label='true')
plt.grid(True)
plt.legend()
plt.savefig('SpG.png')
plt.show()

# %%
MSE4 = ((np.array(pred4) - np.array(test_y4))**2).sum() / test_X4.shape[0]
MSE4
# Out:
# 12.444305538268297

# %% [markdown]
# ## 2-1. 상위 3개 feature

# %%
X5 = FW_df[['Goals', 'Assists', 'SpG']]
y_data5 = FW_df[['Pts']]

X_data5 = sm.add_constant(X5, has_constant='add')
train_X5, test_X5, train_y5, test_y5 = train_test_split(X_data5, y_data5, train_size=0.7, test_size=0.3)

model5 = sm.OLS(train_y5, train_X5)
fitted_model5 = model5.fit()
print(fitted_model5.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    Pts   R-squared:                       0.242
# Model:                            OLS   Adj. R-squared:                  0.235
# Method:                 Least Squares   F-statistic:                     38.77
# Date:                Fri, 10 May 2024   Prob (F-statistic):           9.04e-22
# Time:                        10:52:09   Log-Likelihood:                 22.661
# No. Observations:                 369   AIC:                            -37.32
# Df Residuals:                     365   BIC:                            -21.68
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.2225      0.027      8.286      0.000       0.170       0.275
# Goals          0.0109      0.003      3.282      0.001       0.004       0.017
# Assists        0.0246      0.007      3.295      0.001       0.010       0.039
# SpG            0.0254      0.023      1.128      0.260      -0.019       0.070
# ==============================================================================
# Omnibus:                       13.835   Durbin-Watson:                   2.073
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               14.515
# Skew:                           0.483   Prob(JB):                     0.000705
# Kurtosis:                       3.095   Cond. No.                         29.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
pred5 = fitted_model5.predict(test_X5)

plt.figure(figsize=(30, 10))
plt.plot(np.array(pred), label='pred')
plt.plot(np.array(test_y5), label='true')
plt.grid(True)
plt.legend()
plt.savefig('top_3_features.png')
plt.show()

# %%
MSE5 = ((np.array(pred5) - np.array(test_y5))**2).sum() / test_X5.shape[0]
MSE5
# Out:
# 10.369614161506998

# %% [markdown]
# ## 2-2. 상위 5개 feature

# %%
X6 = FW_df[['Goals', 'Assists', 'SpG', 'PS', 'ThrB']]
y_data6 = FW_df[['Pts']]

X_data6 = sm.add_constant(X6, has_constant='add')
train_X6, test_X6, train_y6, test_y6 = train_test_split(X_data6, y_data6, train_size=0.7, test_size=0.3)

model6 = sm.OLS(train_y6, train_X6)
fitted_model6 = model6.fit()
print(fitted_model6.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    Pts   R-squared:                       0.299
# Model:                            OLS   Adj. R-squared:                  0.289
# Method:                 Least Squares   F-statistic:                     30.92
# Date:                Fri, 10 May 2024   Prob (F-statistic):           3.33e-26
# Time:                        10:51:41   Log-Likelihood:                 39.984
# No. Observations:                 369   AIC:                            -67.97
# Df Residuals:                     363   BIC:                            -44.50
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.2994      0.114     -2.626      0.009      -0.524      -0.075
# Goals          0.0136      0.003      4.278      0.000       0.007       0.020
# Assists        0.0153      0.007      2.136      0.033       0.001       0.029
# SpG            0.0010      0.021      0.046      0.963      -0.040       0.042
# PS             0.0081      0.002      4.818      0.000       0.005       0.011
# ThrB           0.0549      0.264      0.208      0.835      -0.464       0.573
# ==============================================================================
# Omnibus:                       17.419   Durbin-Watson:                   2.076
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               18.535
# Skew:                           0.530   Prob(JB):                     9.44e-05
# Kurtosis:                       3.285   Cond. No.                     1.62e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.62e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
pred6 = fitted_model6.predict(test_X6)

plt.figure(figsize=(30, 10))
plt.plot(np.array(pred), label='pred')
plt.plot(np.array(test_y6), label='true')
plt.grid(True)
plt.legend()
plt.savefig('top_5_features.png')
plt.show()

# %%
MSE6 = ((np.array(pred6) - np.array(test_y6))**2).sum() / test_X6.shape[0]
MSE6
# Out:
# 11.829055943877805

# %% [markdown]
# ## 쓸데없는 지표로 만든 모델

# %%
X8 = FW_df[['Age']]
y_data8 = FW_df[['Pts']]

X_data8 = sm.add_constant(X8, has_constant='add')
train_X8, test_X8, train_y8, test_y8 = train_test_split(X_data8, y_data8, train_size=0.7, test_size=0.3)

model8 = sm.OLS(train_y8, train_X8)
fitted_model8 = model8.fit()
print(fitted_model8.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    Pts   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.003
# Method:                 Least Squares   F-statistic:                   0.01588
# Date:                Fri, 10 May 2024   Prob (F-statistic):              0.900
# Time:                        10:18:52   Log-Likelihood:                -14.462
# No. Observations:                 369   AIC:                             32.92
# Df Residuals:                     367   BIC:                             40.75
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.4071      0.081      5.037      0.000       0.248       0.566
# Age           -0.0003      0.003     -0.126      0.900      -0.005       0.005
# ==============================================================================
# Omnibus:                       21.440   Durbin-Watson:                   1.837
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               24.186
# Skew:                           0.625   Prob(JB):                     5.60e-06
# Kurtosis:                       2.895   Cond. No.                         190.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
pred8 = fitted_model8.predict(test_X8)

plt.figure(figsize=(30, 10))
plt.plot(np.array(pred), label='pred')
plt.plot(np.array(test_y8), label='true')
plt.grid(True)
plt.legend()
plt.savefig('Age.png')
plt.show()

# %%
MSE8 = ((np.array(pred8) - np.array(test_y8))**2).sum() / test_X8.shape[0]
MSE8
# Out:
# 10.054747579657512

# %% [markdown]
# ## 3. 정말 의미 없는 지표만 제거
# - Rating, MotM 등 경기 후에 나오는 지표도 제거

# %%
X7 = FW_df.drop(['Pts', 'Blocks', 'Disp', 'Age', 'Apps', 'Mins', 'Tackles', 'Clear', 'Rating', 'MotM'], axis=1)
y_data7 = FW_df[['Pts']]

X_data7 = sm.add_constant(X7, has_constant='add')
train_X7, test_X7, train_y7, test_y7 = train_test_split(X_data7, y_data7, train_size=0.7, test_size=0.3)

model7 = sm.OLS(train_y7, train_X7)
fitted_model7 = model7.fit()
print(fitted_model7.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    Pts   R-squared:                       0.440
# Model:                            OLS   Adj. R-squared:                  0.406
# Method:                 Least Squares   F-statistic:                     12.97
# Date:                Fri, 10 May 2024   Prob (F-statistic):           2.09e-32
# Time:                        10:50:59   Log-Likelihood:                 90.576
# No. Observations:                 369   AIC:                            -137.2
# Df Residuals:                     347   BIC:                            -51.12
# Df Model:                          21
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0564      0.141     -0.401      0.689      -0.333       0.220
# Goals          0.0137      0.003      4.432      0.000       0.008       0.020
# Assists        0.0258      0.007      3.606      0.000       0.012       0.040
# Yellow        -0.0007      0.006     -0.119      0.905      -0.012       0.011
# Red           -0.0257      0.034     -0.755      0.451      -0.093       0.041
# SpG            0.0682      0.024      2.890      0.004       0.022       0.115
# PS             0.0844      0.021      3.967      0.000       0.043       0.126
# Aerialswon    -0.0024      0.012     -0.201      0.841      -0.026       0.021
# Inter         -0.0092      0.103     -0.090      0.929      -0.212       0.193
# Fouls         -0.0384      0.036     -1.058      0.291      -0.110       0.033
# Offsides       0.0225      0.380      0.059      0.953      -0.726       0.770
# Drb_def       -0.0767      0.061     -1.253      0.211      -0.197       0.044
# OwnG           0.1590      0.071      2.225      0.027       0.018       0.300
# Drb_off        0.0231      0.046      0.497      0.619      -0.068       0.114
# Fouled        -0.0542      0.026     -2.066      0.040      -0.106      -0.003
# Off           -0.0333      0.048     -0.693      0.489      -0.128       0.061
# UnsTch        -0.0738      0.035     -2.135      0.033      -0.142      -0.006
# AvgP          -0.0070      0.004     -1.818      0.070      -0.014       0.001
# PSp           -0.0774      0.021     -3.644      0.000      -0.119      -0.036
# Crosses       -0.0231      0.156     -0.148      0.882      -0.329       0.283
# LonB          -0.0692      0.047     -1.463      0.144      -0.162       0.024
# ThrB           0.2805      0.245      1.147      0.252      -0.201       0.761
# ==============================================================================
# Omnibus:                        3.087   Durbin-Watson:                   2.172
# Prob(Omnibus):                  0.214   Jarque-Bera (JB):                2.840
# Skew:                           0.205   Prob(JB):                        0.242
# Kurtosis:                       3.131   Cond. No.                     3.73e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.73e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
pred7 = fitted_model7.predict(test_X7)

plt.figure(figsize=(30, 10))
plt.plot(np.array(pred7), label='pred')
plt.plot(np.array(test_y7), label='true')
plt.grid(True)
plt.legend()
plt.savefig('All_features.png')
plt.show()

# %%
MSE7 = ((np.array(pred7) - np.array(test_y7))**2).sum() / test_X7.shape[0]
MSE7
# Out:
# 14.165699987181751

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## 데이터 가져오기

# %%
league_features = {'1' :{'FW':['Assists', 'PS%', 'Goals'], 
                         'AM':['PS%', 'Goals', 'ThrB', 'SpG', 'Assists'],
                         'M':['PS%', 'Goals', 'AvgP', 'ThrB', 'Assists'],
                         'DM':['PS%'],
                         'D':['PS%', 'AvgP'],
                         'GK':['PS%', 'Dribble', 'Fouls', 'Disp']},
                   '2' :{'FW':['Goals', 'SpG', 'PS%', 'KeyP', 'Assists'],
                         'AM':['PS%', 'AvgP', 'Goals', 'SpG', 'Assists'],
                         'M':['Assists', 'ThrB', 'KeyP', 'LongB', 'SpG'],
                         'DM':['Assists', 'ThrB', 'Goals', 'KeyP'],
                         'D':['PS%', 'AvgP', 'ThrB', 'Assists'],
                         'GK':['PS%', 'Mins']},
                   '3' :{'FW':['PS%', 'KeyP', 'Dribble', 'ThrB', 'SpG'],
                         'AM':['AvgP', 'Assists', 'KeyP', 'ThrB', 'PS%'],
                         'M':['PS%', 'AvgP', 'Assists', 'Blocks', 'LongB'],
                         'DM':['AvgP', 'ThrB', 'PS%', 'AerialsWon', 'Fouled'],
                         'D':['PS%', 'AvgP', 'ThrB'],
                         'GK':['PS%', 'AvgP']},
                   '4':{'FW':['Assists', 'Goals'],
                        'AM':['Assists', 'PS%', 'Dribble', 'SpG', 'ThrB'],
                        'M':['PS%', 'Assists'],
                        'DM':['PS%', 'AvgP', 'LongB', 'Blocks'],
                        'D':['PS%', 'AvgP', 'Assists'],
                        'GK':['PS%', 'KeyP']},
                   '5':{'FW':['Goals', 'Assists', 'SpG', 'KeyP'],
                        'AM':['Assists'],
                        'M':['PS%'],
                        'DM':['PS%'],
                        'D':['PS%'],
                        'GK':['PS%']},
                   '6': {'FW':['Goals', 'Assists', 'SpG', 'PS%', 'ThrB'],
                         'AM':['Goals', 'Assists', 'PS%', 'SpG', 'AvgP'],
                         'M':['PS%', 'Assists', 'AvgP', 'Goals'],
                         'DM':['PS%', 'AvgP'],
                         'D':['PS%', 'AvgP'],
                         'GK':['PS%']}}

# %%
BL_player = pd.read_csv('./EDA/5_League/Budesliga_data/BL_player_value_merged.csv')
EPL_player = pd.read_csv('./EDA/5_League/EPL_data/EPL_player_value_merged.csv')
LL_player = pd.read_csv('./EDA/5_League/Laliga_data/LL_player_value_merged.csv')
L1_player = pd.read_csv('./EDA/5_League/League1_data/L1_player_value_merged.csv')
SA_player = pd.read_csv('./EDA/5_League/SerieA_data/SA_player_value_merged.csv')

# %% [markdown]
# ## 데이터 전처리
# - 필요없는 컬럼 삭제
# - Position 재정의

# %%
BL_player.drop('Unnamed: 0', axis=1, inplace=True)
EPL_player.drop('Unnamed: 0', axis=1, inplace=True)
LL_player.drop('Unnamed: 0', axis=1, inplace=True)
L1_player.drop('Unnamed: 0', axis=1, inplace=True)
SA_player.drop('Unnamed: 0', axis=1, inplace=True)

# %%
po_li = BL_player['Position']
for i in range(BL_player.shape[0]):
    if po_li[i] == 'Attacking Midfield':
        po_li[i] = 'AM'
    elif po_li[i] == 'Central Midfield' or po_li[i] == 'Left Midfield' or po_li[i] == 'Right Midfield':
        po_li[i] = 'M'
    elif po_li[i] == 'Defensive Midfield':
        po_li[i] = 'DM'
    elif po_li[i] == 'Centre-Back' or po_li[i] == 'Right-Back' or po_li[i] == 'Left-Back':
        po_li[i] = 'D'
    elif po_li[i] == 'Centre-Forward' or po_li[i] == 'Right Winger' or po_li[i] == 'Left Winger' or po_li[i] == 'Second Striker':
        po_li[i] = 'FW'
    elif po_li[i] == 'Goalkeeper':
        po_li[i] = 'GK'
        
BL_player['Position'] = pd.DataFrame(po_li, columns=['Position'])
BL_player['Position']
# Out:
# /var/folders/zt/1l6rrzf977nbpmcz1d2j0vd40000gn/T/ipykernel_85679/3410667279.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   po_li[i] = 'AM'
# /var/folders/zt/1l6rrzf977nbpmcz1d2j0vd40000gn/T/ipykernel_85679/3410667279.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   po_li[i] = 'M'
# /var/folders/zt/1l6rrzf977nbpmcz1d2j0vd40000gn/T/ipykernel_85679/3410667279.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   po_li[i] = 'D'
# /var/folders/zt/1l6rrzf977nbpmcz1d2j0vd40000gn/T/ipykernel_85679/3410667279.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   po_li[i] = 'FW'
# /var/folders/zt/1l6rrzf977nbpmcz1d2j0vd40000gn/T/ipykernel_85679/3410667279.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   po_li[i] = 'GK'
# /var/folders/zt/1l6rrzf977nbpmcz1d2j0vd40000gn/T/ipykernel_85679/3410667279.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   po_li[i] = 'DM'
# 0      AM
# 1       M
# 2       D
# 3      AM
# 4       M
#        ..
# 270    FW
# 271    GK
# 272     M
# 273     D
# 274    FW
# Name: Position, Length: 275, dtype: object

# %%
po_li = EPL_player['Position']
for i in range(EPL_player.shape[0]):
    if po_li[i] == 'Attacking Midfield':
        po_li[i] = 'AM'
    elif po_li[i] == 'Central Midfield' or po_li[i] == 'Left Midfield' or po_li[i] == 'Right Midfield':
        po_li[i] = 'M'
    elif po_li[i] == 'Defensive Midfield':
        po_li[i] = 'DM'
    elif po_li[i] == 'Centre-Back' or po_li[i] == 'Right-Back' or po_li[i] == 'Left-Back':
        po_li[i] = 'D'
    elif po_li[i] == 'Centre-Forward' or po_li[i] == 'Right Winger' or po_li[i] == 'Left Winger' or po_li[i] == 'Second Striker':
        po_li[i] = 'FW'
    elif po_li[i] == 'Goalkeeper':
        po_li[i] = 'GK'
        
EPL_player['Position'] = pd.DataFrame(po_li, columns=['Position'])
EPL_player['Position']
# Out:
# /var/folders/zt/1l6rrzf977nbpmcz1d2j0vd40000gn/T/ipykernel_85679/2424994410.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   po_li[i] = 'M'
# /var/folders/zt/1l6rrzf977nbpmcz1d2j0vd40000gn/T/ipykernel_85679/2424994410.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   po_li[i] = 'D'
# /var/folders/zt/1l6rrzf977nbpmcz1d2j0vd40000gn/T/ipykernel_85679/2424994410.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   po_li[i] = 'FW'
# /var/folders/zt/1l6rrzf977nbpmcz1d2j0vd40000gn/T/ipykernel_85679/2424994410.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   po_li[i] = 'DM'
# /var/folders/zt/1l6rrzf977nbpmcz1d2j0vd40000gn/T/ipykernel_85679/2424994410.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   po_li[i] = 'GK'
# /var/folders/zt/1l6rrzf977nbpmcz1d2j0vd40000gn/T/ipykernel_85679/2424994410.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   po_li[i] = 'AM'
# 0       M
# 1       D
# 2       D
# 3       D
# 4      FW
#        ..
# 299    GK
# 300    FW
# 301    FW
# 302    DM
# 303     M
# Name: Position, Length: 304, dtype: object

# %%
po_li = LL_player['Position']
for i in range(LL_player.shape[0]):
    if po_li[i] == 'Attacking Midfield':
        po_li[i] = 'AM'
    elif po_li[i] == 'Central Midfield' or po_li[i] == 'Left Midfield' or po_li[i] == 'Right Midfield':
        po_li[i] = 'M'
    elif po_li[i] == 'Defensive Midfield':
        po_li[i] = 'DM'
    elif po_li[i] == 'Centre-Back' or po_li[i] == 'Right-Back' or po_li[i] == 'Left-Back':
        po_li[i] = 'D'
    elif po_li[i] == 'Centre-Forward' or po_li[i] == 'Right Winger' or po_li[i] == 'Left Winger' or po_li[i] == 'Second Striker':
        po_li[i] = 'FW'
    elif po_li[i] == 'Goalkeeper':
        po_li[i] = 'GK'
        
LL_player['Position'] = pd.DataFrame(po_li, columns=['Position'])
LL_player['Position']
# Out:
# /var/folders/zt/1l6rrzf977nbpmcz1d2j0vd40000gn/T/ipykernel_85679/1534325327.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   po_li[i] = 'D'
# /var/folders/zt/1l6rrzf977nbpmcz1d2j0vd40000gn/T/ipykernel_85679/1534325327.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   po_li[i] = 'FW'
# /var/folders/zt/1l6rrzf977nbpmcz1d2j0vd40000gn/T/ipykernel_85679/1534325327.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   po_li[i] = 'M'
# /var/folders/zt/1l6rrzf977nbpmcz1d2j0vd40000gn/T/ipykernel_85679/1534325327.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   po_li[i] = 'AM'
# /var/folders/zt/1l6rrzf977nbpmcz1d2j0vd40000gn/T/ipykernel_85679/1534325327.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   po_li[i] = 'DM'
# /var/folders/zt/1l6rrzf977nbpmcz1d2j0vd40000gn/T/ipykernel_85679/1534325327.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   po_li[i] = 'GK'
# 0       D
# 1       D
# 2      FW
# 3      FW
# 4       M
#        ..
# 314    DM
# 315     D
# 316    FW
# 317     M
# 318     M
# Name: Position, Length: 319, dtype: object

# %%
po_li = L1_player['Position']
for i in range(L1_player.shape[0]):
    if po_li[i] == 'Attacking Midfield':
        po_li[i] = 'AM'
    elif po_li[i] == 'Central Midfield' or po_li[i] == 'Left Midfield' or po_li[i] == 'Right Midfield':
        po_li[i] = 'M'
    elif po_li[i] == 'Defensive Midfield':
        po_li[i] = 'DM'
    elif po_li[i] == 'Centre-Back' or po_li[i] == 'Right-Back' or po_li[i] == 'Left-Back':
        po_li[i] = 'D'
    elif po_li[i] == 'Centre-Forward' or po_li[i] == 'Right Winger' or po_li[i] == 'Left Winger' or po_li[i] == 'Second Striker':
        po_li[i] = 'FW'
    elif po_li[i] == 'Goalkeeper':
        po_li[i] = 'GK'
        
L1_player['Position'] = pd.DataFrame(po_li, columns=['Position'])
L1_player['Position']
# Out:
# /var/folders/zt/1l6rrzf977nbpmcz1d2j0vd40000gn/T/ipykernel_85679/2632924717.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   po_li[i] = 'FW'
# /var/folders/zt/1l6rrzf977nbpmcz1d2j0vd40000gn/T/ipykernel_85679/2632924717.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   po_li[i] = 'M'
# /var/folders/zt/1l6rrzf977nbpmcz1d2j0vd40000gn/T/ipykernel_85679/2632924717.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   po_li[i] = 'D'
# /var/folders/zt/1l6rrzf977nbpmcz1d2j0vd40000gn/T/ipykernel_85679/2632924717.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   po_li[i] = 'AM'
# /var/folders/zt/1l6rrzf977nbpmcz1d2j0vd40000gn/T/ipykernel_85679/2632924717.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   po_li[i] = 'DM'
# /var/folders/zt/1l6rrzf977nbpmcz1d2j0vd40000gn/T/ipykernel_85679/2632924717.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   po_li[i] = 'GK'
# 0      FW
# 1       M
# 2       M
# 3      FW
# 4       D
#        ..
# 310     D
# 311     D
# 312     D
# 313     D
# 314    FW
# Name: Position, Length: 315, dtype: object

# %%
po_li = SA_player['Position']
for i in range(SA_player.shape[0]):
    if po_li[i] == 'Attacking Midfield':
        po_li[i] = 'AM'
    elif po_li[i] == 'Central Midfield' or po_li[i] == 'Left Midfield' or po_li[i] == 'Right Midfield':
        po_li[i] = 'M'
    elif po_li[i] == 'Defensive Midfield':
        po_li[i] = 'DM'
    elif po_li[i] == 'Centre-Back' or po_li[i] == 'Right-Back' or po_li[i] == 'Left-Back':
        po_li[i] = 'D'
    elif po_li[i] == 'Centre-Forward' or po_li[i] == 'Right Winger' or po_li[i] == 'Left Winger' or po_li[i] == 'Second Striker':
        po_li[i] = 'FW'
    elif po_li[i] == 'Goalkeeper':
        po_li[i] = 'GK'
        
SA_player['Position'] = pd.DataFrame(po_li, columns=['Position'])
SA_player['Position']
# Out:
# /var/folders/zt/1l6rrzf977nbpmcz1d2j0vd40000gn/T/ipykernel_85679/1519857846.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   po_li[i] = 'FW'
# /var/folders/zt/1l6rrzf977nbpmcz1d2j0vd40000gn/T/ipykernel_85679/1519857846.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   po_li[i] = 'M'
# /var/folders/zt/1l6rrzf977nbpmcz1d2j0vd40000gn/T/ipykernel_85679/1519857846.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   po_li[i] = 'D'
# /var/folders/zt/1l6rrzf977nbpmcz1d2j0vd40000gn/T/ipykernel_85679/1519857846.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   po_li[i] = 'DM'
# /var/folders/zt/1l6rrzf977nbpmcz1d2j0vd40000gn/T/ipykernel_85679/1519857846.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   po_li[i] = 'GK'
# /var/folders/zt/1l6rrzf977nbpmcz1d2j0vd40000gn/T/ipykernel_85679/1519857846.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   po_li[i] = 'AM'
# 0      FW
# 1      FW
# 2       M
# 3       D
# 4       D
#        ..
# 300    FW
# 301    FW
# 302    FW
# 303    FW
# 304     M
# Name: Position, Length: 305, dtype: object

# %%
#BL_player.to_csv('BL_player_stats_value.csv')
#EPL_player.to_csv('EPL_player_stats_value.csv')
#LL_player.to_csv('LL_player_stats_value.csv')
#L1_player.to_csv('L1_player_stats_value.csv')
#SA_player.to_csv('SA_player_stats_value.csv')

# %% [markdown]
# ## 데이터 병합

# %%
BL_player = pd.read_csv('./player stats value/BL_player_stats_value.csv')
EPL_player = pd.read_csv('./player stats value/EPL_player_stats_value.csv')
LL_player = pd.read_csv('./player stats value/LL_player_stats_value.csv')
L1_player = pd.read_csv('./player stats value/L1_player_stats_value.csv')
SA_player = pd.read_csv('./player stats value/SA_player_stats_value.csv')

# %%
all_player = pd.concat([BL_player, EPL_player, LL_player, L1_player, SA_player], ignore_index=True)

# %%
player_df_list = [BL_player, EPL_player, LL_player, L1_player, SA_player, all_player]

# %% [markdown]
# # 통계 도출 프로그램

# %%
player = input('선수 이름을 입력하세요 : ')
league = input('리그를 선택하세요\n1. Bundesliga\n2. EPL\n3. Laliga\n4. Ligue1\n5. SerieA\n6. Big_5\n리그 입력:')
position = input("포지션을 입력하세요 : ")

selected_player = all_player[all_player['player_name'] == player]
features = league_features[str(league)][position]
# Out:
# 선수 이름을 입력하세요 : Harry Kane
# 리그를 선택하세요
# 1. Bundesliga
# 2. EPL
# 3. Laliga
# 4. Ligue1
# 5. SerieA
# 6. Big_5
# 리그 입력:1
# 포지션을 입력하세요 : FW

# %% [markdown]
# ## 특정 리그에 대해서 통계치 보여주기

# %%
# 선택된 리그, 포지션에 해당하는 feature만 뽑아서 보여준다.
selected_league_player_df = player_df_list[int(league)-1]
selected_league_position = selected_league_player_df[selected_league_player_df['Position'] == position][features]
selected_league_position
# Out:
#      Assists   PS%  Goals
# 5          3  76.6      9
# 11         3  73.7      4
# 16         1  55.1      2
# 19         0  68.3      7
# 24         3  82.8     12
# ..       ...   ...    ...
# 259        0  73.9      1
# 265        1  58.9      6
# 267        7  77.3      3
# 270        1  59.5      2
# 274        2  71.7      1
#
# [73 rows x 3 columns]

# %%
selected_league_position_stats = selected_league_position.describe().loc[['mean', 'min', 'max']]
selected_league_position_stats
# Out:
#         Assists        PS%      Goals
# mean   2.835616  69.816438   5.630137
# min    0.000000  44.600000   0.000000
# max   11.000000  84.700000  16.000000

# %%
selected_player[features]
# Out:
#      Assists   PS%  Goals
# 454        3  72.0     30

# %%
for i in range(len(features)):
    league_stats = selected_league_position_stats[[features[i]]]
    print(league_stats)
    print(f'Player Stats: {selected_player[features[i]].tolist()[0]}')
    print('--------------------')
# Out:
#         Assists
# mean   2.835616
# min    0.000000
# max   11.000000
# Player Stats: 3
# --------------------
#             PS%
# mean  69.816438
# min   44.600000
# max   84.700000
# Player Stats: 72.0
# --------------------
#           Goals
# mean   5.630137
# min    0.000000
# max   16.000000
# Player Stats: 30
# --------------------

# %% [markdown]
# # 선수 가격 예측 모델

# %%
all_player
# Out:
#       Unnamed: 0            player_name  team_number team_name  age  \
# 0              0     Christopher Nkunku         7614       RBL   25
# 1              1     Dominik Szoboszlai         7614       RBL   22
# 2              2            Willi Orbán         7614       RBL   30
# 3              3              Dani Olmo         7614       RBL   25
# 4              4          Konrad Laimer         7614       RBL   26
# ...          ...                    ...          ...       ...  ...
# 1513         300           Assan Ceesay           79     Lecce   29
# 1514         301  Federico Di Francesco           79     Lecce   29
# 1515         302           Lameck Banda           79     Lecce   22
# 1516         303        Lorenzo Colombo           79     Lecce   21
# 1517         304   Kristoffer Askildsen           79     Lecce   22
#
#            position    Apps  Mins  Assists  KeyP  ...  Offsides  Clear  Drb  \
# 0       M(CLR),FW     20(5)  1899        4   1.6  ...       0.0    0.4  0.2
# 1         AM(CLR)     28(3)  2453        8   2.3  ...       0.0    0.7  0.8
# 2            D(C)        33  2951        0   0.2  ...       0.5    3.9  0.5
# 3      AM(CLR),FW     15(8)  1285        5   1.7  ...       0.0    0.2  0.3
# 4      D(R),M(CR)     17(4)  1474        0   0.8  ...       0.0    0.3  1.1
# ...             ...     ...   ...      ...   ...  ...       ...    ...  ...
# 1513           FW    20(14)  1818        0   0.2  ...       0.0    0.6  0.2
# 1514     M(LR),FW    23(13)  2040        2   0.7  ...       0.0    0.4  0.3
# 1515        AM(L)    19(17)  1637        1   0.4  ...       0.0    0.1  0.7
# 1516           FW    18(15)  1518        2   0.5  ...       0.0    0.2  0.2
# 1517         M(C)     7(14)   724        0   0.3  ...       0.0    0.3  0.3
#
#       Blocks  OwnG  Position  Date of Birth  Age  Nationality  Market Value
# 0        0.1     0        AM   Nov 14, 1997   25       France       €80.00m
# 1        0.1     0         M   Oct 25, 2000   22      Hungary       €50.00m
# 2        0.7     1         D    Nov 3, 1992   30      Hungary       €10.00m
# 3        0.0     0        AM    May 7, 1998   25        Spain       €40.00m
# 4        0.2     0         M   May 27, 1997   26      Austria       €28.00m
# ...      ...   ...       ...            ...  ...          ...           ...
# 1513     0.1     0        FW   Mar 17, 1994   29   The Gambia        €2.50m
# 1514     0.0     0        FW   Jun 14, 1994   29        Italy        €1.80m
# 1515     0.1     0        FW   Jan 29, 2001   22       Zambia        €4.00m
# 1516     0.0     0        FW    Mar 8, 2002   21        Italy        €5.00m
# 1517     0.2     0         M    Jan 9, 2001   22       Norway        €2.00m
#
# [1518 rows x 40 columns]

# %%
# 가격이 결측인 행은 삭제

all_player['Market Value'].replace('-', np.nan, inplace=True)
all_player.dropna(subset=['Market Value'], inplace=True)
all_player.reset_index(inplace=True)
all_player.drop('index', axis=True, inplace=True)

# %%
value_li = all_player['Market Value'].tolist()

for i in range(all_player.shape[0]):
    value = float(value_li[i][1:len(value_li[i])-1])
    m = value_li[i][-1]
    
    if m == 'm':
        value *= 1000
        
    value_li[i] = value
    
all_player['Market Value'] = pd.DataFrame(value_li)

# %%
all_player[['Market Value']]
# Out:
#       Market Value
# 0          80000.0
# 1          50000.0
# 2          10000.0
# 3          40000.0
# 4          28000.0
# ...            ...
# 1512        2500.0
# 1513        1800.0
# 1514        4000.0
# 1515        5000.0
# 1516        2000.0
#
# [1517 rows x 1 columns]

# %% [markdown]
# # sm.OLS

# %%
import statsmodels.api as sm
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
# 모든 feature 사용

data_tmp = all_player.select_dtypes(['int64', 'float64'])
data = data_tmp.drop(['Market Value', 'team_number'], axis=1)

X = sm.add_constant(data, has_constant='add')
y = data_tmp[['Market Value']]

X_train1, X_test1, y_train1, y_test1 = train_test_split(X, y, train_size=0.8, test_size=0.2, random_state=42)

linear_reg_model = sm.OLS(y_train1, X_train1)
linear_reg_fitted_model = linear_reg_model.fit()
print(linear_reg_fitted_model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           Market Value   R-squared:                       0.545
# Model:                            OLS   Adj. R-squared:                  0.533
# Method:                 Least Squares   F-statistic:                     45.68
# Date:                Thu, 09 May 2024   Prob (F-statistic):          6.69e-178
# Time:                        10:07:54   Log-Likelihood:                -13172.
# No. Observations:                1213   AIC:                         2.641e+04
# Df Residuals:                    1181   BIC:                         2.657e+04
# Df Model:                          31
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -1.409e+05   2.29e+04     -6.143      0.000   -1.86e+05   -9.59e+04
# Unnamed: 0     3.6807      4.229      0.870      0.384      -4.617      11.979
# age        -1961.5629   1066.479     -1.839      0.066   -4053.967     130.842
# Mins          -0.5940      0.832     -0.714      0.476      -2.227       1.039
# Assists      680.9861    273.278      2.492      0.013     144.821    1217.151
# KeyP         629.3704   2004.052      0.314      0.754   -3302.529    4561.270
# AvgP         437.3905     64.301      6.802      0.000     311.234     563.547
# PS%           87.6886     78.657      1.115      0.265     -66.635     242.012
# Crosses    -7205.7246   1668.541     -4.319      0.000   -1.05e+04   -3932.090
# LongB      -1341.5382    428.214     -3.133      0.002   -2181.683    -501.393
# ThrB        3091.6759   6430.246      0.481      0.631   -9524.304    1.57e+04
# Rating      2.797e+04   3613.531      7.739      0.000    2.09e+04    3.51e+04
# Goals        919.3262    203.688      4.513      0.000     519.695    1318.958
# Yel          690.2132    192.691      3.582      0.000     312.159    1068.267
# Red         -531.8355    829.380     -0.641      0.521   -2159.058    1095.386
# SpG         1706.4895   1228.311      1.389      0.165    -703.425    4116.404
# AerialsWon -2172.5669    770.646     -2.819      0.005   -3684.555    -660.579
# MoM          -22.6551    393.984     -0.058      0.954    -795.643     750.332
# Dribble     -312.8570   1386.810     -0.226      0.822   -3033.743    2408.029
# Fouled     -2100.0271   1048.067     -2.004      0.045   -4156.308     -43.746
# Off        -1543.2029   3151.341     -0.490      0.624   -7726.054    4639.648
# Disp        1310.0003   1672.818      0.783      0.434   -1972.027    4592.027
# UnsTch     -2094.7607   1336.451     -1.567      0.117   -4716.844     527.323
# Tackles        4.5872   1114.720      0.004      0.997   -2182.466    2191.641
# Inter      -3995.0695   1528.604     -2.614      0.009   -6994.152    -995.987
# Fouls      -1136.0914   1445.578     -0.786      0.432   -3972.279    1700.096
# Offsides    -699.3081   3485.961     -0.201      0.841   -7538.675    6140.059
# Clear      -1460.6468    875.362     -1.669      0.095   -3178.085     256.791
# Drb        -7032.2578   1599.491     -4.397      0.000   -1.02e+04   -3894.097
# Blocks     -1036.4802   2895.411     -0.358      0.720   -6717.203    4644.243
# OwnG        1232.8786   1339.011      0.921      0.357   -1394.227    3859.984
# Age          512.2460   1066.895      0.480      0.631   -1580.976    2605.468
# ==============================================================================
# Omnibus:                      438.311   Durbin-Watson:                   1.903
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2823.419
# Skew:                           1.522   Prob(JB):                         0.00
# Kurtosis:                       9.826   Cond. No.                     1.31e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.31e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
linear_reg_pred = linear_reg_fitted_model.predict(X_test1)
linear_reg_pred
# Out:
# 724     14116.575062
# 812      4330.522968
# 1466    22344.777950
# 1469    24715.641236
# 51      14082.799571
#             ...
# 358     33451.988652
# 1169    22842.459507
# 111     17919.792137
# 1292    33465.429921
# 816     -7625.760569
# Length: 304, dtype: float64

# %%
plt.figure(figsize=(20, 10))
plt.plot(np.array(linear_reg_pred), label='pred')
plt.plot(np.array(y_test1), label='true')
plt.title('Predict Results with sm.OLS ')
plt.legend()
plt.show()

# %%
np.array(linear_reg_pred) - np.array(y_test1)
# Out:
# array([[ 10616.5750625 ,    830.52296773,  18844.77795046, ...,
#          14419.79213675,  29965.4299208 , -11125.76056887],
#        [ 11116.5750625 ,   1330.52296773,  19344.77795046, ...,
#          14919.79213675,  30465.4299208 , -10625.76056887],
#        [  4116.5750625 ,  -5669.47703227,  12344.77795046, ...,
#           7919.79213675,  23465.4299208 , -17625.76056887],
#        ...,
#        [ -5883.4249375 , -15669.47703227,   2344.77795046, ...,
#          -2080.20786325,  13465.4299208 , -27625.76056887],
#        [-15883.4249375 , -25669.47703227,  -7655.22204954, ...,
#         -12080.20786325,   3465.4299208 , -37625.76056887],
#        [ 12616.5750625 ,   2830.52296773,  20844.77795046, ...,
#          16419.79213675,  31965.4299208 ,  -9125.76056887]])

# %%
MSE = (np.array(linear_reg_pred) - np.array(y_test1)).sum() ** 2 / X_test1.shape[0]
MSE
# Out:
# 4192017695047.887

# %% [markdown]
# ## feature 조정

# %%
import statsmodels.api as sm
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
# 모든 feature 사용

data_tmp = all_player.select_dtypes(['int64', 'float64'])
data = data_tmp.drop(['Market Value', 'team_number', 'KeyP', 'MoM', 'Dribble', 'Tackles', 'Mins', 'Age', 'OwnG', 'Offsides', 'Off', 'Blocks', 'Red'], axis=1)

X = sm.add_constant(data, has_constant='add')
y = data_tmp[['Market Value']]

X_train3, X_test3, y_train3, y_test3 = train_test_split(X, y, train_size=0.8, test_size=0.2, random_state=42)

linear_reg_model3 = sm.OLS(y_train3, X_train3)
linear_reg_fitted_model3 = linear_reg_model3.fit()
print(linear_reg_fitted_model3.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           Market Value   R-squared:                       0.544
# Model:                            OLS   Adj. R-squared:                  0.537
# Method:                 Least Squares   F-statistic:                     71.20
# Date:                Thu, 09 May 2024   Prob (F-statistic):          4.29e-187
# Time:                        10:08:05   Log-Likelihood:                -13174.
# No. Observations:                1213   AIC:                         2.639e+04
# Df Residuals:                    1192   BIC:                         2.650e+04
# Df Model:                          20
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -1.399e+05   1.85e+04     -7.547      0.000   -1.76e+05   -1.03e+05
# Unnamed: 0     3.5321      4.180      0.845      0.398      -4.668      11.733
# age        -1457.1147     93.149    -15.643      0.000   -1639.870   -1274.360
# Assists      689.5910    251.484      2.742      0.006     196.191    1182.991
# AvgP         428.3659     58.439      7.330      0.000     313.711     543.021
# PS%           97.2014     75.430      1.289      0.198     -50.789     245.192
# Crosses    -6851.9822   1153.635     -5.939      0.000   -9115.364   -4588.600
# LongB      -1387.3179    382.341     -3.628      0.000   -2137.454    -637.182
# ThrB        4262.6875   5968.573      0.714      0.475   -7447.391     1.6e+04
# Rating      2.768e+04   2812.988      9.839      0.000    2.22e+04    3.32e+04
# Goals        879.3107    180.512      4.871      0.000     525.154    1233.468
# Yel          652.3250    183.197      3.561      0.000     292.900    1011.750
# SpG         1740.2027   1175.167      1.481      0.139    -565.424    4045.829
# AerialsWon -2122.0404    717.226     -2.959      0.003   -3529.206    -714.875
# Fouled     -2128.2046   1036.851     -2.053      0.040   -4162.460     -93.949
# Disp        1318.4131   1583.732      0.832      0.405   -1788.800    4425.626
# UnsTch     -2451.9260   1211.177     -2.024      0.043   -4828.203     -75.649
# Inter      -4104.8900   1427.692     -2.875      0.004   -6905.960   -1303.820
# Fouls      -1137.0275   1375.645     -0.827      0.409   -3835.983    1561.928
# Clear      -1741.0211    594.725     -2.927      0.003   -2907.846    -574.196
# Drb        -6851.7245   1352.863     -5.065      0.000   -9505.982   -4197.467
# ==============================================================================
# Omnibus:                      440.426   Durbin-Watson:                   1.911
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2857.409
# Skew:                           1.529   Prob(JB):                         0.00
# Kurtosis:                       9.869   Cond. No.                     9.87e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 9.87e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
linear_reg_pred3 = linear_reg_fitted_model3.predict(X_test3)
linear_reg_pred3
# Out:
# 724     14378.336393
# 812      4610.691573
# 1466    21904.821420
# 1469    24401.944844
# 51      14119.534216
#             ...
# 358     33549.540757
# 1169    22446.611348
# 111     17816.193679
# 1292    32317.909977
# 816     -6537.022340
# Length: 304, dtype: float64

# %%
plt.figure(figsize=(20, 10))
plt.plot(np.array(linear_reg_pred3), label='pred')
plt.plot(np.array(y_test3), label='true')
plt.title('Predict Results with sm.OLS(feature removed)')
plt.legend()
plt.show()

# %%
MSE3 = (np.array(linear_reg_pred3) - np.array(y_test3)).sum() ** 2 / X_test3.shape[0]
MSE3
# Out:
# 3688401461750.2485

# %% [markdown]
# # LinearRegression

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
# 모든 feature 사용

data_tmp = all_player.select_dtypes(['int64', 'float64'])

X = data_tmp.drop(['Market Value', 'team_number'], axis=1)
y = data_tmp[['Market Value']]

X_train2, X_test2, y_train2, y_test2 = train_test_split(X, y, train_size=0.8, test_size=0.2, random_state=42)

linear_reg_model2 = LinearRegression()
linear_reg_fitted_model2 = linear_reg_model2.fit(X_train2, y_train2)

# %%
linear_reg_pred2 = linear_reg_fitted_model2.predict(X_test2)
linear_reg_pred2
# Out:
# array([[ 1.41165751e+04],
#        [ 4.33052297e+03],
#        [ 2.23447780e+04],
#        [ 2.47156412e+04],
#        [ 1.40827996e+04],
#        [ 8.87806650e+03],
#        [ 3.36906238e+04],
#        [ 1.38230238e+03],
#        [ 1.65311440e+04],
#        [ 4.80308905e+03],
#        [ 4.18323064e+03],
#        [ 3.63351511e+03],
#        [ 4.21587041e+03],
#        [-9.39860417e+03],
#        [-3.10633644e+03],
#        [ 1.24317865e+04],
#        [ 9.77310194e+03],
#        [ 1.40938959e+03],
#        [ 8.70315252e+03],
#        [ 2.55615172e+04],
#        [ 6.12024468e+03],
#        [ 1.89189451e+04],
#        [-8.66641244e+03],
#        [ 1.69463396e+04],
#        [ 3.70020597e+04],
#        [-4.68515157e+03],
#        [ 4.52290125e+03],
#        [ 1.03311555e+04],
#        [ 1.79455934e+04],
#        [-3.71403038e+03],
#        [ 1.92243953e+04],
#        [ 2.68577913e+04],
#        [ 3.79324224e+04],
#        [ 9.11628031e+03],
#        [ 6.22473970e+03],
#        [ 2.22056675e+03],
#        [-2.66473037e+03],
#        [ 4.27911241e+03],
#        [ 2.83249547e+03],
#        [ 2.13738207e+03],
#        [ 1.02667847e+04],
#        [ 3.42718106e+04],
#        [ 9.99744867e+03],
#        [ 4.14552588e+04],
#        [ 6.88900921e+03],
#        [-1.87173816e+04],
#        [-3.92047470e+03],
#        [-4.20665231e+03],
#        [-6.42624682e+03],
#        [ 2.09767873e+04],
#        [ 3.40189607e+03],
#        [ 3.01986764e+02],
#        [ 1.07359747e+03],
#        [ 2.08892121e+04],
#        [ 3.36120664e+01],
#        [ 1.39401782e+04],
#        [ 4.89175669e+04],
#        [ 1.31325125e+04],
#        [ 4.21837194e+04],
#        [ 1.38315786e+04],
#        [ 1.95433368e+04],
#        [ 1.32608576e+04],
#        [ 3.30467415e+04],
#        [ 1.10714457e+04],
#        [ 1.87277261e+04],
#        [ 1.75323776e+04],
#        [ 1.45187656e+04],
#        [ 7.65918818e+03],
#        [ 6.91476347e+03],
#        [-1.37849845e+04],
#        [ 1.74693730e+04],
#        [ 1.31142368e+04],
#        [ 7.15685881e+03],
#        [ 2.26514993e+03],
#        [ 1.88167496e+04],
#        [ 4.68450385e+04],
#        [ 6.92886961e+03],
#        [ 9.65349002e+03],
#        [ 1.43721039e+04],
#        [ 2.04104188e+04],
#        [ 1.17332611e+04],
#        [ 1.87385373e+04],
#        [ 3.30146335e+04],
#        [-2.91923295e+03],
#        [ 1.83670639e+04],
#        [ 3.03916929e+04],
#        [ 1.92187943e+04],
#        [ 2.07612170e+04],
#        [ 2.56116541e+03],
#        [ 2.22430075e+04],
#        [-7.55885658e+03],
#        [ 1.79767751e+04],
#        [ 1.82506959e+04],
#        [ 6.39737380e+04],
#        [ 2.30326506e+04],
#        [ 3.97858433e+03],
#        [ 4.29740411e+03],
#        [ 1.03676031e+04],
#        [ 1.31464593e+04],
#        [ 2.62563861e+03],
#        [ 1.90774649e+04],
#        [-1.10101993e+04],
#        [ 2.10316275e+04],
#        [ 1.80622239e+04],
#        [ 2.19024285e+04],
#        [ 2.02825314e+04],
#        [ 3.52289568e+04],
#        [ 5.04203096e+04],
#        [ 2.24369435e+04],
#        [-7.21970283e+03],
#        [ 1.40087350e+04],
#        [ 2.99548159e+04],
#        [ 6.98607208e+03],
#        [ 2.58892701e+04],
#        [-3.07449199e+03],
#        [ 1.14256785e+04],
#        [ 6.44202260e+03],
#        [ 2.52105273e+04],
#        [ 1.75437289e+04],
#        [ 2.80365921e+04],
#        [ 1.26512621e+04],
#        [ 6.74741578e+02],
#        [-9.32532078e+03],
#        [-5.58253600e+03],
#        [ 2.45688342e+04],
#        [-1.71004411e+03],
#        [ 2.02506516e+04],
#        [ 1.03049558e+04],
#        [ 1.16698112e+04],
#        [ 2.74455175e+04],
#        [ 5.91189892e+03],
#        [ 1.45899868e+04],
#        [ 2.54634157e+03],
#        [ 1.03925967e+04],
#        [ 7.25810198e+03],
#        [-4.24136812e+03],
#        [ 3.54139747e+03],
#        [ 4.06205439e+04],
#        [-6.78959148e+03],
#        [ 1.20462265e+04],
#        [ 2.07363108e+04],
#        [ 1.17781261e+04],
#        [ 2.01063664e+04],
#        [ 1.61066459e+04],
#        [ 1.34024883e+04],
#        [-2.59392754e+01],
#        [ 3.21804541e+04],
#        [ 1.05426382e+04],
#        [ 4.75897389e+03],
#        [ 3.57059655e+04],
#        [-7.20326564e+03],
#        [ 6.25375921e+03],
#        [ 1.20986454e+04],
#        [ 1.71889802e+04],
#        [ 2.36835260e+04],
#        [ 2.26506327e+04],
#        [ 4.91759548e+04],
#        [ 1.64997072e+04],
#        [ 1.57988463e+04],
#        [ 3.84800817e+04],
#        [ 1.52610312e+04],
#        [ 1.09300552e+04],
#        [ 2.95887980e+04],
#        [-1.71409946e+03],
#        [ 1.45224988e+04],
#        [ 6.42930940e+03],
#        [ 6.62732615e+03],
#        [ 1.91677680e+04],
#        [ 1.07709733e+04],
#        [ 2.24292018e+04],
#        [ 5.47961512e+04],
#        [ 3.33810642e+04],
#        [ 8.87432224e+03],
#        [ 6.47929685e+03],
#        [ 1.22074161e+04],
#        [ 2.45223878e+04],
#        [ 1.96611378e+04],
#        [ 8.73098470e+03],
#        [-5.02473423e+03],
#        [ 2.79568884e+04],
#        [ 1.64989114e+04],
#        [ 1.03923138e+04],
#        [ 8.76004266e+03],
#        [ 1.18985106e+04],
#        [ 2.90730116e+04],
#        [ 1.95023747e+03],
#        [-1.37299191e+04],
#        [ 1.30601207e+04],
#        [ 1.03293919e+04],
#        [ 5.23657633e+04],
#        [ 1.66941105e+04],
#        [ 1.37677354e+04],
#        [ 9.28068518e+03],
#        [ 1.11097691e+03],
#        [-1.00738832e+04],
#        [ 1.70783867e+04],
#        [ 1.56066600e+04],
#        [ 7.82114060e+03],
#        [ 5.16793318e+04],
#        [ 3.89408335e+03],
#        [ 1.19791629e+04],
#        [ 7.33044750e+03],
#        [ 7.44221641e+03],
#        [ 2.43412465e+03],
#        [ 1.57488283e+04],
#        [ 1.19762893e+04],
#        [ 1.07458655e+03],
#        [ 6.25534515e+03],
#        [-6.51799747e+03],
#        [ 5.14027522e+03],
#        [ 4.21914726e+03],
#        [ 3.64628961e+04],
#        [-1.10365950e+04],
#        [-3.50138525e+03],
#        [ 4.31738970e+04],
#        [ 9.52205253e+03],
#        [ 1.80778532e+04],
#        [ 3.35657919e+04],
#        [ 1.20316493e+04],
#        [ 3.78151619e+03],
#        [ 1.81383944e+04],
#        [ 7.24610715e+03],
#        [-7.54422587e+03],
#        [ 2.37145907e+04],
#        [ 7.87375504e+03],
#        [ 1.16498270e+04],
#        [ 5.21641617e+03],
#        [ 2.56891940e+04],
#        [ 8.88816980e+03],
#        [ 5.23472275e+03],
#        [-7.51290279e+03],
#        [-6.78301053e+03],
#        [-1.47664199e+04],
#        [ 1.84611570e+04],
#        [ 3.00767288e+04],
#        [ 1.61565763e+04],
#        [ 2.07943838e+04],
#        [ 9.63000643e+03],
#        [ 9.41689576e+03],
#        [-2.54590680e+03],
#        [ 1.14814149e+04],
#        [ 2.38786598e+04],
#        [ 1.38835549e+04],
#        [ 7.61087149e+02],
#        [ 1.87343060e+04],
#        [-1.34830904e+03],
#        [ 1.47229918e+04],
#        [ 1.16704444e+04],
#        [ 5.24671394e+03],
#        [-3.93665838e+03],
#        [ 2.15442890e+04],
#        [ 2.17475558e+04],
#        [ 1.16227698e+04],
#        [ 2.92189731e+04],
#        [ 1.58569814e+04],
#        [ 4.97566480e+03],
#        [ 2.45327460e+04],
#        [ 1.83442780e+04],
#        [-3.68336390e+02],
#        [ 1.15004450e+04],
#        [ 5.86066164e+03],
#        [ 1.53448690e+04],
#        [ 9.73864427e+03],
#        [-3.89552000e+03],
#        [ 2.27388640e+04],
#        [ 1.30236630e+04],
#        [ 2.58484300e+04],
#        [ 8.92082256e+03],
#        [ 6.86828771e+03],
#        [ 1.55215951e+04],
#        [ 7.73893601e+03],
#        [ 3.78522526e+04],
#        [ 2.68112361e+04],
#        [ 2.40101822e+04],
#        [ 3.66543795e+04],
#        [ 3.96178473e+03],
#        [ 9.38260778e+03],
#        [ 1.68624880e+04],
#        [-9.30995742e+03],
#        [ 1.10783806e+04],
#        [ 1.06328397e+04],
#        [-2.24612689e+03],
#        [ 9.59816693e+03],
#        [ 1.94233606e+04],
#        [ 1.17992311e+04],
#        [ 1.82201710e+04],
#        [ 2.06313045e+04],
#        [ 5.51600643e+03],
#        [ 4.28740773e+04],
#        [ 4.17432265e+03],
#        [ 2.75183507e+04],
#        [ 1.61617503e+04],
#        [-1.26699063e+04],
#        [ 2.39066138e+04],
#        [ 2.82906503e+04],
#        [ 3.05565210e+04],
#        [ 2.68222484e+04],
#        [ 1.03696726e+04],
#        [ 1.75476202e+04],
#        [ 3.34519887e+04],
#        [ 2.28424595e+04],
#        [ 1.79197921e+04],
#        [ 3.34654299e+04],
#        [-7.62576057e+03]])

# %%
plt.figure(figsize=(20, 10))
plt.plot(np.array(linear_reg_pred2), label='pred')
plt.plot(np.array(y_test2), label='true')
plt.legend()
plt.show()

# %%
np.array(linear_reg_pred2) - np.array(y_test2)
# Out:
# array([[ 10616.5750625 ],
#        [  1330.52296773],
#        [ 12344.77795046],
#        [ 14715.64123583],
#        [  9582.79957148],
#        [  4378.06650304],
#        [ -6309.37623882],
#        [ -1617.69761984],
#        [ -5468.85597353],
#        [  1803.08904604],
#        [   183.23064178],
#        [ -6366.48488644],
#        [  1715.87041074],
#        [-10598.60416927],
#        [ -4106.33643553],
#        [  9431.7864678 ],
#        [  4773.101938  ],
#        [  -390.61041144],
#        [  4703.15252008],
#        [ 13561.51719889],
#        [  3120.24467938],
#        [  8918.94511287],
#        [-10166.41243529],
#        [  6946.33961006],
#        [-52997.94025937],
#        [ -6685.15156505],
#        [  -477.09875462],
#        [  6331.15546941],
#        [ 10945.59335339],
#        [ -5714.03038444],
#        [  5224.39525103],
#        [ 19857.79129987],
#        [-27067.57762408],
#        [  2116.28031403],
#        [-41775.26030215],
#        [ -3779.43324941],
#        [ -7664.73037283],
#        [  -720.88758677],
#        [  1332.49547419],
#        [   637.38206929],
#        [  5766.78470365],
#        [  2271.81061582],
#        [  5497.44867235],
#        [-23544.7412467 ],
#        [  4389.00920905],
#        [-18917.38160643],
#        [ -6420.47469705],
#        [ -7206.65231046],
#        [ -6626.24681642],
#        [  5976.78728336],
#        [   901.89607468],
#        [-19698.0132356 ],
#        [ -1426.40252549],
#        [  5889.21208274],
#        [  -666.38793364],
#        [-16059.82180799],
#        [ -1082.43307208],
#        [  5132.51252675],
#        [ 20183.71943497],
#        [  9331.57857591],
#        [  4543.33683783],
#        [  7260.85760881],
#        [ 15046.74146761],
#        [ -8928.55425055],
#        [ 15727.72613416],
#        [ 15032.37758081],
#        [  -481.23440951],
#        [  3159.18817662],
#        [  3414.76346652],
#        [-14984.9845048 ],
#        [  9969.37299605],
#        [  3114.23678986],
#        [  4656.85881215],
#        [    65.14993323],
#        [ -1183.25036678],
#        [ 26845.03850989],
#        [   928.86961129],
#        [  5153.49001823],
#        [  8372.10392744],
#        [ -9589.58116629],
#        [ -3266.73891008],
#        [  3738.53733034],
#        [ -6985.3664864 ],
#        [ -4419.23295153],
#        [ 14367.06385053],
#        [ -4608.30713485],
#        [ 14218.79434557],
#        [  6761.2170278 ],
#        [    61.16540777],
#        [ -2756.99247558],
#        [ -9358.85657635],
#        [  5976.77506167],
#        [  8250.69593539],
#        [-26026.26202026],
#        [  1032.65055749],
#        [ -6021.41566789],
#        [  1797.40410532],
#        [  2367.60309216],
#        [  1146.45925827],
#        [  -874.36139249],
#        [  9077.46493487],
#        [-11510.19928516],
#        [  1031.62751695],
#        [ -6937.77612757],
#        [ 15902.42847379],
#        [ 12282.53144253],
#        [ -4771.04324981],
#        [-49579.69041413],
#        [ -5563.05647008],
#        [-10219.70283278],
#        [ 10008.73501213],
#        [ 11954.81585534],
#        [ -4013.92792443],
#        [ 14889.27005205],
#        [-15074.49198885],
#        [  5425.67851484],
#        [-13557.97739571],
#        [-14789.47271141],
#        [ 11543.72890642],
#        [ 22036.59210526],
#        [  9151.26207922],
#        [ -1325.25842155],
#        [-11825.3207845 ],
#        [ -7082.53600383],
#        [-20431.16577926],
#        [ -2710.04411031],
#        [ 10250.65158772],
#        [  8304.95575824],
#        [  8669.81118883],
#        [ 17445.51754511],
#        [  3911.8989244 ],
#        [  4589.98683941],
#        [  1546.34156623],
#        [  3392.59673249],
#        [  2258.10198236],
#        [-11241.36812184],
#        [  1541.39747282],
#        [  8620.54391621],
#        [ -7789.59147775],
#        [-12953.77350591],
#        [-14263.6891541 ],
#        [-23221.87393776],
#        [ 10106.36635453],
#        [  -893.35414   ],
#        [ 10402.48832099],
#        [ -6025.93927543],
#        [-32819.54593048],
#        [-24457.36178392],
#        [  3758.97389152],
#        [ -4294.0344831 ],
#        [ -8403.26563855],
#        [  2253.759211  ],
#        [  8098.64540657],
#        [ -4811.01976585],
#        [  3683.52604103],
#        [ -2349.36731548],
#        [-50824.04518691],
#        [   499.70722835],
#        [ 10798.84628416],
#        [ 16480.08170563],
#        [ 13261.03122915],
#        [-29069.94483207],
#        [ 14588.79799538],
#        [ -3714.09946224],
#        [  6522.49884511],
#        [  4629.30939547],
#        [  5127.32614727],
#        [-15832.23200926],
#        [  5270.97334792],
#        [ -2570.79818867],
#        [-25203.84881621],
#        [ 16381.06421627],
#        [  5074.32223768],
#        [   979.29684543],
#        [  5207.41607851],
#        [ 16522.38783676],
#        [ 11661.13780723],
#        [  6730.98470312],
#        [ -6824.73422981],
#        [  2956.88843957],
#        [  9498.91144312],
#        [  7892.31382858],
#        [  5760.04266413],
#        [  2898.51064015],
#        [ -5926.98839288],
#        [   450.23747001],
#        [-14229.91906962],
#        [ 10060.12066506],
#        [  4329.39194992],
#        [-12634.23669275],
#        [ 10694.1104996 ],
#        [-14232.26458261],
#        [ -6719.31481706],
#        [ -3389.02309168],
#        [-11073.88317492],
#        [  8078.38666979],
#        [ 11606.6599709 ],
#        [  3321.14059973],
#        [-13320.66820893],
#        [ -6105.91664631],
#        [  7979.16293448],
#        [-10669.55250316],
#        [  3442.21640753],
#        [ -3565.87535491],
#        [ -2251.17168639],
#        [-10023.7107499 ],
#        [ -2425.41344509],
#        [  3755.34514503],
#        [ -7217.9974719 ],
#        [   140.27522076],
#        [-13780.85274086],
#        [ -3537.10388358],
#        [-11436.59499612],
#        [ -4501.38525166],
#        [ 13173.89696667],
#        [  6522.05252599],
#        [ -1922.14682791],
#        [ -1434.20814282],
#        [  5531.64925085],
#        [-21218.48381038],
#        [ 11138.39437389],
#        [  4246.10714966],
#        [ -8544.22586968],
#        [ 11714.59065943],
#        [  1873.7550434 ],
#        [  6649.82699043],
#        [  2716.41617081],
#        [   689.19400271],
#        [  4888.16979903],
#        [  2234.72274849],
#        [ -7962.90278912],
#        [ -7483.0105279 ],
#        [-15016.41993004],
#        [ 15961.15698497],
#        [ 17076.72883563],
#        [ -8843.42368533],
#        [  7794.38383015],
#        [  5630.00642889],
#        [  3916.89575856],
#        [ -4545.9067985 ],
#        [ -8518.58512574],
#        [ 17878.65978746],
#        [ 11183.55490546],
#        [ -1738.91285071],
#        [ 12734.30604877],
#        [ -1948.30904331],
#        [  6722.99177083],
#        [  6670.44444335],
#        [  1746.71394221],
#        [ -4736.65837777],
#        [-13455.71102014],
#        [  6747.55584359],
#        [-13377.23023505],
#        [-15781.02687387],
#        [ 11356.98136176],
#        [  3475.66479508],
#        [  9532.74599736],
#        [ -1655.72201943],
#        [ -2368.33639034],
#        [-26499.55499887],
#        [  3860.66163806],
#        [-16655.1310223 ],
#        [  5238.64427385],
#        [ -8895.51999797],
#        [  2738.86400924],
#        [ -1976.33697404],
#        [ 15848.42998063],
#        [  4920.82256217],
#        [  3368.28770745],
#        [ 11521.59505209],
#        [  4738.93600512],
#        [-27147.74736921],
#        [ 16811.23608468],
#        [-13989.81779652],
#        [ 11654.37945389],
#        [ -3038.21526872],
#        [-15617.39222043],
#        [  1862.48804727],
#        [-11309.95741582],
#        [  6078.38062672],
#        [  2632.83971552],
#        [ -5746.12688614],
#        [ -3401.83307236],
#        [  3423.3605646 ],
#        [  8299.23109205],
#        [ 13220.17098453],
#        [-39368.69547677],
#        [  3516.00643491],
#        [-17125.92268382],
#        [  1674.32265413],
#        [ 19518.35071543],
#        [  7161.75032011],
#        [-14169.90628249],
#        [  9906.6138436 ],
#        [  3290.65028601],
#        [  5556.52095064],
#        [-13177.75155434],
#        [  5369.67264689],
#        [  9547.62015623],
#        [ -8548.01134829],
#        [ 15342.45950688],
#        [ -2080.20786325],
#        [  3465.4299208 ],
#        [ -9125.76056887]])

# %%
MSE2 = (np.array(linear_reg_pred2) - np.array(y_test2)).sum() ** 2 / X_test2.shape[0]
MSE2
# Out:
# 45360302.27500756
